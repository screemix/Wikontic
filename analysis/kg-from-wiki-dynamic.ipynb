# %%
import urllib.parse        
import requests
from bs4 import BeautifulSoup
import re

import numpy as np
from tqdm import tqdm_notebook
from tqdm import tqdm

import json

from utils.structured_dynamic_index_utils_with_db import Aligner
from utils.openai_utils import LLMTripletExtractor
from utils.structured_inference_with_db import extract_triplets

import pandas as pd
import networkx as nx
import plotly.graph_objects as go

import warnings
warnings.filterwarnings('ignore')

from pymongo import MongoClient
import os
from dotenv import load_dotenv, find_dotenv

from utils.structured_dynamic_index_utils_with_db import Aligner

# %%
# --- Mongo Setup ---
_ = load_dotenv(find_dotenv())
mongo_client = MongoClient(os.getenv("MONGO_URI"))
db = mongo_client.get_database("wikidata_ontology")

# --- Extractor Setup ---
# extractor = LLMTripletExtractor(model='gpt-4.1-mini')
aligner = Aligner(db)

# %%
def get_wiki_paragraphs_by_entity(entity_name):

    url = f"https://en.wikipedia.org/wiki/{entity_name}"
    response = requests.get(url)

    soup = BeautifulSoup(response.content, 'html.parser')

    title = soup.find(id="firstHeading")

    text_div = soup.find("div", class_='mw-content-ltr mw-parser-output')

    regex = re.compile('infobox.*')
    last_marked = text_div.find("table", {"class" : regex})

    texts = []
    last_marked = text_div.find("h2")

    for text in last_marked.find_all_previous('p'):
        texts.append(text)

    texts.reverse()
    
    text_metadata = []
    for text in texts:
        external_entities = []
        for entity in text.find_all("a"):
            title = entity.get('title')
            if title:
                external_entities.append(title)
        
        content = text.text.strip()
        if len(content) > 0:
            text_metadata.append((content, external_entities))
    
    return text_metadata

# %%
entity_name = "Steve Jobs"
get_wiki_paragraphs_by_entity(entity_name)
# Out:
# [('Steven Paul Jobs (February 24, 1955 – October 5, 2011) was an American businessman, inventor, and investor best known for co-founding the technology company Apple Inc. Jobs was also the founder of NeXT and chairman and majority shareholder of Pixar. He was a pioneer of the personal computer revolution of the 1970s and 1980s, along with his early business partner and fellow Apple co-founder Steve Wozniak.',
#   ['Apple Inc.',
#    'NeXT',
#    'Pixar',
#    'Personal computer revolution',
#    'Steve Wozniak']),
#  ("Jobs was born in San Francisco in 1955 and adopted shortly afterwards. He attended Reed College in 1972 before withdrawing that same year. In 1974, he traveled through India, seeking enlightenment before later studying Zen Buddhism. He and Wozniak co-founded Apple in 1976 to further develop and sell Wozniak's Apple I personal computer. Together, the duo gained fame and wealth a year later with production and sale of the Apple II, one of the first highly successful mass-produced microcomputers.",
#   ['Reed College',
#    'Hippie trail',
#    'Buddhism in the West',
#    'Apple I',
#    'Apple II',
#    'Microcomputer']),
#  ('Jobs saw the commercial potential of the Xerox Alto in 1979, which was mouse-driven and had a graphical user interface (GUI). This led to the development of the largely unsuccessful Apple Lisa in 1983, followed by the breakthrough Macintosh in 1984, the first mass-produced computer with a GUI. The Macintosh launched the desktop publishing industry in 1985 (for example, the Aldus Pagemaker) with the addition of the Apple LaserWriter, the first laser printer to feature vector graphics and PostScript.',
#   ['Xerox Alto',
#    'Computer mouse',
#    'Graphical user interface',
#    'Apple Lisa',
#    'Macintosh 128K',
#    'Desktop publishing',
#    'Aldus Pagemaker',
#    'LaserWriter',
#    'Laser printer',
#    'Vector graphics',
#    'PostScript']),
#  ("In 1985, Jobs departed Apple after a long power struggle with the company's board and its then-CEO, John Sculley. That same year, Jobs took some Apple employees with him to found NeXT, a computer platform development company that specialized in computers for higher-education and business markets, serving as its CEO. In 1986, he bought the computer graphics division of Lucasfilm, which was spun off independently as Pixar.[3] Pixar produced the first computer-animated feature film, Toy Story (1995), and became a leading animation studio, producing dozens of commercially successful and critically acclaimed films.",
#   ['John Sculley',
#    'Computer platform',
#    'Lucasfilm',
#    'Pixar',
#    'Computer-animated',
#    'Toy Story',
#    'Animation studio',
#    'List of Pixar films']),
#  ('In 1997, Jobs returned to Apple as CEO after the company\'s acquisition of NeXT. He was largely responsible for reviving Apple, which was on the verge of bankruptcy. He worked closely with British designer Jony Ive to develop a line of products and services that had larger cultural ramifications, beginning with the "Think different" advertising campaign, and leading to the iMac, iTunes, Mac OS X, Apple Store, iPod, iTunes Store, iPhone, App Store, and iPad. Jobs was also a board member at Gap Inc. from 1999 to 2002.[4] In 2003, Jobs was diagnosed with a pancreatic neuroendocrine tumor. He died of tumor-related respiratory arrest in 2011; in 2022, he was posthumously awarded the Presidential Medal of Freedom. Since his death, he has won 141 patents; Jobs holds over 450 patents in total.[5]',
#   ['Jony Ive',
#    'Think different',
#    'IMac',
#    'ITunes',
#    'Mac OS X',
#    'Apple Store',
#    'IPod',
#    'ITunes Store',
#    'IPhone',
#    'App Store (iOS)',
#    'IPad',
#    'Gap Inc.',
#    'Pancreatic neuroendocrine tumor',
#    'Respiratory arrest',
#    'Presidential Medal of Freedom'])]

# %%
texts_metadata = get_wiki_paragraphs_by_entity(entity_name)
wiki_entities = []

for text, metadata in texts_metadata:
    wiki_entities.extend(metadata)
wiki_entities
# Out:
# ['Apple Inc.',
#  'NeXT',
#  'Pixar',
#  'Personal computer revolution',
#  'Steve Wozniak',
#  'Reed College',
#  'Hippie trail',
#  'Buddhism in the West',
#  'Apple I',
#  'Apple II',
#  'Microcomputer',
#  'Xerox Alto',
#  'Computer mouse',
#  'Graphical user interface',
#  'Apple Lisa',
#  'Macintosh 128K',
#  'Desktop publishing',
#  'Aldus Pagemaker',
#  'LaserWriter',
#  'Laser printer',
#  'Vector graphics',
#  'PostScript',
#  'John Sculley',
#  'Computer platform',
#  'Lucasfilm',
#  'Pixar',
#  'Computer-animated',
#  'Toy Story',
#  'Animation studio',
#  'List of Pixar films',
#  'Jony Ive',
#  'Think different',
#  'IMac',
#  'ITunes',
#  'Mac OS X',
#  'Apple Store',
#  'IPod',
#  'ITunes Store',
#  'IPhone',
#  'App Store (iOS)',
#  'IPad',
#  'Gap Inc.',
#  'Pancreatic neuroendocrine tumor',
#  'Respiratory arrest',
#  'Presidential Medal of Freedom']

# %%
with open("wiki_entities.json", 'w') as f:
    json.dump(wiki_entities, f)

# %% [markdown]
# ## Inference

# %%
model_name = 'gpt-4.1'
extractor = LLMTripletExtractor(model=model_name)
aligner = Aligner(db)

# %%
entity_name = "Steve Jobs"
jobs_paragraphs = get_wiki_paragraphs_by_entity(entity_name)

for paragraph in jobs_paragraphs:
    initial_triplets, refined_triplets, filtered_triplets = extract_triplets(paragraph, sample_id='wiki-texts', aligner=aligner, extractor=extractor)
    print("Refined triplets: ", refined_triplets)
    print("Filtered triplets: ", filtered_triplets)
# Out:
# Refined triplets:  [{'subject': 'Steven Paul Jobs', 'relation': 'date of birth', 'object': 'February 24, 1955', 'subject_type': 'human', 'object_type': 'point in time', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'date of death', 'object': 'October 5, 2011', 'subject_type': 'human', 'object_type': 'point in time', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'country of citizenship', 'object': 'United States of America', 'subject_type': 'human', 'object_type': 'country', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'occupation', 'object': 'businessman', 'subject_type': 'human', 'object_type': 'profession', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'occupation', 'object': 'inventor', 'subject_type': 'human', 'object_type': 'profession', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'occupation', 'object': 'investor', 'subject_type': 'human', 'object_type': 'profession', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Apple Inc.', 'relation': 'founded by', 'object': 'Steven Paul Jobs', 'subject_type': 'company', 'object_type': 'human', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'NeXT', 'relation': 'founded by', 'object': 'Steven Paul Jobs', 'subject_type': 'company', 'object_type': 'human', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Pixar', 'relation': 'chairperson', 'object': 'Steven Paul Jobs', 'subject_type': 'company', 'object_type': 'human', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'owner of', 'object': 'Pixar', 'subject_type': 'human', 'object_type': 'company', 'qualifiers': [{'relation': 'shareholder type', 'object': 'majority shareholder'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'notable work', 'object': 'personal computer revolution', 'subject_type': 'human', 'object_type': 'event', 'qualifiers': [{'relation': 'point in time', 'object': '1970s'}, {'relation': 'point in time', 'object': '1980s'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'partner in business or sport', 'object': 'Steve Wozniak', 'subject_type': 'human', 'object_type': 'human', 'qualifiers': [{'relation': 'co-founder of', 'object': 'Apple Inc.'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}]
# Filtered triplets:  []
# Refined triplets:  [{'subject': 'Steven Paul Jobs', 'relation': 'place of birth', 'object': 'San Francisco', 'subject_type': 'human', 'object_type': 'city', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'date of birth', 'object': '1955', 'subject_type': 'human', 'object_type': 'point in time', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'practiced by', 'object': 'adoptive parents', 'subject_type': 'human', 'object_type': 'human', 'qualifiers': [{'relation': 'point in time', 'object': 'shortly after 1955'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'educated at', 'object': 'Reed College', 'subject_type': 'human', 'object_type': 'university', 'qualifiers': [{'relation': 'start time', 'object': '1972'}, {'relation': 'end time', 'object': '1972'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'participant in', 'object': 'India', 'subject_type': 'human', 'object_type': 'country', 'qualifiers': [{'relation': 'point in time', 'object': '1974'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'practiced by', 'object': 'Zen Buddhism', 'subject_type': 'human', 'object_type': 'religion', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steve Jobs', 'relation': 'founded by', 'object': 'Apple Inc.', 'subject_type': 'group of humans', 'object_type': 'company', 'qualifiers': [{'relation': 'point in time', 'object': '1976'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steve Wozniak', 'relation': 'founded by', 'object': 'Apple Inc.', 'subject_type': 'group of humans', 'object_type': 'company', 'qualifiers': [{'relation': 'point in time', 'object': '1976'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Apple Inc.', 'relation': 'discoverer or inventor', 'object': 'Apple I', 'subject_type': 'company', 'object_type': 'software', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Apple Inc.', 'relation': 'discoverer or inventor', 'object': 'Apple II', 'subject_type': 'company', 'object_type': 'software', 'qualifiers': [{'relation': 'point in time', 'object': '1977'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Apple II', 'relation': 'instance of', 'object': 'microcomputer', 'subject_type': 'computer', 'object_type': 'computer', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Apple II', 'relation': 'fabrication method', 'object': 'yes', 'subject_type': 'computer', 'object_type': 'query', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}]
# Filtered triplets:  []
# Refined triplets:  [{'subject': 'Steven Paul Jobs', 'relation': 'statement supported by', 'object': 'Xerox Alto', 'subject_type': 'human', 'object_type': 'computer', 'qualifiers': [{'relation': 'point in time', 'object': '1979'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Xerox Alto', 'relation': 'based on', 'object': 'computer mouse', 'subject_type': 'computer', 'object_type': 'input device', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Xerox Alto', 'relation': 'web interface software', 'object': 'graphical user interface', 'subject_type': 'computer', 'object_type': 'user interface', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Apple Lisa', 'relation': 'inspired by', 'object': 'Xerox Alto', 'subject_type': 'computer', 'object_type': 'computer', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Apple Lisa', 'relation': 'inception', 'object': '1983', 'subject_type': 'computer', 'object_type': 'point in time', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Apple Lisa', 'relation': 'has edition or translation', 'object': 'unsuccessful', 'subject_type': 'computer', 'object_type': 'qualitative property', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Macintosh 128K', 'relation': 'follows', 'object': 'Apple Lisa', 'subject_type': 'computer', 'object_type': 'computer', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Macintosh 128K', 'relation': 'inception', 'object': '1984', 'subject_type': 'computer', 'object_type': 'point in time', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Macintosh 128K', 'relation': 'web interface software', 'object': 'graphical user interface', 'subject_type': 'computer', 'object_type': 'user interface', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Macintosh 128K', 'relation': 'nature of statement', 'object': 'mass-produced', 'subject_type': 'computer', 'object_type': 'qualitative property', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Macintosh 128K', 'relation': 'agent of action', 'object': 'desktop publishing industry', 'subject_type': 'computer', 'object_type': 'industry', 'qualifiers': [{'relation': 'point in time', 'object': '1985'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Aldus PageMaker', 'relation': 'instance of', 'object': 'desktop publishing software', 'subject_type': 'software', 'object_type': 'software category', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Apple LaserWriter', 'relation': 'introduced in', 'object': 'Macintosh 128K', 'subject_type': 'printer', 'object_type': 'computer', 'qualifiers': [{'relation': 'point in time', 'object': '1985'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Apple LaserWriter', 'relation': 'instance of', 'object': 'laser printer', 'subject_type': 'printer', 'object_type': 'printer', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Apple LaserWriter', 'relation': 'has characteristic', 'object': 'vector graphics', 'subject_type': 'printer', ' ...
# Filtered triplets:  []
# Refined triplets:  [{'subject': 'Apple Inc.', 'relation': 'employer', 'object': 'Steven Paul Jobs', 'subject_type': 'company', 'object_type': 'human', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'work period (end)', 'object': '1985', 'subject_type': 'human', 'object_type': 'point in time', 'qualifiers': [{'relation': 'employer', 'object': 'Apple'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'together with', 'object': 'John Sculley', 'subject_type': 'human', 'object_type': 'human', 'qualifiers': [{'relation': 'point in time', 'object': '1985'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'notable work', 'object': 'NeXT', 'subject_type': 'human', 'object_type': 'company', 'qualifiers': [{'relation': 'point in time', 'object': '1985'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'NeXT', 'relation': 'industry', 'object': 'computer platform development', 'subject_type': 'fictional company', 'object_type': 'industry', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'NeXT', 'relation': 'chief executive officer', 'object': 'Steven Paul Jobs', 'subject_type': 'fictional company', 'object_type': 'human', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'NeXT', 'relation': 'intended public', 'object': 'higher-education', 'subject_type': 'company', 'object_type': 'industry', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'NeXT', 'relation': 'intended public', 'object': 'business markets', 'subject_type': 'company', 'object_type': 'industry', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'owner of', 'object': 'Lucasfilm computer graphics division', 'subject_type': 'human', 'object_type': 'division', 'qualifiers': [{'relation': 'point in time', 'object': '1986'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Lucasfilm computer graphics division', 'relation': 'separated from', 'object': 'Pixar', 'subject_type': 'division', 'object_type': 'enterprise', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Pixar', 'relation': 'industry', 'object': 'animation studio', 'subject_type': 'fictional company', 'object_type': 'industry', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Pixar', 'relation': 'created for', 'object': 'Toy Story', 'subject_type': 'company', 'object_type': 'film', 'qualifiers': [{'relation': 'point in time', 'object': '1995'}, {'relation': 'genre', 'object': 'computer-animated feature film'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Pixar', 'relation': 'notable work', 'object': 'List of Pixar films', 'subject_type': 'company', 'object_type': 'film series', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}]
# Filtered triplets:  []
# Refined triplets:  [{'subject': 'Steven Paul Jobs', 'relation': 'position held', 'object': 'CEO of Apple', 'subject_type': 'human', 'object_type': 'title of authority', 'qualifiers': [{'relation': 'start time', 'object': '1997'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Apple Inc.', 'relation': 'afterward owned by', 'object': 'NeXT', 'subject_type': 'enterprise', 'object_type': 'enterprise', 'qualifiers': [{'relation': 'point in time', 'object': '1997'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'employer', 'object': 'Apple Inc.', 'subject_type': 'human', 'object_type': 'company', 'qualifiers': [{'relation': 'position held', 'object': 'CEO'}, {'relation': 'start time', 'object': '1997'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'partner in business or sport', 'object': 'Jony Ive', 'subject_type': 'human', 'object_type': 'human', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'developer', 'object': 'Think different', 'subject_type': 'human', 'object_type': 'advertising campaign', 'qualifiers': [{'relation': 'instance of', 'object': 'advertising campaign'}], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'discoverer or inventor', 'object': 'iMac', 'subject_type': 'human', 'object_type': 'software', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'developer', 'object': 'iTunes', 'subject_type': 'human', 'object_type': 'software', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'discoverer or inventor', 'object': 'iMac', 'subject_type': 'human', 'object_type': 'operating system', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'developer', 'object': 'Apple Store', 'subject_type': 'human', 'object_type': 'shop', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'iPod', 'relation': 'developer', 'object': 'Steven Paul Jobs', 'subject_type': 'electronic device', 'object_type': 'human', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'developer', 'object': 'iTunes', 'subject_type': 'human', 'object_type': 'online music store', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'discoverer or inventor', 'object': 'iPhone', 'subject_type': 'human', 'object_type': 'smartphone', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'developer', 'object': 'App Store (iOS)', 'subject_type': 'human', 'object_type': 'online service', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'discoverer or inventor', 'object': 'iPad', 'subject_type': 'human', 'object_type': 'tablet computer', 'qualifiers': [], 'source_text_id': 0, 'prompt_token_nums': 0, 'completion_token_num': 0, 'sample_id': 'wiki-texts'}, {'subject': 'Steven Paul Jobs', 'relation': 'member of', 'object': 'Gap Inc.', 'subject_type': 'human', 'object_t ...
# Filtered triplets:  []

# %% [markdown]
# ## Neo4j

# %%
from neo4j import GraphDatabase

uri = "neo4j://localhost:7688"
# username = "neo4j"
# password = "12345678"
# driver = GraphDatabase.driver(uri, auth=(username, password))
driver = GraphDatabase.driver(uri)

# %%
def fetch_neo4j_triplets():
    with driver.session() as session:
        query = """
        MATCH (s)-[r]->(o)
        RETURN s.name AS subject, type(r) AS predicate, o.name AS object
        LIMIT 100
        """
        result = session.run(query)
        triplets = [(r["subject"], r["predicate"], r["object"]) for r in result]
    return triplets

fetch_neo4j_triplets()
# Out:
# [('Alla', 'lives_with', 'Roman'), ('Alla', 'lives_with', 'Roman')]

# %%
def find_any_node(tx):
    query = "MATCH (n) RETURN n LIMIT 1"
    result = tx.run(query)
    return result.single()[0] if result.peek() else None

def find_some_nodes(tx, limit=5):
    query = f"MATCH (n) RETURN n LIMIT {limit}"
    return [record["n"] for record in tx.run(query)]

with driver.session() as session:
    any_node = session.read_transaction(find_any_node)
    node_collection = session.read_transaction(find_some_nodes, 10)

    print("Any single node:")
    print(any_node)

    print("\nCollection of nodes:")
    for node in node_collection:
        print(node)

driver.close()
# Out:
# Any single node:
# <Node element_id='4:4500ff1a-3206-4fe1-9ee3-52b341586ea0:0' labels=frozenset({'Person'}) properties={'name': 'Alla'}>
#
# Collection of nodes:
# <Node element_id='4:4500ff1a-3206-4fe1-9ee3-52b341586ea0:0' labels=frozenset({'Person'}) properties={'name': 'Alla'}>
# <Node element_id='4:4500ff1a-3206-4fe1-9ee3-52b341586ea0:1' labels=frozenset({'Person'}) properties={'name': 'Alla'}>
# <Node element_id='4:4500ff1a-3206-4fe1-9ee3-52b341586ea0:2' labels=frozenset({'Person'}) properties={'name': 'Roman'}>
# /tmp/ipykernel_1664220/744417672.py:10: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session() as session:
# /tmp/ipykernel_1664220/744417672.py:11: DeprecationWarning: read_transaction has been renamed to execute_read
#   any_node = session.read_transaction(find_any_node)
# /tmp/ipykernel_1664220/744417672.py:12: DeprecationWarning: read_transaction has been renamed to execute_read
#   node_collection = session.read_transaction(find_some_nodes, 10)

# %%
def find_some_nodes(tx, limit=5):
    query = f"MATCH (n) RETURN n LIMIT {limit}"
    return [record["n"] for record in tx.run(query)]

# %%
def add_node(tx, name):
    tx.run("CREATE (n:Person {name: $name})", name=name)

with driver.session() as session:
    session.write_transaction(add_node, "Alla")
# Out:
# /tmp/ipykernel_1091987/3946427599.py:4: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session() as session:
# /tmp/ipykernel_1091987/3946427599.py:5: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(add_node, "Alla")

# %%
def get_triples(tx):
    tx.run(f"""
            MATCH (a)-[r]->(b)
            RETURN a, r, b
            """)
    

with driver.session() as session:
    print(session.execute_read(get_triples))
# Out:
# None
# /tmp/ipykernel_1664220/4046672432.py:8: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session() as session:

# %%
def add_relation(tx, head, tail, relation):
    query = f"""
        MATCH (a {{name: $head}}), (b {{name: $tail}})
        CREATE (a)-[r:{relation}]->(b)
        RETURN type(r)
        """
    result = tx.run(query, head=head, tail=tail)

with driver.session() as session:        
    session.write_transaction(add_relation, "DevOps", "Practice", "is")
    # session.write_transaction(add_node, "Practice")
# Out:
# /tmp/ipykernel_1700293/18095691.py:10: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(add_relation, "DevOps", "Practice", "is")

# %%
def add_node(tx, node_name):
    tx.run("CREATE (n:Node {name: $node_name})", node_name=node_name)

def add_relation(tx, head, tail, relation):
    query = f"""
        MATCH (a {{name: $head}}), (b {{name: $tail}})
        CREATE (a)-[r:{relation}]->(b)
        RETURN type(r)
        """
    result = tx.run(query, head=head, tail=tail)

def get_node(tx, name):
    result = tx.run("MATCH (n:Node {name: $name}) RETURN n.name AS name", name=name)
    return [record["name"] for record in result]


# for i, row in full_df.iterrows():
#     head = row['subject']
#     tail = row['object']
#     relation = "_".join(row['relation'].replace("-", "").replace(".", "").split())
#     # print(head, tail, relation)
#     with driver.session() as session:
#         if not session.read_transaction(get_node, head):
#             session.write_transaction(add_node, head)

#         if not session.read_transaction(get_node, tail):
#             session.write_transaction(add_node, tail)
            
#         session.write_transaction(add_relation, head, tail, relation)

# %%
def get_person(tx):
    
    result = tx.run("MATCH (subject:Node {name: $name1}) -[r:RELATION]-> (object:Node {name: $name2}) RETURN r.name as relation", name1="Steven Paul Jobs", name2="Next")
    
    return [rel["relation"] for rel in result]

with driver.session() as session:
    names = session.read_transaction(get_person)

names
# Out:
# /tmp/ipykernel_683353/1323360862.py:8: DeprecationWarning: read_transaction has been renamed to execute_read
#   names = session.read_transaction(get_person)
# []

# %%
def delete_all(tx):
    
    result = tx.run("MATCH (n) OPTIONAL MATCH (n)-[r]-() DELETE r, n")
    
    return result

with driver.session() as session:
    names = session.write_transaction(delete_all)
# Out:
# /tmp/ipykernel_705238/3144383912.py:8: DeprecationWarning: write_transaction has been renamed to execute_write
#   names = session.write_transaction(delete_all)

# %%
driver.close()

# %% [markdown]
# ## Post-analysis

# %%
import pandas as pd
from collections import defaultdict

df = pd.read_csv('full_triplets.csv', index_col=0)
df
# Out:
#                                               subject                relation  \
# 0                                    Steven Paul Jobs           date of birth
# 1                                    Steven Paul Jobs           date of death
# 2                                    Steven Paul Jobs  country of citizenship
# 3                                    Steven Paul Jobs              occupation
# 4                                    Steven Paul Jobs              occupation
# ..                                                ...                     ...
# 42  several other businesses and philanthropic ven...          specialized in
# 43  several other businesses and philanthropic ven...          specialized in
# 44  several other businesses and philanthropic ven...          specialized in
# 45  several other businesses and philanthropic ven...          specialized in
# 46  several other businesses and philanthropic ven...          specialized in
#
#                                     object
# 0                        February 24, 1955
# 1                          October 5, 2011
# 2                 United States of America
# 3                              Businessman
# 4                                 Inventor
# ..                                     ...
# 42                          Microprocessor
# 43  technology and pop culture conventions
# 44              technology in K–12 schools
# 45                 environmental practices
# 46                              satellites
#
# [291 rows x 3 columns]

# %%
df_instance_of = df[df['relation'] == 'instance of']

# %%
df[(df['subject'] == 'Apple II') & (df['relation'] != 'instance of')].relation.to_list()
# Out:
# ['specialized in', 'notable work', 'inception']

# %%
relation2head = defaultdict(set)
relation2tail = defaultdict(set)

for i, row in df_instance_of.iterrows():
    relations = df[(df['subject'] == row['subject']) & (df['relation'] != 'instance of')].relation.to_list()
    
    for rel in relations:
        relation2head[rel].add(row['object'])

    relations = df[(df['object'] == row['subject']) & (df['relation'] != 'instance of')].relation.to_list()
    
    for rel in relations:
        relation2tail[rel].add(row['object'])

# %%
relation2tail
# Out:
# defaultdict(set,
#             {'notable work': {'3D computer-animated feature film',
#               'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'desk lamp',
#               'market capitalization',
#               'microcomputer'},
#              'developed': {'Animation studio',
#               'Computer graphics division of Lucasfilm',
#               'RenderMan',
#               'Software',
#               'microcomputer',
#               'video game'},
#              'saw the commercial potential of': {'Graphical user interface',
#               'Mouse',
#               'microcomputer'},
#              'inception': {'Graphical user interface',
#               'advertising campaign',
#               'microcomputer'},
#              'has part': {'Graphical user interface', 'microcomputer'},
#              'influenced': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Graphical user interface',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'Software',
#               'Technology company',
#               'market capitalization',
#               'microcomputer'},
#              'succeeded': {'Graphical user interface', 'microcomputer'},
#              'founder of': {'Animation studio',
#               'Apple Inc.',
#               'Computer graphics division of Lucasfilm',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'Software',
#               'Technology company',
#               'market capitalization'},
#              'acquired': {'Animation studio',
#               'Computer graphics division of Lucasfilm',
#               'Software',
#               'Technology company'},
#              'specialized in': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'Software',
#               'Technology company',
#               'market capitalization'},
#              'occupation': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'Software',
#               'Technology company',
#               'market capitalization'},
#              'spun off as': {'Animation studio',
#               'Apple Inc.',
#               'Computer graphics division of Lucasfilm',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization'},
#              'funded': {'Animation studio',
#               'Computer graphics division of Lucasfilm'},
#              'majority shareholder of': {'Animation studio',
#               'Computer graphics division of Lucasfilm'},
#              'mascot of': {'Animation studio',
#               'Computer graphics division of Lucasfilm'},
#              'developer': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization'},
#              'departed from': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization'},
#              'returned to': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization'},
#              'participant': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization'}})

# %%
relation2head
# Out:
# defaultdict(set,
#             {'specialized in': {'Animation studio',
#               'Apple Inc.',
#               'Computer graphics division of Lucasfilm',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'Software',
#               'Technology company',
#               'market capitalization',
#               'microcomputer'},
#              'notable work': {'Animation studio',
#               'Apple Inc.',
#               'Computer graphics division of Lucasfilm',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization',
#               'microcomputer'},
#              'inception': {'Animation studio',
#               'Apple Inc.',
#               'Computer graphics division of Lucasfilm',
#               'Computers for higher-education and business markets',
#               'Graphical user interface',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'Software',
#               'Technology company',
#               'market capitalization',
#               'microcomputer'},
#              'point in time': {'3D computer-animated feature film',
#               'Graphical user interface',
#               'microcomputer'},
#              'developer': {'Graphical user interface',
#               'Laser printer',
#               'microcomputer'},
#              'influenced': {'Graphical user interface', 'microcomputer'},
#              'has part': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Graphical user interface',
#               'Laser printer',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization',
#               'microcomputer'},
#              'country of citizenship': {'Animation studio',
#               'Apple Inc.',
#               'Computer graphics division of Lucasfilm',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'Software',
#               'Technology company',
#               'market capitalization'},
#              'headquarters location': {'Animation studio',
#               'Apple Inc.',
#               'Computer graphics division of Lucasfilm',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'Software',
#               'Technology company',
#               'market capitalization'},
#              'number of units sold': {'Software',
#               'Technology company',
#               'microcomputer'},
#              'business partner': {'Software', 'Technology company'},
#              'developed': {'Animation studio',
#               'Computer graphics division of Lucasfilm',
#               'RenderMan',
#               'Software',
#               'Technology company'},
#              'departed from': {'Software', 'Technology company'},
#              'founder of': {'Animation studio',
#               'Apple Inc.',
#               'Computer graphics division of Lucasfilm',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization'},
#              'acquired': {'Animation studio',
#               'Apple Inc.',
#               'Computer graphics division of Lucasfilm',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization'},
#              'division of': {'Animation studio',
#               'Computer graphics division of Lucasfilm'},
#              'spun off as': {'Animation studio',
#               'Computer graphics division of Lucasfilm'},
#              'revenue': {'Animation studio',
#               'Apple Inc.',
#               'Computer graphics division of Lucasfilm',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization'},
#              'award received': {'Animation studio',
#               'Computer graphics division of Lucasfilm'},
#              'state': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization'},
#              'lost market share to': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization'},
#              'largest manufacturing company by': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization'},
#              'largest vendor of': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization'},
#              'market capitalization': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization'},
#              'has': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization'},
#              'received criticism regarding': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'Software',
#               'market capitalization'},
#              'cost': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization',
#               'microcomputer'},
#              'shares issued': {'Apple Inc.',
#               'Computers for higher-education and business markets',
#               'Multinational corporation',
#               "One of the world's most valuable brands",
#               'market capitalization'},
#              'hosted on': {'Software'},
#              'combined with': {'Software'},
#              'mascot of': {'desk lamp'}})

# %%
df_instance_of
# Out:
#               subject     relation  \
# 26           Apple II  instance of
# 29         Xerox Alto  instance of
# 30         Xerox Alto  instance of
# 31         Xerox Alto  instance of
# 33         Apple Lisa  instance of
# 36          Macintosh  instance of
# 38          Macintosh  instance of
# 42    Aldus Pagemaker  instance of
# 43  Apple LaserWriter  instance of
# 50               NeXT  instance of
# 55          Toy Story  instance of
# 56              Pixar  instance of
# 68    Think different  instance of
# 0          Apple Inc.  instance of
# 14         Apple Inc.  instance of
# 16            Apple I  instance of
# 22               Lisa  instance of
# 24               Lisa  instance of
# 59         Apple Inc.  instance of
# 61         Apple Inc.  instance of
# 64         Apple Inc.  instance of
# 0                NeXT  instance of
# 20           OpenStep  instance of
# 25  OPENSTEP for Mach  instance of
# 27         WebObjects  instance of
# 43               Doom  instance of
# 44              Quake  instance of
# 10              Pixar  instance of
# 23          RenderMan  instance of
# 25           Luxo Jr.  instance of
# 0   Personal computer  instance of
#
#                                                object
# 26                                      microcomputer
# 29                                      microcomputer
# 30                                              Mouse
# 31                           Graphical user interface
# 33                                      microcomputer
# 36                                      microcomputer
# 38                           Graphical user interface
# 42                                           Software
# 43                                      Laser printer
# 50                                           Software
# 55                  3D computer-animated feature film
# 56                                   Animation studio
# 68                               advertising campaign
# 0                           Multinational corporation
# 14                                         Apple Inc.
# 16                                      microcomputer
# 22                                      microcomputer
# 24                           Graphical user interface
# 59            One of the world's most valuable brands
# 61  Computers for higher-education and business ma...
# 64                              market capitalization
# 0                                  Technology company
# 20                                           Software
# 25                                           OpenStep
# 27                                           Software
# 43                                         video game
# 44                                         video game
# 10            Computer graphics division of Lucasfilm
# 23                                          RenderMan
# 25                                          desk lamp
# 0                                       microcomputer
