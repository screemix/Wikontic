# %%
import json
from collections import Counter

from SPARQLWrapper import SPARQLWrapper, JSON
import time
import re

from tqdm import tqdm

# from transformers import AutoTokenizer, AutoModel
# import numpy as np
# from langdetect import detect

# import faiss
from tenacity import retry, wait_random_exponential, before_sleep_log

# %%
ONTOLOGY_MAPPINGS_DIR = "../utils/ontology_mappings/"

# %% [markdown]
# ## Collecting relation names and constraints

# %% [markdown]
# ### Collecting labels and data types of relations

# %%
PROP_2_LABEL = {}
PROP_2_DATA_TYPE = {}

sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

# SPARQL query for properties with data types: Item, Quantity, Point in time
query = """
SELECT ?property ?propertyLabel ?typeLabel WHERE {
  # ?property a wikibase:Property .
  # ?property wikibase:propertyType ?type .
  
  VALUES ?type { wikibase:WikibaseItem wikibase:Quantity wikibase:Time }
  
  BIND(
    IF(?type = wikibase:WikibaseItem, "Item",
      IF(?type = wikibase:Quantity, "Quantity",
        IF(?type = wikibase:Time, "Point in time", "Unknown")
      )
    ) AS ?typeLabel
  )
  
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
"""

sparql.setQuery(query)
sparql.setReturnFormat(JSON)

try:
    results = sparql.query().convert()

    for result in results["results"]["bindings"]:
        prop = result["property"]["value"].split("/")[-1]
        label = result.get("propertyLabel", {}).get("value", "No label")
        data_type = result.get("typeLabel", {}).get("value", "Unknown")

        PROP_2_LABEL[prop] = label
        PROP_2_DATA_TYPE[prop] = data_type

except Exception as e:
    print(f"Error executing SPARQL query: {e}")

# %%
len(PROP_2_LABEL), len(PROP_2_DATA_TYPE)
# Out:
# (2479, 2479)

# %%
set(PROP_2_DATA_TYPE.values())
# Out:
# {'Item', 'Point in time', 'Quantity'}

# %%
ONTOLOGY_MAPPINGS_DIR = "../src/wikontic/utils/ontology_mappings/"
with open(ONTOLOGY_MAPPINGS_DIR + "prop2data_type.json", "w") as f:
    json.dump(PROP_2_DATA_TYPE, f)

# %%
with open(ONTOLOGY_MAPPINGS_DIR + "prop2label.json", "w") as f:
    json.dump(PROP_2_LABEL, f)

# %% [markdown]
# ### Collecting relation aliases

# %%
len(set(PROP_2_LABEL.keys())), len(set(PROP_2_LABEL.values()))
# Out:
# (2479, 2479)

# %%
@retry(wait=wait_random_exponential(multiplier=1, max=60))
def get_property_aliases(property_id):
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

    query = f"""
    SELECT ?alias WHERE {{
      wd:{property_id} skos:altLabel ?alias .
      FILTER (lang(?alias) = "en")
    }}
    """

    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    aliases = [result["alias"]["value"] for result in results["results"]["bindings"]]
    return aliases


PROP2ALIASES = {}

for property_id in tqdm(PROP_2_LABEL.keys()):
    PROP2ALIASES[property_id] = get_property_aliases(property_id)
# Out:
# 100%|██████████| 2479/2479 [20:23<00:00,  2.03it/s]

# %%
alias_set = set()
alias_list = []
for prop, aliases in PROP2ALIASES.items():
    alias_set.update(aliases)
    alias_list.extend(aliases)
print(len(alias_set), len(alias_list))
# Out:
# 8612 9230

# %%
for prop in PROP_2_LABEL:
    print(PROP_2_LABEL[prop], PROP2ALIASES[prop])
# Out:
# height ['size', 'depth over terrain', 'heighth']
# width ['size', 'breadth', 'bus width']
# wingspan []
# M sin i ['M ⋅ sin i', 'M x sin i']
# speed ['velocity']
# watershed area ['basin area', 'catchment basin size', 'drainage basin size', 'size of watershed']
# density ['specific gravity']
# electrical conductivity []
# specific heat capacity ['heat capacity', 'specific heat', 'thermal capacity']
# luminosity []
# molar fusion enthalpy ['fusion enthalpy']
# mass ['weight', 'displacement', 'molecular mass', 'molecular weight']
# thermal conductivity []
# magnetic moment []
# vehicle range ['range', 'maximum range', 'operational range']
# speed of sound ['sound speed']
# temperature []
# under pressure []
# term length of position ['length of term', 'position term', 'term length', 'term of position', 'time in position']
# melting point ['freezing point']
# boiling point []
# size of team at start []
# size of team at finish ['size of team at the end']
# decomposition point []
# nominal power output ['capacity', 'generating capacity', 'installed capacity', 'nameplate capacity', 'nominal power', 'nominal power capacity', 'power capacity', 'power output', 'rated power']
# wing area []
# sublimation temperature ['sublimation point']
# half-life []
# molar enthalpy of vaporization ['enthalpy of vaporization', 'heat of evaporation', 'heat of vaporization', 'latent heat of vaporization', 'molar enthalpy of vaporisation', 'vaporisation enthalpy', 'vaporization enthalpy']
# combustion enthalpy []
# kinematic viscosity []
# vapor pressure ['vapour pressure']
# radius []
# prize money ['money', 'value', 'purse']
# member count ['membership', 'number of members', 'amount of members', 'count of members', 'total members']
# flash point []
# immediately dangerous to life or health []
# capital cost ['cost', 'budget', 'unit cost', 'CAPEX']
# nominal GDP ['GDP', 'gross domestic product', 'GDP, nominal', 'nominal GDP', 'nominal gross domestic product']
# nominal GDP per capita ['GDP (nominal) per capita', 'gdp per capita', 'GDP per capita, nominal', 'Gross domestic product per capita']
# total debt ['debt']
# total reserves []
# total exports ['exports', 'export volume']
# total imports ['imports', 'import volume']
# total equity ['equity', 'shareholder equity']
# total liabilities ['liabilities']
# total revenue ['turnover', 'income', 'revenue', 'sales', 'gross revenue', 'net sales']
# foreign direct investment net outflow ['foreign direct investment outflow']
# foreign direct investment net inflow ['FDI, net inflows', 'foreign direct investment inflow']
# box office ['earnings']
# genome size []
# frequency []
# explosive energy equivalent ['yield', 'explosive yield']
# orbital period ['revolution period', 'sidereal period']
# rotation period []
# distance from river mouth ['river kilometer', 'river kilometre', 'river mile']
# clock frequency ['clock rate', 'clock speed', 'CPU clock', 'CPU clock rate']
# FSB speed ['bus speed', 'front-side bus speed']
# focal length ['focal distance']
# binding energy []
# mass excess []
# solubility []
# count of students ['number of pupils', 'enrollment', 'count of pupils', 'count of students', 'number of pupils or students', 'number of students', 'pupils count', 'student count']
# production rate ['production volume', 'rate of production']
# average gradient ['gradient']
# autoignition temperature ['kindling point', 'self-ignition temperature', 'spontaneous ignition temperature']
# electric charge ['charge']
# electric dipole moment ['dipole moment']
# lower flammable limit []
# upper flammable limit ['UEL', 'UFL', 'upper explosive limit']
# minimum explosive concentration []
# average shot length ['ASL']
# position angle ['angular position', 'PA']
# angular distance ['angle']
# longitude of ascending node ['longitude of the ascending node']
# parallax ['astronomical parallax']
# radial velocity []
# cruise speed ['cruising speed', 'maximum cruise speed', 'maximum cruising speed', 'normal operating speed', 'sustained speed', 'VNO']
# net worth ['wealth', 'declared patrimony', 'estimated net worth', 'net wealth', 'net worth estimate', 'personal assets', 'personal fortune']
# real GDP growth rate ['real gross domestic product growth rate']
# household wealth []
# flux []
# gyromagnetic ratio []
# decay width []
# discharge []
# market capitalization ['market cap', 'market capitalisation']
# metallicity []
# maximum thrust ['thrust']
# thermal design power ['TDP', 'Thermal Design Parameter', 'thermal design point']
# torque ['moment', 'moment of force']
# explosive velocity ['detonation velocity', 'velocity of detonation', 'VoD']
# cash []
# semi-major axis of an orbit ['major semi-axis of an orbit', 'major semiaxis of an orbit', 'orbital semi-major axis', 'semi major axis', 'semimajor axis of an orbit']
# volume as quantity ['tonnage', 'fluid capacity', 'liquid capacity', 'quantity as volume', 'spatial volume', 'vaq', 'volume (geometry)']
# median lethal dose (LD50) ['LD50', 'LD₅₀']
# apoapsis ['apogee', 'aphelion', 'apapsis']
# periapsis ['perigee', 'perihelion']
# argument of periapsis ['argument of periastron', 'argument of pericenter', 'argument of perifocus', 'argument of perigee', 'argument of perihelion', 'ω']
# life expectancy ['lifespan', 'life span']
# maximum operating altitude ['ceiling', 'maximum altitude', 'service ceiling']
# Human Development Index ['HDI']
# population ['inhabitants', 'human population']
# maximum capacity ['crew', 'capacity', 'seats', 'complement', 'number of seats', 'seating capacity']
# atomic number ['Z', 'atom number', 'number of protons', 'proton number']
# Elo rating ['classical chess Elo rating']
# Mohs' hardness ['hardness', 'hardness of mineral', 'mineral hardness', 'Mohs hardness']
# redshift ['Z', 'z']
# total produced ['circulation', 'number built', 'number made', 'number produced', 'production quantity', 'qty built', 'qty made', 'qty produced', 'quantity issued', 'total built', 'total made']
# gross tonnage ['GRT', 'GT', 'ship gross tonnage', 'tonnage gross']
# orbital eccentricity ['eccentricity']
# g-factor []
# number of speakers, writers, or signers ['signers of a language', 'speakers of language', 'writers of a language']
# number of masts []
# number of cylinders []
# floors above ground ['stories', 'floor count', 'levels above ground', 'number of floors', 'number of stories', 'storeys']
# flattening ['ellipticity', 'oblateness']
# number of platform tracks ['Tracks', 'platform tracks']
# number of pages ['column count', 'number of columns', 'leaves', 'pages', 'pagination', 'foliation', 'leaf count', 'number of leaves', 'numpages', 'page count']
# Sandbox-Quantity []
# proportion ['part', 'ratio', 'share', 'percent', '%']
# electronegativity []
# refractive index ['index of refraction', 'IOR']
# attendance ['spectators']
# votes received ['popular vote']
# number of episodes ['episodes', 'episode count', 'no. of episodes', 'series length']
# quantity ['number', 'count', 'total', 'amount', 'instances', 'multiplicity', 'occurrences', 'copies', 'number of copies', 'number of instances', 'number of occurrencies', 'qty', 'total number']
# pKa ['acid dissociation constant']
# number of deaths ['dead', 'fatalities', 'deaths', 'death count', 'death number', 'death toll', 'number of fatalities', 'qty deaths', 'qty fatalities']
# oxidation state ['has oxidation state', 'in oxidation state', 'oxidation number']
# spin quantum number ['spin', 'spin (physics)', 'spin (quantum mechanics)']
# parity quantum number ['parity']
# Gini coefficient []
# isospin quantum number []
# isospin z-component []
# employees ['staff', 'workers', 'personnel', 'employee count', 'number of employees', 'number of staff']
# national team appearances ['national team caps']
# number of participants ['participants', 'number of competitors', 'number of teams', 'participant count', 'qty participants']
# floors below ground ['basement floors', 'floors below ground', 'levels below ground', 'underground floors']
# number of processor cores ['cores', 'core count', 'CPU cores', 'number of cores', 'number of CPU cores', 'processor cores']
# neutron number ['neutron count', 'number of neutrons']
# group cardinality ['cardinality of the group', 'group order', 'group size']
# visitors per year ['annual visitors', 'yearly visitors']
# numeric value ['value', 'numerical value']
# prevalence []
# unemployment rate []
# apparent magnitude []
# compression ratio []
# inflation rate ['consumer price index inflation rate', 'CPI inflation rate', 'inflation rate of consumer price index']
# emissivity []
# number of elevators ['elevators', 'lifts', '# of elevators', '# of lifts']
# number of spans ['spans', 'number of arches of a bridge', 'span count']
# number of injured ['wounded', 'injured', 'injuries', 'injury toll', 'non-fatal injuries', 'number injured']
# number of seats ['membership quantity', 'number of seats (members)', 'quantity of members', 'seats (members)']
# number of victims of killer ['kills', 'homicides', 'enemy kills', 'kill count', 'number of deaths by the killer', 'number of homicide victims', 'number of killed persons', 'number of persons killed']
# number of matches played/races/starts ['starts', 'races', 'appearances', 'caps', 'games pitched', 'games played', 'gp', 'matches played', 'mp', 'number of games played']
# number of points/goals/set scored ['GF', 'goals for', 'goals scored', 'number of goals', 'number of points', 'points scored', 'score for']
# ranking ['place', 'position', 'rank', 'placing', 'peak position']
# number of wins ['wins', 'won', 'W', 'victories', 'games won', 'match victories', 'matches won', 'sporting wins']
# number of losses ['lost', 'L', 'losses', 'defeats', 'games lost', 'match losses', 'matches lost', 'matches lost/games lost']
# number of draws/ties ['drawn', 'tied', 'D', 'T']
# points for ['points', 'PTS', 'championship points', 'competition points', 'league points', 'pf']
# number of points/goals conceded ['GA', 'goals against']
# daily patronage ['daily ridership']
# match time of event ['match time of event (minute)', 'time of event in match']
# number of seats in assembly ['seats', 'number of seats', 'number of delegates', 'number of representatives']
# orbits completed []
# collection or exhibition size ['collection size', 'exhibition size', 'number of objects', 'number of records', 'size of collection', 'size of exhibition']
# number of missing ['missing', 'number missing', 'number of disappearance', 'number of missing people', 'people missing']
# absolute magnitude []
# color index []
# maximum glide ratio ['best L/D-ratio', 'best lift/drag ratio']
# number of households ['dwellings', 'households']
# female population []
# male population ['male inhabitants', 'number of males']
# maximum Strahler number []
# number of survivors ['survivors']
# number of casualties ['casualities', 'number of deaths and injuries']
# number of cases ['case number', 'cases reported', 'infections reported', 'number infected', 'number of infections', 'number of occurrences', 'occurrences reported', 'total number of cases']
# port ['Internet port', 'network port', 'port number']
# Alexa rank []
# number confirmed []
# number probable ['number of probable cases']
# number suspected []
# central government debt as a percent of GDP []
# total valid votes ['formal votes', 'valid votes']
# beats per minute ['bpm', 'tempo', 'musical tempo', 'BPM', 'metronome mark']
# scale ['scale ratio']
# electorate []
# number of registered users/contributors ['users', 'number of contributors', 'number of registered users', 'number of users']
# eligible voters ['registered voters', 'total voters', 'voters eligible', 'registered electors']
# ballots cast ['turnout', 'total vote count', 'total votes', 'votes cast']
# minimum number of players ['minimum players', 'number of players, minimum', 'players, minimum number']
# maximum number of players ['max players', 'maximum players', 'number of players, maximum', 'players max', 'players, maximum number']
# number of children ['issue', 'children', 'kids', 'children (number)', 'how many children', 'no of children', 'no. of children', 'number of kids', 'number of offspring']
# Erdős number ['Erdos number']
# length ['distance', 'long', 'size', 'dimension', 'length overall', 'LOA']
# elevation above sea level ['altitude', 'height', 'elevation', 'AMSL', 'EASL', 'elevation above mean sea level', 'MAMSL', 'MASL']
# orbital inclination ['inclination']
# area ['surface', 'resolution', 'size', 'surface area', 'acreage', 'image resolution', 'camera resolution', 'die area', 'die size', 'photo resolution', 'total area']
# duration ['cooking time', 'era', 'interval', 'length', 'period', 'time interval', 'length of time', 'cook time', 'run time', 'running length', 'running time', 'runtime', 'time length', 'time span', 'timespan']
# service life []
# boiler pressure []
# coastline ['coastal line', 'sea shoreline']
# vehicles per thousand people ['motorization rate']
# stroke count ['number of strokes']
# chromosome count ['2n chromosome count', 'chromosome count (2n)', 'diploid chromosome count']
# residual stroke count []
# angular diameter ['angular size', 'apparent diameter', 'apparent size']
# laps completed []
# position of accent nucleus ['accent nucleus', 'accent number']
# position of devoiced vowel ['devoiced vowel']
# number of viewers/listeners ['views', 'watches', 'plays', 'listeners', 'listens', 'viewers', 'listen count', 'listener count', 'listener number', 'number of listeners', 'number of listens', 'number of plays', 'number of viewers', 'number of views', 'number of watches', 'play count', 'TV ratings', 'view count', 'view number', 'viewer count', 'viewer number', 'viewing figures', 'watch count']
# lower limit ['minimum', 'minimum value', 'lower bound', 'smallest value']
# upper limit ['maximum', 'maximum value', 'greatest value', 'upper bound']
# section number ['heat', 'section', 'flight', 'flight number', 'heat number', 'stage series ordinal']
# ultimate tensile strength ['Ftu', 'Rm', 'stress at break', 'Tensile strength', 'TS', 'UTS']
# tensile modulus of elasticity ['E', 'elastic modulus', 'elasticity modulus', 'tensile modulus', "Young's modulus"]
# position of nasal sonant []
# hardness []
# toughness ['impact', 'choc', 'Charpy', 'impact resistance', 'impact strengh', 'Izod']
# horizontal depth ['depth', 'thickness', 'spatial depth']
# valency ['verbal valency']
# yield strength ['yield point', 'yield stress']
# coefficient of friction []
# number of arrests ['arrests', 'arrest count']
# number of works accessible online []
# Poisson's ratio []
# moisture absorption ['humidity absorption', 'water absorption']
# number of platform faces ['platforms', 'number of platforms', 'platform faces']
# relative humidity []
# fatigue limit []
# pitting resistance equivalent number ['P.R.E.N.', 'pitting corrosion number', 'PREn', 'PREN', 'stainless steel corrosion number']
# prisoner count ['inmates', 'prisioners']
# bulk modulus []
# compressive strength ['compression strength', 'ultimate compressive strengh', 'ρe']
# glass transition temperature ['glass-transition temperature', 'glass–liquid transition temperature', 'Tg']
# linear thermal expansion coefficient ['linear expansion coefficient']
# shear modulus []
# thermal diffusivity ['α']
# relative permittivity []
# relative permeability []
# flexural strength ['flexural strength at yield', 'flexural yield strength', 'modulus of rupture']
# dissipation factor []
# electrical resistivity ['resistivity', 'electrical resistivity and conductivity', 'specific resistance']
# flexural modulus []
# heat deflection temperature ['DTUL', 'HDT', 'HDTUL', 'heat distortion temperature']
# tear resistance []
# shear strength []
# force []
# abrasion resistance ['resistance to abrasion']
# elongation at break ['A%', 'Strain at break', 'Tensile strain', 'Z%']
# admission rate ['acceptance rate']
# work hardening strain []
# tuition fee []
# foreign transaction fee ['FX fee']
# trading fee ['brokerage commission', 'brokerage fee', 'maker fee', 'taker fee']
# account charge / subscription fee ['fee', 'annual cost', 'member fee', 'membership fee', 'monthly cost', 'reoccuring fee', 'subscription cost']
# borrowing rate ['annual percentage rate (APR)', 'debit interest rate']
# interest rate []
# JMA Magnitude []
# limiting oxygen index []
# Vicat softening point []
# annual number of weddings []
# carbon footprint ['footprint', 'carbon emissions', 'carbon impact', 'embodied carbon', 'emissions equivalent', 'greenhouse gas footprint']
# attenuation coefficient []
# compressive modulus of elasticity []
# water footprint ['footprint']
# flexural strain at break []
# INEP IGC continuous score []
# permeability []
# embodied energy []
# biobased content weight percentage []
# beer bitterness ['IBU']
# beer color []
# number of volunteers ['volunteers']
# narrative age ['age in fiction', 'age in story', 'ingame age', 'narrative age', 'specific age inside fictional universe', 'years old in-universe']
# right ascension ['Longitude of Ascending Node']
# declination []
# galactic longitude []
# galactic latitude []
# specific rotation []
# concentration ['strength']
# urban population []
# rural population []
# closest approach []
# Euler characteristic []
# drag coefficient []
# illiterate population []
# literate population []
# total goals in career []
# stall speed []
# total shots in career []
# total points in career []
# total assists in career []
# penalty minutes in career ['PIMS in career']
# career plus-minus rating []
# number of words ['word count', 'words (number of)']
# endowment ['financial endowment']
# highest break ['highest break (snooker)']
# maximum temperature record ['highest temperature']
# event interval ['interval', 'period', 'event frequency', 'frequency of event']
# ionization energy ['IP', 'IE', 'ionisation energy', 'ionisation potential', 'ionization potential']
# beam ['width', 'breadth', 'BOA']
# draft ['draught']
# price ['cost', 'value', 'exchange rate', 'purchase price', 'list price', 'MSRP', 'published price', 'sold for']
# consumption rate ['consumption', 'rate of consumption']
# balance of trade ['net exports']
# net profit ['profit', 'bottom line', 'clear gain', 'clear profit', 'net earnings', 'net income', 'net return']
# money supply ['money stock']
# employment by economic sector ['employment by industry', 'employment by sector']
# PPP GDP per capita ['GDP (PPP) per capita', 'GDP per capita based on purchasing power parity', 'GDP per capita, PPP', 'gross domestic product (at purchasing power parity) per capita']
# minimal lethal dose ['LDLo']
# maximum value ['to', 'up to', 'max quantity', 'max value', 'at most this many', 'maximum quantity']
# minimum value ['from', 'at least this many', 'min quantity', 'min value', 'minimum quantity']
# aftershocks ['number of aftershocks', 'quantity of aftershocks']
# quantity buried ['burials', 'graves', 'number of burials', 'number of people buried']
# mean anomaly []
# number of graves ['capacity cemetery', 'total number of graves']
# time to altitude ['time to climb']
# conversion to SI unit ['conversion to coherent SI unit', 'conversion to SI base unit', 'SI unit equivalent']
# natural abundance ['relative abundance']
# diameter ['diametre']
# total expenditure ['expenses', 'expense', 'spending']
# total assets ['assets', 'balance sheet total']
# time-weighted average exposure limit ['TWAEL']
# ceiling exposure limit []
# maximum peak exposure limit []
# short-term exposure limit ['Short term limited']
# personal best ['record', 'PR', 'PB', 'personal record']
# takeoff roll []
# voltage ['electric potential difference', 'electric pressure', 'electric tension', 'electromotive force', 'potential difference']
# number of seasons ['seasons', 'no. of seasons', 'no. of series', 'number of series']
# conversion to standard unit ['unit conversion']
# earthquake magnitude on the moment magnitude scale ['magnitude', 'earthquake magnitude', 'magnitude of an earthquake', 'moment magnitude scale value', 'Mw']
# earthquake magnitude on the Richter magnitude scale ['magnitude', 'ML', 'earthquake magnitude', 'magnitude of an earthquake', 'Richter scale value']
# lowest atmospheric pressure ['lowest pressure']
# acceptable daily intake ['ADI']
# perimeter ['circumference', 'coastline', 'boundary length']
# fee ['charge', 'fine', 'toll', 'fare', 'admission', 'entrance fee', 'entrance fees', 'entry fee', 'onetime fee']
# bore []
# stroke []
# global warming potential ['global warming potential', 'greenhouse warming potential', 'GWP']
# number of out-of-school children []
# distance from Earth ['angular diameter distance', 'comoving distance', 'light-travel distance', 'light-year distance', 'luminosity distance', 'parsec distance', 'proper distance']
# maximum gradient ['max gradient', 'max slop', 'maximum incline', 'maximum slope', 'ruling grade']
# block size ['block length']
# thickness ['cast thickness', 'wall thickness']
# cost of damage ['damage', 'amount of damage', 'value of damage']
# number of parts of this work ['volumes', 'acts count', 'acts number', 'acts quantity', 'amount of parts of this work', 'chapter count', 'chapters quantity', 'component count', 'composed of x acts', 'composed of x parts', 'comprises x acts', 'comprises x parts', 'consists of x acts', 'consists of x parts', 'contains x acts', 'movement count', 'movements quantity', 'number of acts', 'number of chapters', 'number of issues', 'number of movements', 'number of parts of this work of art', 'number of pictures', 'number of scenes', 'number of segments of anthology film', 'number of songs', 'number of stanzas', 'number of tracks', 'number of tracks on release', 'number of volumes', 'picture count', 'pictures quantity', 'stanza count', 'stanzas quantity', 'track count', 'tracks quantity']
# mean lifetime []
# Scoville grade ['Scoville heat units', 'Scoville rating', 'Scoville scale', 'SHU']
# topographic isolation ['isolation']
# topographic prominence ['prominence']
# target interest rate []
# consumption rate per capita []
# common equity tier 1 capital ratio (CETI) ['CET1', 'CET1-ratio', 'CETI']
# units sold ['sales', 'number of sales', 'sales figures', 'total sales']
# alcohol by volume ['alcohol', 'Alc. vol.']
# minimal lethal concentration ['LCLo', 'lowest lethal concentration']
# median lethal concentration (LC50) ['LC50', 'LC₅₀']
# no-observed-adverse-effect level ['NOAEL']
# lowest-observed-adverse-effect level ['LOAEL']
# budget []
# race time []
# longest span ['length of longest span', 'length of main span', 'longest span length', 'main span', 'main span length', 'span length (longest)', 'span length (main)']
# net tonnage []
# power consumed ['TDP', 'power consumption', 'thermal design power']
# clearance ['height', 'air draft', 'air draught', 'bridge height', 'clearance below', 'deck height', 'height above ground', 'height above valley floor', 'height above water', 'height of deck bottom', 'span height']
# sound power level []
# Wikidata time precision ['timePrecision in Wikibase']
# vibration []
# molar volume []
# wavelength []
# individual tax rate ['tax rate for individuals']
# lowest income threshold []
# highest income threshold []
# incidence []
# disease burden []
# VAT rate ['VAT', 'goods and services tax rate', 'GST', 'sales tax', 'tax rate for sales', 'taxation rate for sales', 'value-added tax rate']
# time in space ['logged space hours', 'space exposure']
# mains voltage ['mains electricity voltage']
# maximum sustained winds ['wind speed', 'highest sustained winds', 'highest wind speed', 'maximum wind speed', 'strongest sustained winds', 'sustained winds']
# publication interval ['frequency of publication', 'interval of publication', 'publication cycle', 'publication frequency', 'update frequency']
# minimum age ['age restriction', 'min age', 'youngest allowed']
# UTC timezone offset ['offset from UTC', 'UTC offset of timezone']
# time gap ['gap']
# focal height ['height of focal plane']
# water as percent of area ['H₂O%', 'percent of area that is water']
# storage capacity ['HD capacity', 'HD size', 'memory storage capacity']
# lighthouse range ['range of lighthouse light']
# point of penalty ['penalty points']
# throughput ['rate', 'capacity', 'transmission rate']
# partition coefficient water/octanol ['LogKow']
# age of majority []
# age of candidacy ['minimum age of candidacy']
# age of consent ['consent age']
# marriageable age ['marriage age', 'minimum age for marriage']
# retirement age []
# surface tension []
# residence time of water ['lake residence time', 'lake retention time', 'retention time', 'water residence time', 'water retention time']
# EIRIN film rating ['EIRIN film rating category']
# CNC film rating (France) ['CNC film rating', 'CNC movie rating', 'CNC rating', 'Commission de classification des œuvres cinématographiques film rating', 'film classification category (CNC)']
# source of income ['income source', 'revenue source', 'source of revenue']
# modified Mercalli intensity scale []
# connects with ['contacts', 'links to', 'affixed to', 'attached to', 'attaches to', 'binds to', 'connected to', 'connected with', 'connects to', 'couples with', 'intersects at grade', 'mates with', 'meets at grade']
# house publication ['mouthpiece', 'publishes', 'publication', 'manifest', 'has mouthpiece', 'house journal', 'house magazine', 'house organ', 'house periodical', 'mouth piece', 'official gazette', 'official media', 'official newspaper', 'official publication', 'official publication of', 'organisation publication', 'organization publication']
# appears in the heritage monument list []
# set cardinality ['cardinality of this set', 'number of elements', 'cardinality of set', 'size of set', 'size of this set']
# by-product ['byproduct', 'has by-product', 'has byproduct', 'produces by-product', 'secondary product', 'yields by-product']
# by-product of ['byproduct of']
# via ['stopover', 'waystation', 'called at', 'calling at', 'calling point', 'intermediate point', 'journey stopover', 'journey via', 'route via', 'routing point']
# flower color ['bloom color', 'bloom colour', 'blossom color', 'blossom colour', 'color of the flower', 'colour of the flower', 'flower colour', 'floral color', 'floral colour']
# corporate officer ['executive officer']
# totem []
# professional name []
# gait []
# age of onset []
# place of marriage ['location of marriage', 'marriage location', 'married at', 'married in', 'wed at', 'wedding location']
# disabled accessibility ['ADA', 'accessibility for people with visual disabilities', 'accessibility for wheelchair users', 'easy access', 'step-free access', 'wheelchair accessibility']
# Wi-Fi access ['wifi', 'Wi-Fi', 'internet access', 'wifi access', 'WLAN', 'WLAN access']
# produced by ['product of', 'secreted by', 'secretion of']
# payment types accepted ['accepted payment methods', 'credit cards accepted', 'payment methods accepted']
# emergency phone number ['emergency telephone number']
# electrical plug type ['electrical connector type', 'electrical socket type', 'mains connector', 'mains plug type', 'mains socket type', 'plug type', 'socket type']
# cites work ['citation', 'references', 'bibliographic citation', 'works cited']
# subject has role ['role', 'has role', 'subject had role', 'subject of qualified statement has role', 'subject of statement has role', 'subject role']
# record or record progression ['olympic record', 'world record']
# visitor center ['tourist office', 'contact station', 'visitor centre']
# property usage tracking category ['property tracked (inverse of)']
# type of unit for this property []
# promoted ['promotion', 'competitor promoted', 'player promoted', 'team promoted']
# relegated ['relegation', 'competitor relegated', 'player relegated', 'team relegated']
# day of week ['day of the week', 'days of week']
# distinctive jersey ['jersey']
# month of the year ['month', 'month of year']
# domain of saint or deity ['saint of', 'deity of', 'angel of', 'divine patron', 'domain of deity or saint', 'god of', 'goddess of', 'guardian of', 'is patron saint of', 'patron of', 'patron saint of', 'sacred domain', 'saint or deity domain']
# connector ['port', 'ports', 'electrical connector', 'has connector']
# language used ['working language', 'languages used', 'medium of instruction', 'used language', 'uses language', 'working languages']
# parliamentary term ['legislative term', 'legislative session']
# permanent duplicated item ['same as', 'duplicate', 'duplicate item', 'duplicate of', 'duplicate of item', 'identical to', 'permanently duplicated item', 'same concept as']
# title of chess person ['chess title']
# right to vote ['suffrage']
# habitat []
# has host ['host taxon']
# patronym or matronym for this name ['patronym', 'matronym', 'parentonym for this name', 'parentonymic for this name']
# wheel arrangement []
# has grammatical case ['cases', 'has case']
# software quality assurance ['QA', 'Software QA']
# valid in place ['place', 'of', 'country', 'location', 'applies to place', 'applies to country', 'applies to location', 'applies to nonjurisdictional location', 'applies to nonjurisdictional place', 'in location', 'in place', 'of the location', 'of the place', 'true in', 'valid in location', 'valid in nonjurisdictional location', 'valid in nonjurisdictional place', 'valid in territory']
# laws applied ['applied law', 'law applied', 'legal base']
# backup or reserve team or crew ['backup crew', 'backup team', 'reserve crew', 'reserve team']
# located in protected area ['located in bioreserve', 'located in biosphere reserve', 'located in conservation area', 'located in ecological protection area', 'located in national park', 'located in natural reserve', 'located in nature conservation area', 'located in nature preserve', 'located in nature reserve', 'located in provincial park', 'located in state park', 'located in territorial park', 'located in wildlife refuge', 'located in wildlife sanctuary', 'national park location', 'protected area location', 'provincial park location', 'state park location']
# railway signalling system ['signalling system', 'signalling type', 'type of signalling']
# flag bearer []
# open days ['days open', 'open on days', 'opening days']
# closed on ['except', 'closed days', 'days not open']
# open period from ['opening day of the year', 'opening month', 'opening season', 'start of opening season', 'start opening season']
# open period to ['end of opening season', 'end opening season', 'open until']
# adjacent structure or building ['adjacent facility', 'next to', 'adjacent building', 'adjoining building', 'located next to', 'neighboring building']
# package management system ['software package']
# spatial reference system ['SRS', 'coordinate reference system', 'CRS']
# official religion ['established religion', 'state religion']
# game artist ['game artwork by', 'video game artist', 'video game artwork by']
# damaged ['class of item damaged', 'class of object damaged', 'class of structure damaged', 'item damaged', 'object damaged', 'structure damaged']
# destroyed ['class of items destroyed', 'class of objects destroyed', 'class of structure destroyed', 'item destroyed', 'object destroyed', 'structure destroyed', 'structures destroyed', 'were destroyed']
# qualifies for event ['league this event qualifies for']
# mount ['horse', 'steed']
# film crew member []
# recovered by ['recovery group', 'recovery vehicle']
# develops from ['antecedent anatomical structure', 'developed from', 'evolved from', 'evolves from']
# practiced by ['proponent', 'practitioners', 'associated with', 'done by', 'has practitioner', 'has proponent', 'implemented by', 'implementor', 'observed by', 'occupation of this field', 'practioner', 'studied by']
# KML file ['Keyhole Markup Language file']
# has tense ['grammatical tense', 'has grammatical tense']
# does not have part ['non part', 'not have part', 'missing', 'lacks', 'does not include', "doesn't have", 'has part missing']
# parent peak ['parent mountain']
# repeals ['cancels', 'invalidates', 'revokes']
# molecule conformation ['conformations of molecule']
# birthday ['b-day', 'bday', 'birth day']
# Australian Classification ['ACB', 'ACB rating']
# enclosure []
# has grammatical mood ['mode', 'mood', 'grammatical mood', 'grammatical mode', 'has grammatical mode']
# offers view on ['sights', 'has view of', 'has views of', 'offers view of', 'view of', 'view to', 'views of', 'views to']
# art director ['artistic director']
# territory overlaps ['overlaps', 'partially coextensive with', 'partially coincident with', 'partially contains territorial extent', 'partially located in territorial entity', 'partially overlaps', 'partly coincident with', 'partly located in territorial entity', 'partly overlaps']
# innervated by []
# innervates []
# league points system ['points system']
# patient of ['physician', 'doctor']
# ClassInd rating ['BARS']
# intangible cultural heritage status []
# anatomical branch of []
# has anatomical branch []
# base ['base face', 'base facet', 'base edge']
# radix ['base']
# content deliverer ['content distributor', 'deliverer of contents', 'distributor of contents']
# storyboard artist ['visualizer', 'story artist']
# statistical leader ['most valuable player', 'MVP', 'record setter', 'statistical leader']
# encoding []
# musical conductor ['conductor', 'music director', 'choir director', 'conducted by', 'musical director', 'principal conductor']
# broadcast by ['aired on', 'broadcasted on', 'broadcasting on', 'streamed on', 'streaming on', 'network', 'broadcaster', 'radio channel', 'broadcast on', 'radio network', 'radio station', 'streamed by', 'TV channel', 'TV network', 'TV station']
# head of government ['executive power headed by', 'first minister', 'government headed by', 'head of national government', 'governor', 'president', 'prime minister', 'mayor', 'chancellor', 'premier']
# transport network ['rail network', 'transportation network', 'route network', 'subway network', 'network', 'road type', 'railway network', 'transport network', 'tram network', 'highway system', 'light rail system', 'metro system', 'part of network', 'routes system', 'subway system', 'system of routes', 'trail system', 'transit network']
# country ['state', 'land', 'sovereign state', 'host country']
# place of birth ['born', 'birthplace', 'birth city', 'birth location', 'birth place', 'born at', 'born in', 'location born', 'location of birth', 'POB']
# place of death ['died', 'death location', 'death place', 'deathplace', 'died in', 'killed in', 'location of death', 'POD']
# sex or gender ['gender', 'sex', 'biological sex', 'gender identity', 'gender expression', 'gender or sex']
# father ['parent', 'child of', 'dad', 'daughter of', 'son of', 'daddy', 'has father', 'is child of', 'is daughter of', 'is son of']
# mother ['is son of', 'mam', 'mum', 'mummy', 'parent', 'mom', 'child of', 'daughter of', 'son of', 'mommy', 'has mother', 'is child of', 'is daughter of']
# spouse ['wife', 'husband', 'married', 'partner', 'marry', 'husbands', 'wives', 'wed', 'spouses', 'common-law husband', 'common-law spouse', 'common-law wife', 'marital partner', 'marriage partner', 'married partner', 'married to', 'wedded to']
# country of citizenship ['nation', 'nationality', 'citizenship', 'country', '(legal) nationality', 'citizen of', 'nation of citizenship', 'national of', 'subject of (country)']
# continent []
# instance of ['example of', 'has type', 'is a', 'is an', 'is of type', 'item of type', 'unique individual of', 'unitary element of class', 'type']
# head of state ['king', 'leader', 'queen', 'emperor', 'governor', 'monarch', 'president', 'state headed by', 'chief of state']
# capital ['seat', 'capital city', 'administrative center', 'administrative capital', 'administrative centre', 'administrative headquarters', 'administrative seat', 'capital town', 'chef-lieu', 'county seat', 'county town', 'court residence', 'government capital', 'government seat', 'has capital', 'location of capital', 'principal place', 'seat of government']
# official language ['speaking', 'language spoken', 'language official', 'spoken in']
# currency ['base currency', 'used money']
# position held ['function', 'job', 'held position', 'holds position', 'office held', 'political office held', 'political seat', 'position occupied', 'public office']
# child ['father of', 'has child', 'has children', 'has daughter', 'has daughters', 'has kid', 'has kids', 'has son', 'has sons', 'mother of', 'parent of', 'offspring', 'progeny', 'son', 'descendants', 'daughter', 'issue', 'kid', 'children', 'kids', 'daughters', 'sons']
# shares border with ['border', 'next to', 'adjacent to', 'bordered by', 'borders clockwise', 'shares borders with']
# author ['writer', 'creator', 'poet', 'maker', 'playwright', 'written by']
# family ['royal house', 'house', 'dynasty', 'noble family', 'member of family']
# member of sports team ['team', 'player of', 'club played for', 'member of team', 'of team', 'part of team', 'played for', 'plays for', 'sport team', 'team played for', 'teams played for']
# director ['film director', 'movie director', 'directed by', 'game director']
# screenwriter ['scenarist', 'scriptwriter', 'script writer', 'written by', 'film script by', 'game writer', 'screenplay by', 'story by', 'teleplay by', 'video game writer', 'writer (of screenplays)', 'writing credits']
# constellation ['part of constellation']
# discoverer or inventor ['inventor', 'invented', 'developer', 'discoverer', 'introduced by', 'created by', 'developed by', 'devised by', 'discovered by', 'first described', 'first studied by', 'invented by', 'inventor or discoverer']
# site of astronomical discovery ['astronomical discovery site', 'discovered at observatory', 'observatory of discovery', 'observatory site of discovery']
# ancestral home ['native place', 'ancestral home place', 'ancestral homeland', 'ancestral homeplace', 'ancestral land', 'ancestral place', 'ancestral village', 'native village']
# educated at ['alma mater', 'alumna of', 'alumni of', 'alumnus of', 'attended school at', 'college attended', 'education place', 'graduate of', 'graduated from', 'place of education', 'school attended', 'schooled at', 'schooling place', 'student at', 'studied at', 'university attended', 'went to school at', 'education', 'attended', 'faculty', 'student of']
# top-level Internet domain ['domain', 'top level domain', 'ccTLD', 'gTLD', 'internet domain', 'TLD']
# connecting line ['is on', 'line connected to', 'rail line connected to', 'railway line']
# architect ['architecture firm']
# anthem ['march', 'national anthem', 'club anthem', 'official hymn', 'official song', 'team anthem']
# composer ['songwriter', 'written by', 'composed by', 'film score by', 'music by', 'musical score by', 'original music composer', 'soundtrack by']
# librettist ['book by', 'libretto by']
# commissioned by ['client', 'commissioner', 'developer', 'made for', 'built for', 'orderer']
# sexual orientation ['sexuality']
# main regulatory text ['applicable law', 'authorizing law', 'governing law', 'bylaws', 'regulated by', 'by-laws', 'authorizing legislation', 'governing document', 'governing text', 'key document', 'legal basis', 'legally established by', 'statutory authority', 'statutory authorization']
# noble title ['title of nobility', 'peerage', 'hereditary title', 'nobility title', 'royal and noble ranks', 'royal title', 'title (hereditary)']
# editor ['edited by', 'associate editor', 'compiled by', 'ed.', 'editorial director', 'eds.', 'publication director', 'series editor']
# field of work ['domain', 'subject', 'discipline', 'area', 'specialty', 'research field', 'studies', 'research', 'activity', 'speciality', 'trade', 'specialism', 'fields', 'academic discipline', 'purpose', 'field of study', 'academic subject', 'field of activity', 'area of work', 'academic area', 'activity domain', 'be researcher in', 'conduct research about', 'domain of activity', 'field of research', 'FOW', 'research fields', 'research on', 'responsible for', 'scientific area', 'scientific discipline', 'work area', 'work field', 'area of research']
# member of political party ['political party', 'party', 'member of', 'member of party', 'party membership', 'political party member']
# native language ['first language', 'mother tongue', 'L1 speaker of', 'language native']
# taxon rank ['rank', 'taxonomic rank', 'type of taxon']
# occupation ['work', 'employment', 'profession', 'job', 'career', 'craft', 'vocation', 'avocation', 'employ']
# employer ['organization', 'organisation', 'employed by', 'of employer', 'worked at', 'worked for', 'working at', 'working for', 'working place', 'works at', 'works for']
# illustrator ['artist', 'illustrated by', 'illustration by', 'drawn by', 'draftsperson', 'drawing by', 'drawings by']
# service retirement ['retirement', 'retired', 'decommissioned', 'date of service retirement', 'out of service', 'time of service retirement']
# date of disappearance ['disappeared', 'date of missing', 'last known alive before disappearance', 'last seen', 'missing since', 'time of disappearance']
# retrieved ['consulted', 'accessed', 'access date', 'accessdate', 'date accessed', 'date of access', 'date of retrieval', 'date retrieved', 'reference date', 'retrieved at', 'retrieved date', 'time of retrieval', 'viewed on', 'viewed on date', 'visited at']
# date of first performance ['date of first performance', 'premiere', 'date of premiere', 'first performance date', 'premiere date', 'time of first performance', 'world premiere', 'world premiere date']
# time of earliest written record ['date of first written record', 'earliest record', 'first attestation', 'first attested', 'first historic record', 'first mentioned in writing', 'first recorded in', 'first written record', 'time of prediction']
# floruit ['living', 'active', 'circa', 'flourished', 'work period', 'alive at', 'alive in', 'date cited', 'fl', 'fl.', 'known alive in', 'time alive', 'year alive', 'years active', 'years alive']
# earliest date ['earliest start time', 'earliest time', 'start time (earliest)', 'after', 'after this date', 'earliest start date', 'later than', 'min date', 'minimum date', 'no earlier than', 'on or after this date', 'start date (earliest)', 'terminus post quem']
# latest date ['before this date', 'earlier than', 'end date (latest)', 'latest end date', 'max date', 'maximum date', 'no later than', 'on or before this date', 'prior to', 'terminus ante quem']
# date of official opening ['opened', 'launched', 'inaugurated', 'inauguration', 'date of opening', 'date opened', 'grand opening', 'inauguration date', 'launch date', 'official opening', 'official opening time', 'officially opened on', 'opening date']
# date of baptism ['baptized', 'christened', 'baptised', 'baptism date', 'christening date', 'date baptism', 'date of baptism in early childhood', 'date of christening', 'time of baptism', 'time of christening']
# oath of office date ['installation', 'inauguration', 'start of office date', 'taking office']
# start of work period ['debut', 'active since', 'career began', 'career start', 'date of activity (start)', 'fl. (start)', 'floruit (start)', 'floruit start', 'flourished (start)', 'start date of activity', 'start time for work', 'start working', 'work period (start)', 'work period start', 'work starts', 'years active']
# end of work period ['retirement', 'active until', 'date of activity (end)', 'end date of activity', 'end time for work', 'fl. (end)', 'floruit (end of work)', 'floruit end', 'flourished (end)', 'work ends', 'years active end']
# periapsis date (DEPRECATED) []
# minimum date (property constraint) ['earliest date', 'min date']
# maximum date (property constraint) ['latest date', 'max date']
# discontinuation date ['discontinued', 'ceased date', 'date discontinued', 'date of discontinuation', 'date product was discontinued', 'discontinued date', 'end-of-life', 'end-of-life date', 'EOL', 'EOL date', 'product discontinued']
# production date ['date of production', 'filming date', 'filming time', 'production date', 'year of production']
# date depicted ['date shown', 'depicted date', 'depicted time', 'depicts date', 'shown as at date', 'temporal coverage']
# archive date ['archival date', 'archived in', 'archivedate', 'date archived']
# public domain date ['copyright end date', 'PD date']
# date of official closure ['closed', 'closed on', 'closed date', 'closing date', 'closure date', 'date of closure', 'official closure']
# awarded for period []
# date of burial or cremation ['burial date', 'cremation date', 'date of cremation', 'funeral date', 'interment date']
# last update ['changed', 'modified', 'revised', 'altered', 'updated', 'altered last', 'changed last', 'last changed', 'last edited', 'last modification', 'last modified', 'last revised', 'last revision', 'last updated', 'modified last', 'most recent update', 'revised last', 'update date', 'updated last']
# commercialization date ['marketed', 'availability date', 'commercialization date', 'date of commercialization', 'product release date', 'release date']
# announcement date ['date', 'published', 'released', 'teaser', 'shown', 'revealed', 'date shown', 'announced in', 'announced on', 'date announced', 'date of announcement', 'date of reveal', 'date released', 'date teased', 'made public on', 'public announcement date']
# start of covered period ['coverage start date', 'covered period start']
# end of covered period ['coverage end date', 'covered period end']
# date of the first one ['first instance', 'date of first', 'date of the first instance']
# date of the latest one ['date of the latest instance', 'date of the most recent instance', 'latest instance']
# Gregorian calendar start date ['adoption of the Gregorian calendar', 'first date (N.S.)', 'Gregorian calendar first used']
# effective date ['date of commencement', 'date of coming into force', 'enforcement date']
# date of promulgation ['assent', 'date of approval', 'date of assent', 'date signed', 'enacted date', 'promulgation date', 'royal assent', 'date of signing', 'signature date', 'signing date', 'adoption date', 'date of adoption']
# earliest end date ['end date (earliest)', 'earliest end time', 'end time (earliest)']
# latest start date ['start date (latest)', 'latest start time', 'start time (latest)']
# extinction date ['date of extinction']
# date postally canceled ['date canceled', 'date cancelled', 'date postally cancelled', 'date postmarked']
# introduced on ['bill introduced on', 'introduced date', 'introduction date']
# date of resignation ['official date of resignation', 'official resignation date', 'resignation date']
# relevant date for copyright ['copyright date', 'date of copyright', 'copyright year', 'year of copyright']
# date of probate ['date will proved', 'probate date', 'will proved on']
# recording date ['capture date', 'date of capture', 'date of recording', 'rec. date', 'recdate', 'record date', 'recorded date']
# debut date []
# date of incorporation ['incorporated', 'date incorporated', 'incorporated on date', 'incorporation date', 'year incorporated']
# embargoed until ['embargo ends', 'embargo period']
# chronological designation []
# date of application []
# latest end date ['end date (latest)', 'end time (latest)', 'latest end time']
# date popularized ['popularization date', 'popularized in', 'popularized on']
# date filed ['submitted', 'filed', 'submission date', 'date submitted', 'filing date']
# time of deposition ['deposited', 'buried', 'date hidden', 'date of burial', 'date of deposit', 'date of deposition', 'time hidden', 'time of deposit']
# collection date []
# capacity factor []
# number of sentences []
# Football Money League rank ['Deloitte Football Rank']
# approach angle []
# departure angle []
# linear reference ['mileage', 'postmile']
# data transfer speed ['bandwidth', 'throughput', 'bit rate', 'bitrate', 'data rate', 'data transfer rate', 'transfer rate', 'transfer speed', 'transmission rate']
# number of polling stations []
# exposure time ['shutter speed']
# ISO speed ['ASA speed', 'ISO speed rating', 'ISO/ASA']
# f-number ['f-ratio', 'focal ratio', 'ƒ-number']
# minimum wage []
# number of hospital beds ['beds', 'hospital beds', 'number of beds', 'number of patients']
# feed-in tariff ['advanced renewable tariff', 'FiT', 'FIT', 'renewable energy payment', 'standard offer contract']
# average speed []
# solar irradiance []
# effective temperature ['equilibrium temperature']
# literacy rate ['literate population (%)', 'percentage of literate population', 'total literacy rate']
# surface gravity []
# shrinkage []
# specific absorption rate ['SAR', 'SAR Value']
# surface roughness []
# computer performance ['computing power', 'floating point operations per second', 'FLOPS', 'processing power']
# cumulative elevation gain ['ascent']
# number of decimal digits ['digits', 'number of digits']
# amount cataloged ['amount catalogued']
# fineness ['purity', 'carat gold', 'millesimal fineness']
# graph radius ['radius of a graph', 'radius of graph']
# minimum temperature record ['lowest temperature']
# ...
# strike tone ['bell note', 'bell tone']
# entry receptor []
# media franchise ['franchise', 'mass media franchise', 'media mix', 'presented in media franchise']
# study type []
# references work, tradition or theory ['references', 'alludes to']
# use with property value ['property value for items of this type']
# prompt when missing []
# open data portal ['od portal', 'odp']
# theorized by ['author', 'proponent', 'proposer', 'defined by', 'supported by', 'named by', 'authored by', 'explained by', 'posed by', 'proposed by', 'suggested by', 'popularized by']
# set in environment ['takes place in', 'environmental location', 'narrative set in', 'playing in', 'set in location', 'setting location']
# academic appointment []
# version control system ['RCS', 'VCS']
# interactive elements ['ESRB IE', 'ESRB interactive elements']
# course ['meal course']
# peak bagging classification []
# public transport stop ['railway station', 'metro station', 'nearest public transport stop', 'served by metro station', 'served by railway station', 'served by station', 'served by subway station', 'station nearby', 'stop nearby', 'subway station', 'transport station nearby', 'transport stop nearby', 'nearest station']
# descriptive solubility ['qualitative solubility', 'solubility (descriptive)', 'solubility (qualitative)']
# content partnership category []
# Ofsted inspection rating []
# Vietnamese middle name []
# heraldic attitude []
# tala []
# raga []
# recording location ['recorded at']
# front and back matter ['epilogue', 'acknowledgment', 'prologue', 'addendum', 'colophon', 'foreword', 'postscript', 'preface', 'appendix', 'table of contents', 'abbreviations table', 'title page', 'afterword', 'back and front matter', 'back matter', 'bibliography of this book', 'front matter', 'glossary of this book', 'index of this book', 'introduction in this book', 'postface']
# external auditor ['auditor, external', 'statutory auditor']
# category for the exterior of the item ['Commons category for the exterior of the item', 'exterior category']
# Oakeshott typology []
# bibliography ['bibliography of']
# opening time ['hour opens', 'open hour', 'opening hour', 'opens at']
# closing time ['closes at']
# expansion of ['add-on for', 'add-on of', 'DLC for', 'DLC of']
# Netflix maturity rating []
# character designer ['designed by', 'character designed by', 'character modeler']
# fandom ['fan group name']
# has census ['has human population census']
# parallel street []
# ritual object []
# permits ['allows', 'enables', 'does not prohibit']
# prohibits ['bans', 'forbids', 'does not allow', 'does not permit']
# economy of topic []
# check-in time ['checkin time']
# check-out time ['checkout time']
# port calls ['port of call']
# dedicated heritage entity ['associated heritage entity', 'has museum']
# defining mutations []
# digitised by ['digitized by', 'scanned by']
# for color scheme ['theme', 'color mode', 'color scheme', 'color theme', 'colour mode', 'colour scheme', 'colour theme', 'for colour scheme', 'prefers color scheme', 'prefers colour scheme', 'uses color scheme', 'uses colour scheme']
# parent ['parents', 'guardian']
# epithet ['cognomen', 'byname']
# attraction to []
# hairstyle / hairlength ['haircut', 'coiffure', 'hairdo', 'hair cut', "'do", 'hair do', 'hair style', 'hair styling', 'style of hair']
# facial hair ['beard', 'moustache', 'mustache', 'face hair']
# identity element ['neutral element']
# mathematical inverse ['reciprocal', 'inverse function', 'negation', 'additive inverse', 'inverse element', 'multiplicative inverse', 'opposite number']
# has operation ['has operator']
# has marker ['has       lineage marker', 'lineage marker']
# Hong Kong film rating ['OFNAA film rating']
# indexed in bibliographic review ['indexed in bibliographic database']
# MTRCB rating []
# ELSPA rating []
# kunya []
# category for the view from the item ['view from category']
# artistic director []
# compatible with ['supports', 'client for', 'used with']
# category for the view of the item ['view of category']
# liturgical rank []
# CCC classification ['CCC clasification', 'Chile age rating', 'Consejo de Calificación Cinematográfica rating category']
# solution to []
# archaeological site of ['contains ruins of', 'contains wreck of', 'ruins of', 'site of ruins of', 'site of wreck of', 'wreck of']
# subdivision of this unit ['divided into']
# character type ['archetype', 'stereotype', 'stock character', '-dere', 'character archetype', 'character stereotype', 'dere']
# derived from organism type ['derived from organism of taxon', 'originated from individual of taxon', 'taxon of origin']
# applicable 'stated in' value ["'stated in' value", 'applicable "stated in" value', 'applicable database', 'applicable P248 value', 'applicable stated in value', 'corresponding database', 'corresponding P248 value', 'stated in database', 'stated in value']
# BAMID film rating []
# Commons media contributed by ['contributing institution', 'contributing organization']
# first family name in Portuguese name []
# thesis committee member ['dissertation committee member']
# letterer ['lettering by']
# sensors ['detector', 'sensor', 'has detector', 'has sensor', 'sensor equipment']
# set during recurring event ['narrative event', 'narrative holiday', 'set during event', 'set during holiday']
# supplement to ['supplements', 'extends', 'is supplement to', 'spin-off of', 'complements work', 'addendum to', 'tie-in of']
# seismic classification []
# reissue of ['re-release', 're-edition', 'repackage']
# affiliated worker organisation ['union', 'labor union', 'trades union', 'workers union']
# demographics of topic ['demography of topic']
# assessment outcome []
# music transcriber ['music notation writer', 'musical notation writer', 'musical transcriber', 'notation writer', 'transcriber of music']
# inverse agonist of []
# transitivity []
# script style ['handwriting style', 'style of script', 'style of writing', 'type style']
# Gedong Kirtya Classification []
# has graphical element ['added graphic element', 'added graphical element', 'graphic element', 'graphical element', 'graphical element added', 'has graphic element']
# does not have cause []
# personal library at ['personal library held at', 'personal library held by', 'personal library located at']
# field of usage ['domain', 'context of usage', 'context of use', 'domain of usage', 'domain of use', 'field of use', 'jargon source']
# artist files at ['artist file at', 'artist file held at', 'artist file held by', 'artist file in', 'artist files held at', 'artist files held by', 'artist files in', 'has artist file at', 'has artist file in', 'has artist files at', 'has artist files in']
# counterpart position ['shadows', 'opposite number', 'shadow minister for', 'shadow minister of', 'shadow position of']
# official podcast ['podcast']
# diel cycle ['diurnal or nocturnal animal', 'nocturnal or diurnal animal']
# intended background color []
# type of lens ['lens', 'Fresnel', 'has lens']
# oral history at ['oral histories at', 'oral history held by', 'oral history in collection at', 'oral history in collection of']
# district heating grid ['district heating', 'district cooling system', 'district heating system', 'teleheating', 'urban heating']
# personality trait of fictional character ['personality', 'personality trait', 'trait', 'traits', 'character trait of fictional character', 'character trait of fictitious character', 'fictional character personal quality', 'fictional character personality trait', 'fictional character trait', 'fictitious character personal quality', 'fictitious character personality trait', 'fictitious character trait', 'has trait', 'personal quality of fictional character', 'personal quality of fictitious character', 'personality trait of fictitious character', 'trait of fictional character', 'trait of fictitious character']
# not found in ['missing from source', 'not attested in', 'not described by source', 'not given in', 'not listed in', 'not present in']
# named place on map ['name on map', 'place on map']
# consequence of text ['because of text', 'result of text']
# voted on by []
# Qualis rank ['Qualis ranking']
# delta of ['delta source', 'river delta of']
# taxon range ['range', 'geographic range', 'geographic range of taxon', 'range of taxon', 'taxon geographic range']
# replacement value []
# announced at ['announced during']
# translation of []
# symbol represents ['representing', 'represents', 'notation represents', 'symbol representing']
# syntactic dependency head relationship ['head relationship', 'relationship to head in syntactic dependency', 'syntactic dependency relationship to head']
# setlist ['performances', 'concert program', 'music performed', 'performance list', 'set list', 'songs performed', 'works performed']
# Classification of the Functions of Government ['COFOG ID', 'COFOG number']
# UEFA stadium category []
# remix of ['remixes', 'chops and screws', 'mashes up', 'mashup of', 'mix of']
# container ['packaging', 'contained within']
# release of ['music release of', 'release of music']
# GRAC rating ['GRAC']
# created for ['occasion', 'made for', 'cause of creation', 'commissioned for', 'on the occasion of', 'produced for', 'work created for']
# Candomblé nation []
# NZTCS conservation status ['New Zealand Threat Classification System conservation status']
# SMECCV classification ['Mexican video game rating category', 'SMECCV classification', 'SMECCV rating']
# App Store age rating ['age rating', 'app rating', 'app store age']
# music created for ['created for', 'composed for', 'composed for work', 'is music for work', 'music composed for', 'music composed for work', 'music for', 'music for work', 'music made for', 'music made for work', 'music written for', 'music written for work']
# issuing agent of work ['issuer', 'issued by', 'official publication of', 'house journal of', 'house organ of', 'house publication of', 'issuing agency (work)', 'issuing agency of work', 'issuing agent (work)', 'issuing body (work)', 'issuing body of work', 'official journal of', 'official organ of', 'organ of', 'work issued by']
# populates category ['extension populates category', 'MediaWiki extension populates category', 'module populates category', 'template has category', 'template populates category', 'Wikimedia module populates category', 'Wikimedia template populates category', 'fills category']
# madhhab ['school of thought', 'madhab', 'mazhab']
# dissertation program []
# catalogue raisonné ['Art Catalog', 'artist catalog', 'artist catalogue', 'reasoned catalogue']
# predicate for ['action', 'verb for', 'verb phrase for']
# has semantic argument ['has thematic relation', 'thematic relation']
# illustrative content []
# isotopically modified form of []
# equivalent in higher rank taxon ['closest concept in higher taxon', 'equivalent in higher taxon', 'equivalent in larger group', 'equivalent in parent taxon', 'subclass of higher-taxon concept', 'term in higher taxon', 'term in higher-order taxon', 'term in larger group']
# train melody ['melody']
# protective marking ['classification', 'secrecy', 'confidentiality', 'document classification', 'document marking', 'information classification', 'privacy category', 'secrecy category', 'security marking']
# type host ['symbiotype', 'symbiotype taxon', 'taxon of symbiotype', 'taxon of type host', 'taxon of type-host', 'type host taxon', 'type-host', 'type-host taxon']
# facilitates flow of ['transports', 'carries', 'channel for', 'controls flux of', 'enables flow of', 'regulates flow of']
# next level in hierarchy []
# individual of taxon ['individual of taxon', 'instance of taxon', 'is an individual of taxon', 'is an individual of the taxon', 'is individual of taxon', 'is individual of the taxon', 'is instance of taxon', 'item is in taxon', 'member of taxon', 'species of this individual', 'taxon of item', 'taxon of subject', 'taxon of the item']
# associated cadastral district ['cadastral community', 'cadastral district', 'cadastral districts', 'cadastral municipality', 'Katastralgemeinde']
# category for honorary citizens of entity ['honorary citizens category']
# hotel rating ['hotel stars', 'star rating of a hotel']
# director of publication ['publication manager']
# semantic gender ['natural gender']
# computational complexity ['complexity class', 'computational complexity class']
# created during ['captured at', 'captured during', 'created at', 'event of media file', 'filmed at', 'filmed during', 'from event', 'recorded at', 'recorded during', 'shot at', 'shot during', 'taken at', 'taken during']
# trained by ['trainer', 'personal trainer']
# identifies ['denotes', 'determines', 'distinguishes', 'fully determines', 'identifier of', 'is identifier of', 'is primary key for', 'is unique key for', 'uniquely determines']
# documentation files at ['clipping files at', 'documentary records at', 'documentary records held at', 'documentary records held by', 'documentation at', 'documentation file at', 'documentation files held at', 'documentation files held by', 'ephemera files at', 'ephemera files held at', 'ephemera files held by', 'has documentation files at', 'pamphlet files at']
# maintains linking to ['links to']
# academic calendar type ['academic term type', 'academic year type']
# taxonomic treatment []
# co-applicant ['coapplicant']
# applicant []
# type of a register in Germany ['register type in Germany', 'type of register in Germany']
# notable role ['notable character role', 'notable for character role', 'notable for role']
# athletics program ['athletic program', 'college athletics program', 'college sports program', 'has athletics program', 'school athletics program', 'school district athletics program', 'school district sports program', 'school sports program', 'sports program', 'university athletics program', 'university sports program']
# has certification ['license', 'qualification', 'certification', 'has license', 'has qualification']
# choreography for ['is choreography for']
# has surface []
# official observer status in organization ['observer of']
# web interface software ['web UI', 'WUI']
# medically indicated in case of ['indication', 'indicated for', 'medical indication', 'medically indicated for']
# place of disappearance []
# reports to []
# rack system []
# exhibited creator ['artist exhibited', 'artist featured', 'artist presented', 'artist whose work is exhibited', 'creator featured', 'creator presented', 'creator whose work is exhibited', 'exhibited artist', 'featured artist', 'featured creator']
# applies to work ['work applied', 'valid for work', 'valid in work']
# featured track(s) ['soundtrack', 'songs', 'audio track', 'audio tracks', 'featured track', 'music track', 'music tracks', 'OST']
# raw material processed ['commodity', 'consumes', 'consumed resource', 'input material', 'intermediate good used', 'material used', 'natural resource used', 'raw material used', 'material processed']
# franchisor ['franchise', 'franchiser']
# introduced in ['added in', 'first appeared in', 'first published in', 'introduced by']
# WikiProject importance scale rating []
# class of non-item property value ['values are instances of']
# finisher []
# dance style ['associated with dance', 'dancing style']
# distributed from ['host', 'distributed via', 'hosted at', 'web host', 'webhost']
# in operation on service ['in operation on route', 'in operation on transport route', 'operates on route', 'operates on service', 'operates on transport route', 'operates transport route', 'route of vehicle', 'route served', 'serves transport route', 'service of vehicle', 'transport route of vehicle', 'transport route operated', 'transport route served', 'transport route serviced', 'used on route', 'used on service', 'used on transport route', 'vehicle serves', 'used by service']
# orchestrator ['arranged for orchestra by', 'orchestral arrangement by', 'orchestral arranger', 'orchestration by', 'orchestrations by']
# preceding halt on service ['preceding station', 'preceding stop', 'previous station', 'previous stop', 'prior station', 'prior stop']
# following halt on service ['following station', 'following stop', 'next halt', 'next station', 'next stop', 'succeeding halt', 'succeeding station', 'succeeding stop', 'successive halt', 'successive station', 'successive stop']

# %%
with open(ONTOLOGY_MAPPINGS_DIR + "prop2label.json", "w") as f:
    json.dump(PROP_2_LABEL, f)

with open(ONTOLOGY_MAPPINGS_DIR + "prop2aliases.json", "w") as f:
    json.dump(PROP2ALIASES, f)

# %%
with open(ONTOLOGY_MAPPINGS_DIR + "prop2label.json", "r") as f:
    PROP_2_LABEL = json.load(f)

with open(ONTOLOGY_MAPPINGS_DIR + "prop2aliases.json", "r") as f:
    PROP2ALIASES = json.load(f)

# %% [markdown]
# ### Collecting subject and value constraints of relations

# %%
from SPARQLWrapper import SPARQLWrapper, JSON


@retry(wait=wait_random_exponential(multiplier=1, max=60))
def get_constraints(property_id):
    """Retrieve value-type and subject-type constraints for a specified Wikidata property."""

    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

    query = f"""
    SELECT ?constraintType ?entity WHERE {{
      VALUES ?property {{ wd:{property_id} }}  

      # ?property p:P2302 ?statement.  # Property constraints
      # ?statement ps:P2302 ?constraintEntity.  # Constraint type

      VALUES ?constraintEntity {{ wd:Q21510865 wd:Q21503250 }}  # Value-type & Subject-type constraints

      # ?statement pq:P2308 ?entity.  # The constrained entity type (allowed type)

      BIND(
        IF(?constraintEntity = wd:Q21510865, "Value-type constraint", "Subject type constraint")
        AS ?constraintType
      )
    }}
    """
    # SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en". }}

    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    constraints = {"Value-type constraint": [], "Subject type constraint": []}
    for result in results["results"]["bindings"]:
        constraints[result["constraintType"]["value"]].append(
            result["entity"]["value"].split("/")[-1]
        )

    return constraints


# Example usage:
property_id = "P40"  # Replace with any Wikidata property ID
constraints = get_constraints(property_id)

print(constraints)
# Out:
# {'Value-type constraint': ['Q5', 'Q729', 'Q4886', 'Q95074', 'Q178885', 'Q207174', 'Q795052', 'Q2135501', 'Q4271324', 'Q13002315', 'Q16979650', 'Q21070568', 'Q21070598', 'Q21191150', 'Q24334299', 'Q64520857', 'Q75855169', 'Q115537581'], 'Subject type constraint': ['Q5', 'Q729', 'Q4886', 'Q95074', 'Q178885', 'Q207174', 'Q215627', 'Q219160', 'Q795052', 'Q2135501', 'Q3046146', 'Q4271324', 'Q13002315', 'Q16979650', 'Q21070568', 'Q21070598', 'Q24334299', 'Q75855169', 'Q115537581']}

# %%
constraint_dict = {}

for prop in tqdm(PROP_2_LABEL.keys()):
    constraint_dict[prop] = get_constraints(prop)
    time.sleep(0.1)
len(constraint_dict)
# Out:
# 100%|██████████| 2479/2479 [26:17<00:00,  1.57it/s]
# 2479

# %%
get_constraints("P50")
# Out:
# {'Value-type constraint': ['Q5',
#   'Q11660',
#   'Q43229',
#   'Q61002',
#   'Q95074',
#   'Q215627',
#   'Q16334295',
#   'Q24229398',
#   'Q60557912',
#   'Q75855169',
#   'Q78056559',
#   'Q107307291'],
#  'Subject type constraint': ['Q571',
#   'Q7366',
#   'Q49848',
#   'Q74574',
#   'Q277759',
#   'Q386724',
#   'Q628523',
#   'Q2668072',
#   'Q3026787',
#   'Q3331189',
#   'Q15306849',
#   'Q15938550',
#   'Q17489659',
#   'Q55760865']}

# %%
with open(ONTOLOGY_MAPPINGS_DIR + "prop2data_type.json", "r") as f:
    PROP_2_DATA_TYPE = json.load(f)

# %%
PROP_2_DATA_TYPE
# Out:
# {'P2048': 'Quantity',
#  'P2049': 'Quantity',
#  'P2050': 'Quantity',
#  'P2051': 'Quantity',
#  'P2052': 'Quantity',
#  'P2053': 'Quantity',
#  'P2054': 'Quantity',
#  'P2055': 'Quantity',
#  'P2056': 'Quantity',
#  'P2060': 'Quantity',
#  'P2066': 'Quantity',
#  'P2067': 'Quantity',
#  'P2068': 'Quantity',
#  'P2069': 'Quantity',
#  'P2073': 'Quantity',
#  'P2075': 'Quantity',
#  'P2076': 'Quantity',
#  'P2077': 'Quantity',
#  'P2097': 'Quantity',
#  'P2101': 'Quantity',
#  'P2102': 'Quantity',
#  'P2103': 'Quantity',
#  'P2105': 'Quantity',
#  'P2107': 'Quantity',
#  'P2109': 'Quantity',
#  'P2112': 'Quantity',
#  'P2113': 'Quantity',
#  'P2114': 'Quantity',
#  'P2116': 'Quantity',
#  'P2117': 'Quantity',
#  'P2118': 'Quantity',
#  'P2119': 'Quantity',
#  'P2120': 'Quantity',
#  'P2121': 'Quantity',
#  'P2124': 'Quantity',
#  'P2128': 'Quantity',
#  'P2129': 'Quantity',
#  'P2130': 'Quantity',
#  'P2131': 'Quantity',
#  'P2132': 'Quantity',
#  'P2133': 'Quantity',
#  'P2134': 'Quantity',
#  'P2135': 'Quantity',
#  'P2136': 'Quantity',
#  'P2137': 'Quantity',
#  'P2138': 'Quantity',
#  'P2139': 'Quantity',
#  'P2140': 'Quantity',
#  'P2141': 'Quantity',
#  'P2142': 'Quantity',
#  'P2143': 'Quantity',
#  'P2144': 'Quantity',
#  'P2145': 'Quantity',
#  'P2146': 'Quantity',
#  'P2147': 'Quantity',
#  'P2148': 'Quantity',
#  'P2149': 'Quantity',
#  'P2150': 'Quantity',
#  'P2151': 'Quantity',
#  'P2154': 'Quantity',
#  'P2160': 'Quantity',
#  'P2177': 'Quantity',
#  'P2196': 'Quantity',
#  'P2197': 'Quantity',
#  'P2198': 'Quantity',
#  'P2199': 'Quantity',
#  'P2200': 'Quantity',
#  'P2201': 'Quantity',
#  'P2202': 'Quantity',
#  'P2203': 'Quantity',
#  'P2204': 'Quantity',
#  'P2208': 'Quantity',
#  'P2211': 'Quantity',
#  'P2212': 'Quantity',
#  'P2213': 'Quantity',
#  'P2214': 'Quantity',
#  'P2216': 'Quantity',
#  'P2217': 'Quantity',
#  'P2218': 'Quantity',
#  'P2219': 'Quantity',
#  'P2220': 'Quantity',
#  'P2221': 'Quantity',
#  'P2222': 'Quantity',
#  'P2223': 'Quantity',
#  'P2225': 'Quantity',
#  'P2226': 'Quantity',
#  'P2227': 'Quantity',
#  'P2228': 'Quantity',
#  'P2229': 'Quantity',
#  'P2230': 'Quantity',
#  'P2231': 'Quantity',
#  'P2232': 'Quantity',
#  'P2233': 'Quantity',
#  'P2234': 'Quantity',
#  'P2240': 'Quantity',
#  'P2243': 'Quantity',
#  'P2244': 'Quantity',
#  'P2248': 'Quantity',
#  'P2250': 'Quantity',
#  'P2254': 'Quantity',
#  'P1081': 'Quantity',
#  'P1082': 'Quantity',
#  'P1083': 'Quantity',
#  'P1086': 'Quantity',
#  'P1087': 'Quantity',
#  'P1088': 'Quantity',
#  'P1090': 'Quantity',
#  'P1092': 'Quantity',
#  'P1093': 'Quantity',
#  'P1096': 'Quantity',
#  'P1097': 'Quantity',
#  'P1098': 'Quantity',
#  'P1099': 'Quantity',
#  'P1100': 'Quantity',
#  'P1101': 'Quantity',
#  'P1102': 'Quantity',
#  'P1103': 'Quantity',
#  'P1104': 'Quantity',
#  'P1106': 'Quantity',
#  'P1107': 'Quantity',
#  'P1108': 'Quantity',
#  'P1109': 'Quantity',
#  'P1110': 'Quantity',
#  'P1111': 'Quantity',
#  'P1113': 'Quantity',
#  'P1114': 'Quantity',
#  'P1117': 'Quantity',
#  'P1120': 'Quantity',
#  'P1121': 'Quantity',
#  'P1122': 'Quantity',
#  'P1123': 'Quantity',
#  'P1125': 'Quantity',
#  'P1126': 'Quantity',
#  'P1127': 'Quantity',
#  'P1128': 'Quantity',
#  'P1129': 'Quantity',
#  'P1132': 'Quantity',
#  'P1139': 'Quantity',
#  'P1141': 'Quantity',
#  'P1148': 'Quantity',
#  'P1164': 'Quantity',
#  'P1174': 'Quantity',
#  'P1181': 'Quantity',
#  'P1193': 'Quantity',
#  'P1198': 'Quantity',
#  'P1215': 'Quantity',
#  'P1247': 'Quantity',
#  'P1279': 'Quantity',
#  'P1295': 'Quantity',
#  'P1301': 'Quantity',
#  'P1314': 'Quantity',
#  'P1339': 'Quantity',
#  'P1342': 'Quantity',
#  'P1345': 'Quantity',
#  'P1350': 'Quantity',
#  'P1351': 'Quantity',
#  'P1352': 'Quantity',
#  'P1355': 'Quantity',
#  'P1356': 'Quantity',
#  'P1357': 'Quantity',
#  'P1358': 'Quantity',
#  'P1359': 'Quantity',
#  'P1373': 'Quantity',
#  'P1390': 'Quantity',
#  'P1410': 'Quantity',
#  'P1418': 'Quantity',
#  'P1436': 'Quantity',
#  'P1446': 'Quantity',
#  'P1457': 'Quantity',
#  'P1458': 'Quantity',
#  'P1470': 'Quantity',
#  'P1538': 'Quantity',
#  'P1539': 'Quantity',
#  'P1540': 'Quantity',
#  'P1548': 'Quantity',
#  'P1561': 'Quantity',
#  'P1590': 'Quantity',
#  'P1603': 'Quantity',
#  'P1641': 'Quantity',
#  'P1661': 'Quantity',
#  'P1674': 'Quantity',
#  'P1675': 'Quantity',
#  'P1676': 'Quantity',
#  'P1689': 'Quantity',
#  'P1697': 'Quantity',
#  'P1725': 'Quantity',
#  'P1752': 'Quantity',
#  'P1831': 'Quantity',
#  'P1833': 'Quantity',
#  'P1867': 'Quantity',
#  'P1868': 'Quantity',
#  'P1872': 'Quantity',
#  'P1873': 'Quantity',
#  'P1971': 'Quantity',
#  'P2021': 'Quantity',
#  'P2043': 'Quantity',
#  'P2044': 'Quantity',
#  'P2045': 'Quantity',
#  'P2046': 'Quantity',
#  'P2047': 'Quantity',
#  'P5069': 'Quantity',
#  'P5071': 'Quantity',
#  'P5141': 'Quantity',
#  'P5167': 'Quantity',
#  'P5205': 'Quantity',
#  'P5230': 'Quantity',
#  'P5281': 'Quantity',
#  'P5348': 'Quantity',
#  'P5349': 'Quantity',
#  'P5427': 'Quantity',
#  'P5428': 'Quantity',
#  'P5436': 'Quantity',
#  'P5447': 'Quantity',
#  'P5448': 'Quantity',
#  'P5474': 'Quantity',
#  'P5479': 'Quantity',
#  'P5480': 'Quantity',
#  'P5481': 'Quantity',
#  'P5483': 'Quantity',
#  'P5520': 'Quantity',
#  'P5524': 'Quantity',
#  'P5526': 'Quantity',
#  'P5529': 'Quantity',
#  'P5575': 'Quantity',
#  'P5582': 'Quantity',
#  'P5592': 'Quantity',
#  'P5593': 'Quantity',
#  'P5594': 'Quantity',
#  'P5595': 'Quantity',
#  'P5596': 'Quantity',
#  'P5608': 'Quantity',
#  'P5624': 'Quantity',
#  'P5630': 'Quantity',
#  'P5668': 'Quantity',
#  'P5669': 'Quantity',
#  'P5670': 'Quantity',
#  'P5672': 'Quantity',
#  'P5673': 'Quantity',
#  'P5674': 'Quantity',
#  'P5675': 'Quantity',
#  'P5676': 'Quantity',
#  'P5677': 'Quantity',
#  'P5678': 'Quantity',
#  'P5679': 'Quantity',
#  'P5681': 'Quantity',
#  'P5682': 'Quantity',
#  'P5685': 'Quantity',
#  'P5706': 'Quantity',
#  'P5708': 'Quantity',
#  'P5709': 'Quantity',
#  'P5811': 'Quantity',
#  'P5822': 'Quantity',
#  'P5893': 'Quantity',
#  'P5894': 'Quantity',
#  'P5895': 'Quantity',
#  'P5896': 'Quantity',
#  'P5897': 'Quantity',
#  'P5898': 'Quantity',
#  'P5899': 'Quantity',
#  'P5900': 'Quantity',
#  'P5929': 'Quantity',
#  'P5947': 'Quantity',
#  'P5982': 'Quantity',
#  'P5991': 'Quantity',
#  'P5992': 'Quantity',
#  'P5993': 'Quantity',
#  'P6000': 'Quantity',
#  'P6014': 'Quantity',
#  'P6069': 'Quantity',
#  'P6073': 'Quantity',
#  'P6075': 'Quantity',
#  'P6076': 'Quantity',
#  'P6088': 'Quantity',
#  'P6089': 'Quantity',
#  'P6125': 'Quantity',
#  'P6249': 'Quantity',
#  'P6257': 'Quantity',
#  'P6258': 'Quantity',
#  'P6260': 'Quantity',
#  'P6261': 'Quantity',
#  'P6272': 'Quantity',
#  'P6274': 'Quantity',
#  'P6343': 'Quantity',
#  'P6344': 'Quantity',
#  'P6354': 'Quantity',
#  'P6438': 'Quantity',
#  'P6497': 'Quantity',
#  'P6498': 'Quantity',
#  'P6499': 'Quantity',
#  'P6509': 'Quantity',
#  'P6510': 'Quantity',
#  'P6543': 'Quantity',
#  'P6544': 'Quantity',
#  'P6545': 'Quantity',
#  'P6546': 'Quantity',
#  'P6547': 'Quantity',
#  'P6570': 'Quantity',
#  'P6589': 'Quantity',
#  'P6590': 'Quantity',
#  'P6591': 'Quantity',
#  'P2257': 'Quantity',
#  'P2260': 'Quantity',
#  'P2261': 'Quantity',
#  'P2262': 'Quantity',
#  'P2284': 'Quantity',
#  'P2292': 'Quantity',
#  'P2294': 'Quantity',
#  'P2295': 'Quantity',
#  'P2296': 'Quantity',
#  'P2297': 'Quantity',
#  'P2299': 'Quantity',
#  'P2300': 'Quantity',
#  'P2312': 'Quantity',
#  'P2313': 'Quantity',
#  'P2320': 'Quantity',
#  'P2324': 'Quantity',
#  'P2325': 'Quantity',
#  'P2351': 'Quantity',
#  'P2362': 'Quantity',
#  'P2370': 'Quantity',
#  'P2374': 'Quantity',
#  'P2386': 'Quantity',
#  'P2402': 'Quantity',
#  'P2403': 'Quantity',
#  'P2404': 'Quantity',
#  'P2405': 'Quantity',
#  'P2406': 'Quantity',
#  'P2407': 'Quantity',
#  'P2415': 'Quantity',
#  'P2430': 'Quantity',
#  'P2436': 'Quantity',
#  'P2437': 'Quantity',
#  'P2442': 'Quantity',
#  'P2527': 'Quantity',
#  'P2528': 'Quantity',
#  'P2532': 'Quantity',
#  'P2542': 'Quantity',
#  'P2547': 'Quantity',
#  'P2555': 'Quantity',
#  'P2556': 'Quantity',
#  'P2557': 'Quantity',
#  'P2565': 'Quantity',
#  'P2573': 'Quantity',
#  'P2583': 'Quantity',
#  'P2595': 'Quantity',
#  'P2599': 'Quantity',
#  'P2610': 'Quantity',
#  'P2630': 'Quantity',
#  'P2635': 'Quantity',
#  'P2645': 'Quantity',
#  'P2658': 'Quantity',
#  'P2659': 'Quantity',
#  'P2660': 'Quantity',
#  'P2661': 'Quantity',
#  'P2662': 'Quantity',
#  'P2663': 'Quantity',
#  'P2664': 'Quantity',
#  'P2665': 'Quantity',
#  'P2710': 'Quantity',
#  'P2712': 'Quantity',
#  'P2717': 'Quantity',
#  'P2718': 'Quantity',
#  'P2769': 'Quantity',
#  'P2781': 'Quantity',
#  'P2787': 'Quantity',
#  'P2790': 'Quantity',
#  'P2791': 'Quantity',
#  'P2793': 'Quantity',
#  'P2797': 'Quantity',
#  'P2803': 'Quantity',
#  'P2806': 'Quantity',
#  'P2807': 'Quantity',
#  'P2808': 'Quantity',
#  'P2834': 'Quantity',
#  'P2835': 'Quantity',
#  'P2836': 'Quantity',
#  'P2844': 'Quantity',
#  'P2854': 'Quantity',
#  'P2855': 'Quantity',
#  'P2873': 'Quantity',
#  'P2884': 'Quantity',
#  'P2895': 'Quantity',
#  'P2896': 'Quantity',
#  'P2899': 'Quantity',
#  'P2907': 'Quantity',
#  'P2911': 'Quantity',
#  'P2923': 'Quantity',
#  'P2927': 'Quantity',
#  'P2928': 'Quantity',
#  'P2929': 'Quantity',
#  'P2955': 'Quantity',
#  'P2957': 'Quantity',
#  'P2993': 'Quantity',
#  'P2997': 'Quantity',
#  'P2998': 'Quantity',
#  'P2999': 'Quantity',
#  'P3000': 'Quantity',
#  'P3001': 'Quantity',
#  'P3013': 'Quantity',
#  'P3020': 'Quantity',
#  'P2756': 'Item',
#  'P2758': 'Item',
#  'P2770': 'Item',
#  'P2784': 'Item',
#  'P2789': 'Item',
#  'P2813': 'Item',
#  'P2817': 'Item',
#  'P2820': 'Item',
#  'P2821': 'Item',
#  'P2822': 'Item',
#  'P2825': 'Item',
#  'P2827': 'Item',
#  'P2828': 'Item',
#  'P2831': 'Item',
#  'P2838': 'Item',
#  'P2839': 'Item',
#  'P2841': 'Item',
#  'P2842': 'Item',
#  'P2846': 'Item',
#  'P2848': 'Item',
#  'P2849': 'Item',
#  'P2851': 'Item',
#  'P2852': 'Item',
#  'P2853': 'Item',
#  'P2860': 'Item',
#  'P2868': 'Item',
#  'P2869': 'Item',
#  'P2872': 'Item',
#  'P2875': 'Item',
#  'P2876': 'Item',
#  'P2881': 'Item',
#  'P2882': 'Item',
#  'P2894': 'Item',
#  'P2912': 'Item',
#  'P2922': 'Item',
#  'P2925': 'Item',
#  'P2935': 'Item',
#  'P2936': 'Item',
#  'P2937': 'Item',
#  'P2959': 'Item',
#  'P2962': 'Item',
#  'P2964': 'Item',
#  'P2974': 'Item',
#  'P2975': 'Item',
#  'P2976': 'Item',
#  'P2978': 'Item',
#  'P2989': 'Item',
#  'P2992': 'Item',
#  'P3005': 'Item',
#  'P3014': 'Item',
#  'P3015': 'Item',
#  'P3018': 'Item',
#  'P3019': 'Item',
#  'P3022': 'Item',
#  'P3025': 'Item',
#  'P3026': 'Item',
#  'P3027': 'Item',
#  'P3028': 'Item',
#  'P3032': 'Item',
#  'P3033': 'Item',
#  'P3037': 'Item',
#  'P3075': 'Item',
#  'P3080': 'Item',
#  'P3081': 'Item',
#  'P3082': 'Item',
#  'P3085': 'Item',
#  'P3091': 'Item',
#  'P3092': 'Item',
#  'P3093': 'Item',
#  'P3094': 'Item',
#  'P3095': 'Item',
#  'P3096': 'Item',
#  'P3103': 'Item',
#  'P3113': 'Item',
#  'P3137': 'Item',
#  'P3148': 'Item',
#  'P3149': 'Item',
#  'P3150': 'Item',
#  'P3156': 'Item',
#  'P3158': 'Item',
#  'P3161': 'Item',
#  'P3173': 'Item',
#  'P3174': 'Item',
#  'P3179': 'Item',
#  'P3189': 'Item',
#  'P3190': 'Item',
#  'P3195': 'Item',
#  'P3205': 'Item',
#  'P3216': 'Item',
#  'P3259': 'Item',
#  'P3261': 'Item',
#  'P3262': 'Item',
#  'P3263': 'Item',
#  'P3264': 'Item',
#  'P3274': 'Item',
#  'P3275': 'Item',
#  'P3279': 'Item',
#  'P3294': 'Item',
#  'P3300': 'Item',
#  'P3301': 'Item',
#  'P6': 'Item',
#  'P16': 'Item',
#  'P17': 'Item',
#  'P19': 'Item',
#  'P20': 'Item',
#  'P21': 'Item',
#  'P22': 'Item',
#  'P25': 'Item',
#  'P26': 'Item',
#  'P27': 'Item',
#  'P30': 'Item',
#  'P31': 'Item',
#  'P35': 'Item',
#  'P36': 'Item',
#  'P37': 'Item',
#  'P38': 'Item',
#  'P39': 'Item',
#  'P40': 'Item',
#  'P47': 'Item',
#  'P50': 'Item',
#  'P53': 'Item',
#  'P54': 'Item',
#  'P57': 'Item',
#  'P58': 'Item',
#  'P59': 'Item',
#  'P61': 'Item',
#  'P65': 'Item',
#  'P66': 'Item',
#  'P69': 'Item',
#  'P78': 'Item',
#  'P81': 'Item',
#  'P84': 'Item',
#  'P85': 'Item',
#  'P86': 'Item',
#  'P87': 'Item',
#  'P88': 'Item',
#  'P91': 'Item',
#  'P92': 'Item',
#  'P97': 'Item',
#  'P98': 'Item',
#  'P101': 'Item',
#  'P102': 'Item',
#  'P103': 'Item',
#  'P105': 'Item',
#  'P106': 'Item',
#  'P108': 'Item',
#  'P110': 'Item',
#  'P730': 'Point in time',
#  'P746': 'Point in time',
#  'P813': 'Point in time',
#  'P1191': 'Point in time',
#  'P1249': 'Point in time',
#  'P1317': 'Point in time',
#  'P1319': 'Point in time',
#  'P1326': 'Point in time',
#  'P1619': 'Point in time',
#  'P1636': 'Point in time',
#  'P1734': 'Point in time',
#  'P2031': 'Point in time',
#  'P2032': 'Point in time',
#  'P2285': 'Point in time',
#  'P2310': 'Point in time',
#  'P2311': 'Point in time',
#  'P2669': 'Point in time',
#  'P2754': 'Point in time',
#  'P2913': 'Point in time',
#  'P2960': 'Point in time',
#  'P3893': 'Point in time',
#  'P3999': 'Point in time',
#  'P4566': 'Point in time',
#  'P4602': 'Point in time',
#  'P5017': 'Point in time',
#  'P5204': 'Point in time',
#  'P6949': 'Point in time',
#  'P7103': 'Point in time',
#  'P7104': 'Point in time',
#  'P7124': 'Point in time',
#  'P7125': 'Point in time',
#  'P7295': 'Point in time',
#  'P7588': 'Point in time',
#  'P7589': 'Point in time',
#  'P8554': 'Point in time',
#  'P8555': 'Point in time',
#  'P8556': 'Point in time',
#  'P9052': 'Point in time',
#  'P9448': 'Point in time',
#  'P9667': 'Point in time',
#  'P9905': 'Point in time',
#  'P9946': 'Point in time',
#  'P10135': 'Point in time',
#  'P10673': 'Point in time',
#  'P10786': 'Point in time',
#  'P11140': 'Point in time',
#  'P12044': 'Point in time',
#  'P12413': 'Point in time',
#  'P12506': 'Point in time',
#  'P12643': 'Point in time',
#  'P13794': 'Point in time',
#  'P13926': 'Point in time',
#  'P14027': 'Point in time',
#  'P6639': 'Quantity',
#  'P6695': 'Quantity',
#  'P6697': 'Quantity',
#  'P6707': 'Quantity',
#  'P6708': 'Quantity',
#  'P6710': 'Quantity',
#  'P6711': 'Quantity',
#  'P6753': 'Quantity',
#  'P6757': 'Quantity',
#  'P6789': 'Quantity',
#  'P6790': 'Quantity',
#  'P6794': 'Quantity',
#  'P6801': 'Quantity',
#  'P6826': 'Quantity',
#  'P6856': 'Quantity',
#  'P6876': 'Quantity',
#  'P6879': 'Quantity',
#  'P6897': 'Quantity',
#  'P7015': 'Quantity',
#  'P7079': 'Quantity',
#  'P7080': 'Quantity',
#  'P7083': 'Quantity',
#  'P7256': 'Quantity',
#  'P7297': 'Quantity',
#  'P7316': 'Quantity',
#  'P7328': 'Quantity',
#  'P7379': 'Quantity',
#  'P7391': 'Quantity',
#  'P7422': 'Quantity',
#  'P7443': 'Quantity',
#  'P7462': 'Quantity',
#  'P7527': 'Quantity',
#  'P7584': 'Quantity',
#  'P7668': 'Quantity',
#  'P7725': 'Quantity',
#  'P7770': 'Quantity',
#  'P7787': 'Quantity',
#  'P7862': 'Quantity',
#  'P7863': 'Quantity',
#  'P7887': 'Quantity',
#  'P7971': 'Quantity',
#  'P8010': 'Quantity',
#  'P8011': 'Quantity',
#  'P8049': 'Quantity',
#  'P8093': 'Quantity',
#  'P8208': 'Quantity',
#  'P8247': 'Quantity',
#  'P8275': 'Quantity',
#  'P8328': 'Quantity',
#  'P8330': 'Quantity',
#  'P8340': 'Quantity',
#  'P8368': 'Quantity',
#  'P8398': 'Quantity',
#  'P8465': 'Quantity',
#  'P8466': 'Quantity',
#  'P8476': 'Quantity',
#  'P8477': 'Quantity',
#  'P8497': 'Quantity',
#  'P8594': 'Quantity',
#  'P8597': 'Quantity',
#  'P8620': 'Quantity',
#  'P8621': 'Quantity',
#  'P8622': 'Quantity',
#  'P8628': 'Quantity',
#  'P8682': 'Quantity',
#  'P8683': 'Quantity',
#  'P8684': 'Quantity',
#  'P8685': 'Quantity',
#  'P8687': 'Quantity',
#  'P8733': 'Quantity',
#  'P8751': 'Quantity',
#  'P8753': 'Quantity',
#  'P8757': 'Quantity',
#  'P8763': 'Quantity',
#  'P8843': 'Quantity',
#  'P8876': 'Quantity',
#  'P8884': 'Quantity',
#  'P8887': 'Quantity',
#  'P8890': 'Quantity',
#  'P8891': 'Quantity',
#  'P8986': 'Quantity',
#  'P9077': 'Quantity',
#  'P9107': 'Quantity',
#  'P9140': 'Quantity',
#  'P9180': 'Quantity',
#  'P9184': 'Quantity',
#  'P9188': 'Quantity',
#  'P9190': 'Quantity',
#  'P9217': 'Quantity',
#  'P9220': 'Quantity',
#  'P9225': 'Quantity',
#  'P9238': 'Quantity',
#  'P9274': 'Quantity',
#  'P9279': 'Quantity',
#  'P9396': 'Quantity',
#  'P9440': 'Quantity',
#  'P9496': 'Quantity',
#  'P9548': 'Quantity',
#  'P9740': 'Quantity',
#  'P9924': 'Quantity',
#  'P3036': 'Quantity',
#  'P3039': 'Quantity',
#  'P3041': 'Quantity',
#  'P3063': 'Quantity',
#  'P3070': 'Quantity',
#  'P3071': 'Quantity',
#  'P3078': 'Quantity',
#  'P3086': 'Quantity',
#  'P3087': 'Quantity',
#  'P3157': 'Quantity',
#  'P3251': 'Quantity',
#  'P3252': 'Quantity',
#  'P3253': 'Quantity',
#  'P3260': 'Quantity',
#  'P3270': 'Quantity',
#  'P3271': 'Quantity',
#  'P3337': 'Quantity',
#  'P3362': 'Quantity',
#  'P3387': 'Quantity',
#  'P3395': 'Quantity',
#  'P3439': 'Quantity',
#  'P3457': 'Quantity',
#  'P3465': 'Quantity',
#  'P3485': 'Quantity',
#  'P3486': 'Quantity',
#  'P3487': 'Quantity',
#  'P3488': 'Quantity',
#  'P3492': 'Quantity',
#  'P3529': 'Quantity',
#  'P3530': 'Quantity',
#  'P3559': 'Quantity',
#  'P3575': 'Quantity',
#  'P3618': 'Quantity',
#  'P3629': 'Quantity',
#  'P3737': 'Quantity',
#  'P3738': 'Quantity',
#  'P3740': 'Quantity',
#  'P3744': 'Quantity',
#  'P3792': 'Quantity',
#  'P3840': 'Quantity',
#  'P3864': 'Quantity',
#  'P3872': 'Quantity',
#  'P3886': 'Quantity',
#  'P3891': 'Quantity',
#  'P3934': 'Quantity',
#  'P3983': 'Quantity',
#  'P4010': 'Quantity',
#  'P4036': 'Quantity',
#  'P4080': 'Quantity',
#  'P4103': 'Quantity',
#  'P4105': 'Quantity',
#  'P4131': 'Quantity',
#  'P4135': 'Quantity',
#  'P4137': 'Quantity',
#  'P4140': 'Quantity',
#  'P4153': 'Quantity',
#  'P4163': 'Quantity',
#  'P4176': 'Quantity',
#  'P4183': 'Quantity',
#  'P4184': 'Quantity',
#  'P4214': 'Quantity',
#  'P4218': 'Quantity',
#  'P4242': 'Quantity',
#  'P4250': 'Quantity',
#  'P4253': 'Quantity',
#  'P4268': 'Quantity',
#  'P4269': 'Quantity',
#  'P4295': 'Quantity',
#  'P4296': 'Quantity',
#  'P4341': 'Quantity',
#  'P4350': 'Quantity',
#  'P4403': 'Quantity',
#  'P4441': 'Quantity',
#  'P4442': 'Quantity',
#  'P4445': 'Quantity',
#  'P4447': 'Quantity',
#  'P4448': 'Quantity',
#  'P4500': 'Quantity',
#  'P4501': 'Quantity',
#  'P4511': 'Quantity',
#  'P4519': 'Quantity',
#  'P4714': 'Quantity',
#  'P4815': 'Quantity',
#  'P4825': 'Quantity',
#  'P4826': 'Quantity',
#  'P4841': 'Quantity',
#  'P4851': 'Quantity',
#  'P4876': 'Quantity',
#  'P4895': 'Quantity',
#  'P4909': 'Quantity',
#  'P4912': 'Quantity',
#  'P4999': 'Quantity',
#  'P5022': 'Quantity',
#  'P5027': 'Quantity',
#  'P5043': 'Quantity',
#  'P5044': 'Quantity',
#  'P5045': 'Quantity',
#  'P5065': 'Quantity',
#  'P5066': 'Quantity',
#  'P5067': 'Quantity',
#  'P2329': 'Item',
#  'P2341': 'Item',
#  'P2348': 'Item',
#  'P2352': 'Item',
#  'P2353': 'Item',
#  'P2354': 'Item',
#  'P2358': 'Item',
#  'P2359': 'Item',
#  'P2360': 'Item',
#  'P2361': 'Item',
#  'P2363': 'Item',
#  'P2365': 'Item',
#  'P2366': 'Item',
#  'P2371': 'Item',
#  'P2375': 'Item',
#  'P2376': 'Item',
#  'P2377': 'Item',
#  'P2378': 'Item',
#  'P2379': 'Item',
#  'P2384': 'Item',
#  'P2388': 'Item',
#  'P2389': 'Item',
#  'P2392': 'Item',
#  'P2396': 'Item',
#  'P2408': 'Item',
#  'P2414': 'Item',
#  'P2416': 'Item',
#  'P2417': 'Item',
#  'P2429': 'Item',
#  'P2433': 'Item',
#  'P2438': 'Item',
#  'P2443': 'Item',
#  'P2444': 'Item',
#  'P2445': 'Item',
#  'P2453': 'Item',
#  'P2462': 'Item',
#  'P2499': 'Item',
#  'P2500': 'Item',
#  'P2501': 'Item',
#  'P2502': 'Item',
#  'P2505': 'Item',
#  'P2507': 'Item',
#  'P2512': 'Item',
#  'P2515': 'Item',
#  'P2517': 'Item',
#  'P2522': 'Item',
#  'P2541': 'Item',
#  'P2545': 'Item',
#  'P2546': 'Item',
#  'P2548': 'Item',
#  'P2550': 'Item',
#  'P2551': 'Item',
#  'P2553': 'Item',
#  'P2554': 'Item',
#  'P2560': 'Item',
#  'P2563': 'Item',
#  'P2564': 'Item',
#  'P2567': 'Item',
#  'P2568': 'Item',
#  'P2571': 'Item',
#  'P2575': 'Item',
#  'P2577': 'Item',
#  'P2578': 'Item',
#  'P2579': 'Item',
#  'P2587': 'Item',
#  'P2591': 'Item',
#  'P2596': 'Item',
#  'P2597': 'Item',
#  'P2614': 'Item',
#  'P2629': 'Item',
#  'P2632': 'Item',
#  'P2633': 'Item',
#  'P2634': 'Item',
#  'P2637': 'Item',
#  'P2643': 'Item',
#  'P2647': 'Item',
#  'P2650': 'Item',
#  'P2652': 'Item',
#  'P2667': 'Item',
#  'P2668': 'Item',
#  'P2670': 'Item',
#  'P2673': 'Item',
#  'P2674': 'Item',
#  'P2675': 'Item',
#  'P2679': 'Item',
#  'P2680': 'Item',
#  'P2681': 'Item',
#  'P2682': 'Item',
#  'P2684': 'Item',
#  'P2695': 'Item',
#  'P2700': 'Item',
#  'P2701': 'Item',
#  'P2702': 'Item',
#  'P2715': 'Item',
#  'P2737': 'Item',
#  'P2738': 'Item',
#  'P2739': 'Item',
#  'P2743': 'Item',
#  'P2746': 'Item',
#  'P2747': 'Item',
#  'P569': 'Point in time',
#  'P570': 'Point in time',
#  'P571': 'Point in time',
#  'P574': 'Point in time',
#  'P575': 'Point in time',
#  'P576': 'Point in time',
#  'P577': 'Point in time',
#  'P578': 'Point in time',
#  'P580': 'Point in time',
#  'P582': 'Point in time',
#  'P585': 'Point in time',
#  'P606': 'Point in time',
#  'P619': 'Point in time',
#  'P620': 'Point in time',
#  'P621': 'Point in time',
#  'P622': 'Point in time',
#  'P729': 'Point in time',
#  'P9927': 'Quantity',
#  'P9998': 'Quantity',
#  'P10091': 'Quantity',
#  'P10107': 'Quantity',
#  'P10209': 'Quantity',
#  'P10263': 'Quantity',
#  'P10273': 'Quantity',
#  'P10300': 'Quantity',
#  'P10316': 'Quantity',
#  'P10322': 'Quantity',
#  'P10367': 'Quantity',
#  'P10610': 'Quantity',
#  'P10622': 'Quantity',
#  'P10623': 'Quantity',
#  'P10636': 'Quantity',
#  'P10640': 'Quantity',
#  'P10648': 'Quantity',
#  'P10649': 'Quantity',
#  'P10650': 'Quantity',
#  'P10651': 'Quantity',
#  'P10659': 'Quantity',
#  'P10676': 'Quantity',
#  'P10681': 'Quantity',
#  'P10685': 'Quantity',
#  'P10751': 'Quantity',
#  'P10752': 'Quantity',
#  'P10756': 'Quantity',
#  'P10764': 'Quantity',
#  'P10768': 'Quantity',
#  'P10795': 'Quantity',
#  'P10814': 'Quantity',
#  'P10823': 'Quantity',
#  'P11035': 'Quantity',
#  'P11081': 'Quantity',
#  'P11200': 'Quantity',
#  'P11412': 'Quantity',
#  'P11413': 'Quantity',
#  'P11547': 'Quantity',
#  'P11593': 'Quantity',
#  'P11698': 'Quantity',
#  'P11796': 'Quantity',
#  'P11813': 'Quantity',
#  'P11899': 'Quantity',
#  'P12004': 'Quantity',
#  'P12221': 'Quantity',
#  'P12417': 'Quantity',
#  'P12432': 'Quantity',
#  'P12469': 'Quantity',
#  'P12470': 'Quantity',
#  'P12471': 'Quantity',
#  'P12549': 'Quantity',
#  'P12642': 'Quantity',
#  'P12649': 'Quantity',
#  'P12651': 'Quantity',
#  'P12655': 'Quantity',
#  'P12712': 'Quantity',
#  'P12853': 'Quantity',
#  'P12919': 'Quantity',
#  'P12956': 'Quantity',
#  'P13048': 'Quantity',
#  'P13171': 'Quantity',
#  'P13238': 'Quantity',
#  'P13251': 'Quantity',
#  'P13361': 'Quantity',
#  'P13413': 'Quantity',
#  'P13414': 'Quantity',
#  'P13430': 'Quantity',
#  'P13522': 'Quantity',
#  'P13525': 'Quantity',
#  'P13564': 'Quantity',
#  'P13571': 'Quantity',
#  'P13635': 'Quantity',
#  'P13668': 'Quantity',
#  'P13745': 'Quantity',
#  'P13749': 'Quantity',
#  'P13787': 'Quantity',
#  'P13788': 'Quantity',
#  'P13828': 'Quantity',
#  'P13903': 'Quantity',
#  'P14028': 'Quantity',
#  'P14047': 'Quantity',
#  'P14052': 'Quantity',
#  'P14143': 'Quantity',
#  ...}

# %%
constraint_dict["P50"]
# Out:
# {'Value-type constraint': ['Q5',
#   'Q11660',
#   'Q43229',
#   'Q61002',
#   'Q95074',
#   'Q215627',
#   'Q16334295',
#   'Q24229398',
#   'Q60557912',
#   'Q75855169',
#   'Q78056559',
#   'Q107307291'],
#  'Subject type constraint': ['Q571',
#   'Q7366',
#   'Q49848',
#   'Q74574',
#   'Q277759',
#   'Q386724',
#   'Q628523',
#   'Q2668072',
#   'Q3026787',
#   'Q3331189',
#   'Q15306849',
#   'Q15938550',
#   'Q17489659',
#   'Q55760865']}

# %%
wo_constraint = []
for prop in constraint_dict:
    if (
        len(constraint_dict[prop]["Value-type constraint"]) == 0
        and len(constraint_dict[prop]["Subject type constraint"]) == 0
    ):
        wo_constraint.append(prop)
len(wo_constraint)
# Out:
# 587

# %%
quantity_props = []
time_props = []
other_props = []
for prop in wo_constraint:
    if PROP_2_DATA_TYPE[prop] == "Quantity":
        quantity_props.append(prop)
    elif PROP_2_DATA_TYPE[prop] == "Point in time":
        time_props.append(prop)
    else:
        other_props.append(prop)

        # print(PROP_2_LABEL[prop])
len(time_props), len(quantity_props), len(other_props)
# Out:
# (29, 299, 259)

# %%
sum((28, 295, 258))
# Out:
# 581

# %%
for prop in constraint_dict:
    if PROP_2_DATA_TYPE[prop] == "Point in time":
        constraint_dict[prop]["Value-type constraint"].append("Q186408")

    elif PROP_2_DATA_TYPE[prop] == "Quantity":
        constraint_dict[prop]["Value-type constraint"].append("Q309314")

# %%
wo_constraint = []
for prop in constraint_dict:
    if (
        len(constraint_dict[prop]["Value-type constraint"]) == 0
        and len(constraint_dict[prop]["Subject type constraint"]) == 0
    ):
        wo_constraint.append(prop)
len(wo_constraint)
# Out:
# 259

# %%
wo_constraint = []
for prop in constraint_dict:
    if len(constraint_dict[prop]["Value-type constraint"]) == 0:
        constraint_dict[prop]["Value-type constraint"] = ["ANY"]
    if len(constraint_dict[prop]["Subject type constraint"]) == 0:
        constraint_dict[prop]["Subject type constraint"] = ["ANY"]
len(wo_constraint)
# Out:
# 0

# %%
wo_constraint = []
for prop in constraint_dict:
    if (
        len(constraint_dict[prop]["Value-type constraint"]) == 0
        and len(constraint_dict[prop]["Subject type constraint"]) == 0
    ):
        wo_constraint.append(prop)
len(wo_constraint)
# Out:
# 0

# %%
with open(ONTOLOGY_MAPPINGS_DIR + "prop2constraints.json", "w") as f:
    json.dump(constraint_dict, f)

# %%
with open(ONTOLOGY_MAPPINGS_DIR + "prop2constraints.json", "r") as f:
    constraint_dict = json.load(f)

# %%
with open(ONTOLOGY_MAPPINGS_DIR + "prop2data_type.json", "r") as f:
    PROP_2_DATA_TYPE = json.load(f)

# %% [markdown]
# ## Colecting entities' metadata

# %%
entities = set()
for prop, constraint in constraint_dict.items():

    for const_type in constraint:
        for entity in constraint[const_type]:
            entities.add(entity)
entities = list(entities)

# %%
len(entities)
# Out:
# 3686

# %% [markdown]
# ### Collecting entities' hierarchy of superclasses

# %%
@retry(wait=wait_random_exponential(multiplier=1, max=60))
def get_subclass_hierarchy(entity_id):
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

    # SPARQL query to get all subclasses (direct and indirect) of the given entity
    query = f"""
      SELECT DISTINCT ?subclass ?subclassLabel WHERE {{
          {{
              wd:{entity_id} wdt:P31/wdt:P279* ?subclass.
          }}
            UNION
          {{
              wd:{entity_id} wdt:P279* ?subclass.
          }}
      }}
      """
    # SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}

    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)

    results = sparql.query().convert()

    subclass_hierarchy = []

    for result in results["results"]["bindings"]:
        subclass_id = result["subclass"]["value"].split("/")[-1]
        subclass_hierarchy.append(subclass_id)

    return subclass_hierarchy


ENTITY_2_HIERARCHY = {}
for entity_id in tqdm(entities):
    hierarchy = get_subclass_hierarchy(entity_id)
    ENTITY_2_HIERARCHY[entity_id] = hierarchy

len(ENTITY_2_HIERARCHY)
# Out:
# 100%|██████████| 3686/3686 [25:55<00:00,  2.37it/s]
# 3686

# %%
ents = []
for item in ENTITY_2_HIERARCHY.values():
    ents.extend(item)
len(set(ents)), len(entities)
# Out:
# (7648, 3686)

# %%
# leaving only entity types that are used in constraints
for entity in tqdm(ENTITY_2_HIERARCHY):
    filtered_super_entities = [
        item for item in ENTITY_2_HIERARCHY[entity] if item in entities
    ]
    ENTITY_2_HIERARCHY[entity] = filtered_super_entities
# Out:
# 100%|██████████| 3686/3686 [00:04<00:00, 836.66it/s]

# %%
ents = []
for item in ENTITY_2_HIERARCHY.values():
    ents.extend(item)
len(set(ents)), len(entities)
# Out:
# (3686, 3686)

# %%
with open(ONTOLOGY_MAPPINGS_DIR + "entity_hierarchy.json", "w") as f:
    json.dump(ENTITY_2_HIERARCHY, f)

# %% [markdown]
# ### Collecting entity types' labels

# %%
BATCH_SIZE = 50


@retry(wait=wait_random_exponential(multiplier=1, max=60))
def fetch_labels(batch):
    entity_values = " ".join(f"wd:{entity}" for entity in batch)

    query = f"""
    SELECT ?entity ?entityLabel WHERE {{
      VALUES ?entity {{ {entity_values} }}
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en". }}
    }}
    """

    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)

    try:
        results = sparql.query().convert()
        return {
            result["entity"]["value"]
            .split("/")[-1]: result.get("entityLabel", {})
            .get("value", "No label")
            for result in results["results"]["bindings"]
        }
    except Exception as e:
        print(f"Error with batch {batch[:5]}...: {e}")
        return {}


ENTITY_2_LABEL = {}

for i in range(0, len(entities), BATCH_SIZE):
    batch = entities[i : i + BATCH_SIZE]
    print(f"Processing batch {i // BATCH_SIZE + 1}/{(len(entities) // BATCH_SIZE) + 1}")

    labels = fetch_labels(batch)
    ENTITY_2_LABEL.update(labels)

# for entity, label in all_labels.items():
#     print(f"{entity}: {label}")
# Out:
# Processing batch 1/74
# Processing batch 2/74
# Processing batch 3/74
# Processing batch 4/74
# Processing batch 5/74
# Processing batch 6/74
# Processing batch 7/74
# Processing batch 8/74
# Processing batch 9/74
# Processing batch 10/74
# Processing batch 11/74
# Processing batch 12/74
# Processing batch 13/74
# Processing batch 14/74
# Processing batch 15/74
# Processing batch 16/74
# Processing batch 17/74
# Processing batch 18/74
# Processing batch 19/74
# Processing batch 20/74
# Processing batch 21/74
# Processing batch 22/74
# Processing batch 23/74
# Processing batch 24/74
# Processing batch 25/74
# Processing batch 26/74
# Processing batch 27/74
# Processing batch 28/74
# Processing batch 29/74
# Processing batch 30/74
# Processing batch 31/74
# Processing batch 32/74
# Processing batch 33/74
# Processing batch 34/74
# Processing batch 35/74
# Processing batch 36/74
# Processing batch 37/74
# Processing batch 38/74
# Processing batch 39/74
# Processing batch 40/74
# Processing batch 41/74
# Processing batch 42/74
# Processing batch 43/74
# Processing batch 44/74
# Processing batch 45/74
# Processing batch 46/74
# Processing batch 47/74
# Processing batch 48/74
# Processing batch 49/74
# Processing batch 50/74
# Processing batch 51/74
# Processing batch 52/74
# Processing batch 53/74
# Processing batch 54/74
# Processing batch 55/74
# Processing batch 56/74
# Processing batch 57/74
# Processing batch 58/74
# Processing batch 59/74
# Processing batch 60/74
# Processing batch 61/74
# Processing batch 62/74
# Processing batch 63/74
# Processing batch 64/74
# Processing batch 65/74
# Processing batch 66/74
# Processing batch 67/74
# Processing batch 68/74
# Processing batch 69/74
# Processing batch 70/74
# Processing batch 71/74
# Processing batch 72/74
# Processing batch 73/74
# Processing batch 74/74

# %%
len(ENTITY_2_LABEL)
# Out:
# 3686

# %%
len(set(ENTITY_2_LABEL.keys())), len(set(ENTITY_2_LABEL.values()))

# %%
label2entity = {}
for entity, label in ENTITY_2_LABEL.items():
    if label not in label2entity:
        label2entity[label] = []
    label2entity[label].append(entity)

for label, entities in label2entity.items():
    if len(entities) > 1:
        print(label, entities)

# %% [markdown]
# ### Collecting descriptions for entity types with duplicated labels

# %%
@retry(wait=wait_random_exponential(multiplier=1, max=60))
def get_entity_info(entity_id):
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

    query = f"""
    SELECT ?entityLabel ?entityDescription WHERE {{
      wd:{entity_id} rdfs:label ?entityLabel .
      wd:{entity_id} schema:description ?entityDescription .
      FILTER (lang(?entityLabel) = "en")
      FILTER (lang(?entityDescription) = "en")
    }}
    """

    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    if results["results"]["bindings"]:
        result = results["results"]["bindings"][0]
        return {
            "label": result["entityLabel"]["value"],
            "description": result["entityDescription"]["value"],
        }
    else:
        return None


for label, entities in label2entity.items():
    if len(entities) > 1:
        for entity_id in entities:
            info = get_entity_info(entity_id)
            ENTITY_2_LABEL[entity_id] = info["label"] + " (" + info["description"] + ")"

# %%
len(set(ENTITY_2_LABEL.keys())), len(set(ENTITY_2_LABEL.values()))

# %% [markdown]
# ### Collecting entity types' aliases

# %%
@retry(wait=wait_random_exponential(multiplier=1, max=60))
def get_entity_aliases(entity_id):
    chinese_japanese_pattern = re.compile(
        r"[\u4E00-\u9FFF\u3400-\u4DBF\uF900-\uFAFF\u3040-\u309F\u30A0-\u30FF\u31F0-\u31FF\uFF00-\uFFEF]"
    )
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

    query = f"""
    SELECT ?alias WHERE {{
      wd:{entity_id} skos:altLabel ?alias .
      FILTER (lang(?alias) = "en")
    }}
    """

    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    aliases = []
    for result in results["results"]["bindings"]:

        alias = result["alias"]["value"]
        if not chinese_japanese_pattern.search(alias):
            aliases.append(alias)
        # except Exception as e:
        #    continue

    return aliases


ENTITY_2_ALIASES = {}
for entity_id in tqdm(ENTITY_2_LABEL.keys()):
    ENTITY_2_ALIASES[entity_id] = get_entity_aliases(entity_id)

# %%
# [(ENTITY_2_LABEL[ent], aliases) for ent, aliases in ENTITY_2_ALIASES.items()]

# %%
ENTITY_2_LABEL["Q186408"], get_entity_aliases("Q186408")

# %%
ENTITY_2_LABEL["Q309314"], get_entity_aliases("Q309314")

# %% [markdown]
# ## Building inverse mapping - object/subject type constraint to relation

# %% [markdown]
# ### Checking that relations with 'point in time' and 'quantity' data types don't have other constraints

# %%
# for prop, data_type in PROP_2_DATA_TYPE.items():
#     if data_type == "Quantity":
#         val_constraints = [ENTITY_2_LABEL[ent] for ent in constraint_dict[prop]["Value-type constraint"]]
#         subj_constraints = [ENTITY_2_LABEL[ent] for ent in constraint_dict[prop]["Subject type constraint"]]
#         # print(PROP_2_LABEL[prop], subj_constraints, val_constraints)
#         assert len(val_constraints) == 0
#         # no value constraints for data type quantity

# %%
# for prop, data_type in PROP_2_DATA_TYPE.items():
#     if data_type == "Point in time":
#         val_constraints = [ENTITY_2_LABEL[ent] for ent in constraint_dict[prop]["Value-type constraint"]]
#         subj_constraints = [ENTITY_2_LABEL[ent] for ent in constraint_dict[prop]["Subject type constraint"]]
#         # print(PROP_2_LABEL[prop], subj_constraints, val_constraints)
#         assert len(val_constraints) == 0
#         # no value constraints for data type quantity

# %%
constraint_dict

# %%
subj2prop_constraints = {"<ANY SUBJECT>": []}
# Q309314 - quantity, Q186408 -  point in time
obj2prop_constraint = {"<ANY OBJECT>": [], "Q309314": [], "Q186408": []}

for prop, constraint in constraint_dict.items():

    if PROP_2_DATA_TYPE[prop] == "Point in time":
        obj2prop_constraint["Q186408"].append(prop)

    elif PROP_2_DATA_TYPE[prop] == "Quantity":
        obj2prop_constraint["Q309314"].append(prop)

    elif constraint["Value-type constraint"] == ["ANY"]:
        obj2prop_constraint["<ANY OBJECT>"].append(prop)

    else:
        for entity in constraint["Value-type constraint"]:
            if entity not in obj2prop_constraint:
                obj2prop_constraint[entity] = []
            obj2prop_constraint[entity].append(prop)

    if constraint["Subject type constraint"] == ["ANY"]:
        subj2prop_constraints["<ANY SUBJECT>"].append(prop)

    else:
        for entity in constraint["Subject type constraint"]:
            if entity not in subj2prop_constraints:
                subj2prop_constraints[entity] = []
            subj2prop_constraints[entity].append(prop)


len(subj2prop_constraints), len(obj2prop_constraint)

# %%
with open(ONTOLOGY_MAPPINGS_DIR + "subj_constraint2prop.json", "w") as f:
    json.dump(subj2prop_constraints, f)

with open(ONTOLOGY_MAPPINGS_DIR + "obj_constraint2prop.json", "w") as f:
    json.dump(obj2prop_constraint, f)

# %%
with open(ONTOLOGY_MAPPINGS_DIR + "entity_type2label.json", "w") as f:
    json.dump(ENTITY_2_LABEL, f)

# %%
with open(ONTOLOGY_MAPPINGS_DIR + "prop2aliases.json", "w") as f:
    json.dump(PROP2ALIASES, f)

# %%
with open(ONTOLOGY_MAPPINGS_DIR + "entity_type2aliases.json", "w") as f:
    json.dump(ENTITY_2_ALIASES, f)

# %%
with open(ONTOLOGY_MAPPINGS_DIR + "entity_type2hierarchy.json", "w") as f:
    json.dump(ENTITY_2_HIERARCHY, f)
