# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

# %%
def get_head_triplets(entity_id):
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    query = f"""
    SELECT ?subjectLabel ?propertyLabel ?objectLabel ?object   WHERE {{

      SERVICE wikibase:label {{ 
        bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" .
      }}
      VALUES (?subject) {{(wd:{entity_id})}}  
      # ?subject ?predicate ?object .
      # ?property wikibase:directClaim ?predicate.

      FILTER(STRSTARTS(STR(?predicate), "http://www.wikidata.org/prop/direct/")) .
      FILTER(STRSTARTS(STR(?object), "http://www.wikidata.org/entity/")) .

    }}
    """
    
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    output_triplets = []

    for result in results["results"]["bindings"]:
        obj_id = result['object']['value'].split("/")[-1]
        subject = result["subjectLabel"]["value"]
        predicate = result["propertyLabel"]["value"]
        object_ = result["objectLabel"]["value"]
    
        output_triplets.append({"subject": subject, "predicate": predicate, "object": object_, "subj_id": entity_id,"obj_id": obj_id})
    
    return output_triplets

get_head_triplets("Q19837")
# Out:
# [{'subject': 'Steve Jobs',
#   'predicate': 'place of birth',
#   'object': 'San Francisco',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q62'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'place of death',
#   'object': 'Palo Alto',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q47265'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'sex or gender',
#   'object': 'male',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q6581097'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'father',
#   'object': 'Abdulfattah Jandali',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q12605967'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'mother',
#   'object': 'Joanne Carole Schieble Simpson',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q28941744'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'spouse',
#   'object': 'Laurene Powell Jobs',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q3133593'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'country of citizenship',
#   'object': 'United States of America',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q30'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'instance of',
#   'object': 'human',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q5'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'position held',
#   'object': 'chief executive officer',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q484876'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'child',
#   'object': 'Lisa Brennan-Jobs',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q2983236'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'child',
#   'object': 'Reed Paul',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q20895861'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'child',
#   'object': 'Erin Sienna',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q20895866'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'child',
#   'object': 'Eve Jobs',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q20895867'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'educated at',
#   'object': 'De Anza College',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q928272'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'educated at',
#   'object': 'Reed College',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q1140775'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'educated at',
#   'object': 'Homestead High School',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q5890521'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'member of political party',
#   'object': 'Democratic Party',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q29552'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'native language',
#   'object': 'English',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q1860'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'occupation',
#   'object': 'computer scientist',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q82594'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'occupation',
#   'object': 'entrepreneur',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q131524'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'occupation',
#   'object': 'inventor',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q205375'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'occupation',
#   'object': 'executive producer',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q1053574'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'occupation',
#   'object': 'financier',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q1979607'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'occupation',
#   'object': 'film producer',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q3282637'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'occupation',
#   'object': 'designer',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q5322166'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'employer',
#   'object': 'Apple',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q312'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'employer',
#   'object': 'Pixar',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q127552'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'employer',
#   'object': 'NeXT',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q308993'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'employer',
#   'object': 'Atari, Inc.',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q13409231'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'place of burial',
#   'object': 'Alta Mesa Memorial Park',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q2477691'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'religion or worldview',
#   'object': 'Buddhism',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q748'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'religion or worldview',
#   'object': 'Zen',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q7953'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'award received',
#   'object': 'National Medal of Technology and Innovation',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q937629'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'award received',
#   'object': 'Disney Legends',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q1150306'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'award received',
#   'object': 'National Inventors Hall of Fame',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q1366018'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'award received',
#   'object': 'California Hall of Fame',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q5020532'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'award received',
#   'object': 'Financial Times Person of the Year',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q5449677'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'award received',
#   'object': 'Grammy Trustees Award',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q5593916'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'unmarried partner',
#   'object': 'Chrisann Brennan',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q18810921'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'member of',
#   'object': 'American Academy of Arts and Sciences',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q463303'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'cause of death',
#   'object': 'pancreatic cancer',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q212961'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'residence',
#   'object': 'Mountain View',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q486860'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'family name',
#   'object': 'Jobs',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q37461660'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'given name',
#   'object': 'Paul',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q4925623'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'given name',
#   'object': 'Steven',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q17501985'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'given name',
#   'object': 'Steve',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q18336566'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'notable work',
#   'object': 'iPhone',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q2766'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'notable work',
#   'object': 'iPad',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q2796'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'notable work',
#   'object': 'iPod',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q9479'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'notable work',
#   'object': 'iTunes',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q9589'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'notable work',
#   'object': 'iMac',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q14091'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'notable work',
#   'object': 'Apple I',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q18981'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'notable work',
#   'object': 'App Store',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q368215'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'notable work',
#   'object': 'Apple Lisa',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q371482'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'notable work',
#   'object': 'NeXTSTEP',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q831367'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'notable work',
#   'object': 'Mac OS X 10.0',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q912481'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'notable work',
#   'object': 'Apple II',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q3017175'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'notable work',
#   'object': 'NeXT Computer',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q4045099'},
#  {'subject': 'Steve Jobs',
#   'predicate': "topic's main category",
#   'object': 'Category:Steve Jobs',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q7155402'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'relative',
#   'object': 'Malek Jandali',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q3281834'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'relative',
#   'object': 'Paul Jobs',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q28941300'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'relative',
#   'object': 'Clara Hagopian Jobs',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q28941339'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'relative',
#   'object': 'Bassma Al Jandaly',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q97355518'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'medical condition',
#   'object': 'pancreatic cancer',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q212961'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'manner of death',
#   'object': 'natural causes',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q3739104'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'described by source',
#   'object': 'Lentapedia',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q17290934'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'described by source',
#   'object': 'Obálky knih',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q67311526'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'participant in',
#   'object': 'commencement at the Stanford University',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q99999126'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'languages spoken, written or signed',
#   'object': 'English',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q1860'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'present in work',
#   'object': 'iSteve',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q12125162'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'lifestyle',
#   'object': 'perfectionism',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q1121749'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'owner of',
#   'object': 'Apple',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q312'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'owner of',
#   'object': 'NeXT',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q308993'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'owner of',
#   'object': 'Jackling House',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q6116760'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'different from',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q18754959'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'different from',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q20243178'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'sibling',
#   'object': 'Mona Simpson',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q238331'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'on focus list of Wikimedia project',
#   'object': 'Wikipedia:Vital articles/Level/4',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q6173448'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'has works in the collection',
#   'object': 'Museum of Modern Art',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q188740'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'copyright status as a creator',
#   'object': 'works protected by copyrights',
#   'subj_id': 'Q19837',
#   'obj_id': 'Q73555012'}]

# %%
def get_tail_triplets(entity_id):
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    query = f"""
    SELECT ?subjectLabel ?propertyLabel ?objectLabel ?subject WHERE {{

      SERVICE wikibase:label {{ 
        bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" .
      }}

      VALUES (?object) {{(wd:{entity_id})}}  
      # ?subject ?predicate ?object .
      # ?property wikibase:directClaim ?predicate.

      FILTER(STRSTARTS(STR(?predicate), "http://www.wikidata.org/prop/direct/")) .
      FILTER(STRSTARTS(STR(?object), "http://www.wikidata.org/entity/")) .

    }}
    """
    
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    
    output_triplets = []
    for result in results["results"]["bindings"]:
        subject = result["subjectLabel"]["value"]
        predicate = result["propertyLabel"]["value"]
        object_ = result["objectLabel"]["value"]
        subj_id = result['subject']['value'].split("/")[-1]

        output_triplets.append({"subject": subject, "predicate": predicate, "object": object_, "subj_id": subj_id, "obj_id": entity_id})
    
    return output_triplets

get_tail_triplets("Q19837")
# Out:
# [{'subject': 'Lisa Brennan-Jobs',
#   'predicate': 'father',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q2983236',
#   'obj_id': 'Q19837'},
#  {'subject': 'Reed Paul',
#   'predicate': 'father',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q20895861',
#   'obj_id': 'Q19837'},
#  {'subject': 'Erin Sienna',
#   'predicate': 'father',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q20895866',
#   'obj_id': 'Q19837'},
#  {'subject': 'Eve Jobs',
#   'predicate': 'father',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q20895867',
#   'obj_id': 'Q19837'},
#  {'subject': 'Laurene Powell Jobs',
#   'predicate': 'spouse',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q3133593',
#   'obj_id': 'Q19837'},
#  {'subject': 'Abdulfattah Jandali',
#   'predicate': 'child',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q12605967',
#   'obj_id': 'Q19837'},
#  {'subject': 'Paul Jobs',
#   'predicate': 'child',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q28941300',
#   'obj_id': 'Q19837'},
#  {'subject': 'Clara Hagopian Jobs',
#   'predicate': 'child',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q28941339',
#   'obj_id': 'Q19837'},
#  {'subject': 'Joanne Carole Schieble Simpson',
#   'predicate': 'child',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q28941744',
#   'obj_id': 'Q19837'},
#  {'subject': 'Thoughts on Flash',
#   'predicate': 'author',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q4781260',
#   'obj_id': 'Q19837'},
#  {'subject': 'Venus',
#   'predicate': 'commissioned by',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q7920563',
#   'obj_id': 'Q19837'},
#  {'subject': 'Apple',
#   'predicate': 'founded by',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q312',
#   'obj_id': 'Q19837'},
#  {'subject': 'macOS',
#   'predicate': 'founded by',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q14116',
#   'obj_id': 'Q19837'},
#  {'subject': 'NeXT',
#   'predicate': 'founded by',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q308993',
#   'obj_id': 'Q19837'},
#  {'subject': 'Pixar',
#   'predicate': 'owned by',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q127552',
#   'obj_id': 'Q19837'},
#  {'subject': 'NeXT',
#   'predicate': 'owned by',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q308993',
#   'obj_id': 'Q19837'},
#  {'subject': 'Jackling House',
#   'predicate': 'owned by',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q6116760',
#   'obj_id': 'Q19837'},
#  {'subject': 'Jobs',
#   'predicate': 'named after',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q392825',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'named after',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q18754959',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs Garage',
#   'predicate': 'named after',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q26257952',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'named after',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q52946669',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'named after',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q52951676',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'named after',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q52986630',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'named after',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q52987978',
#   'obj_id': 'Q19837'},
#  {'subject': 'The Pixar Story',
#   'predicate': 'cast member',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q2244246',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs: The Lost Interview',
#   'predicate': 'cast member',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q19850847',
#   'obj_id': 'Q19837'},
#  {'subject': 'NeXT',
#   'predicate': 'chief executive officer',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q308993',
#   'obj_id': 'Q19837'},
#  {'subject': 'Macintosh 128K Home Computer',
#   'predicate': 'creator',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q109796898',
#   'obj_id': 'Q19837'},
#  {'subject': 'Apple I',
#   'predicate': 'developer',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q18981',
#   'obj_id': 'Q19837'},
#  {'subject': 'Apple One',
#   'predicate': 'developer',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q99356246',
#   'obj_id': 'Q19837'},
#  {'subject': 'The Son of a Migrant from Syria',
#   'predicate': 'depicts',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q21775892',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'depicts',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q47510529',
#   'obj_id': 'Q19837'},
#  {'subject': 'Internet Giants : Masters of the Universe',
#   'predicate': 'depicts',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q54321224',
#   'obj_id': 'Q19837'},
#  {'subject': 'Breakout',
#   'predicate': 'designed by',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q177491',
#   'obj_id': 'Q19837'},
#  {'subject': 'Category:Steve Jobs',
#   'predicate': "category's main topic",
#   'object': 'Steve Jobs',
#   'subj_id': 'Q7155402',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs’ transplanted liver (received by Jobs)',
#   'predicate': 'part of',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q72303384',
#   'obj_id': 'Q19837'},
#  {'subject': 'Chrisann Brennan',
#   'predicate': 'unmarried partner',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q18810921',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs Garage',
#   'predicate': 'occupant',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q26257952',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs Monument',
#   'predicate': 'commemorates',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q4343358',
#   'obj_id': 'Q19837'},
#  {'subject': 'Jobs',
#   'predicate': 'characters',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q392825',
#   'obj_id': 'Q19837'},
#  {'subject': 'Pirates of Silicon Valley',
#   'predicate': 'characters',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q500279',
#   'obj_id': 'Q19837'},
#  {'subject': 'iSteve',
#   'predicate': 'characters',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q12125162',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'characters',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q18754959',
#   'obj_id': 'Q19837'},
#  {'subject': 'Birane Hane',
#   'predicate': 'influenced by',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q69358316',
#   'obj_id': 'Q19837'},
#  {'subject': 'Fincy Pierre',
#   'predicate': 'influenced by',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q104978342',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs Monument',
#   'predicate': 'dedicated to',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q4343358',
#   'obj_id': 'Q19837'},
#  {'subject': 'Jobs',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q392825',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q625645',
#   'obj_id': 'Q19837'},
#  {'subject': 'The Bite in the Apple',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q16842521',
#   'obj_id': 'Q19837'},
#  {'subject': 'Lentapedia article about Steve Jobs',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q17316283',
#   'obj_id': 'Q19837'},
#  {'subject': 'Apple executive Steve Jobs resigns',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q17593997',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q18754959',
#   'obj_id': 'Q19837'},
#  {'subject': 'Designed by Apple in California',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q30587923',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs (1955-2011).',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q34633481',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q47510529',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs: Billion Dollar Hippy',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q50448844',
#   'obj_id': 'Q19837'},
#  {'subject': 'Gender dynamics in the choice of place of trade among young entrepreneurs in Ghana',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q108256281',
#   'obj_id': 'Q19837'},
#  {'subject': 'Patching a Hole in the JOBS Act: How and Why to Rewrite  the Rules that Require Firms to Make Periodic Disclosures',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q108689908',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs’s Beat-Up Birkenstocks Sold for $218,000. A Fan Made His Own.',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q121333773',
#   'obj_id': 'Q19837'},
#  {'subject': 'Make Something Wonderful',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q121734157',
#   'obj_id': 'Q19837'},
#  {'subject': 'Q121964267',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q121964267',
#   'obj_id': 'Q19837'},
#  {'subject': 'Q121968022',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q121968022',
#   'obj_id': 'Q19837'},
#  {'subject': 'Q121975583',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q121975583',
#   'obj_id': 'Q19837'},
#  {'subject': 'Q122033318',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q122033318',
#   'obj_id': 'Q19837'},
#  {'subject': 'Q122079709',
#   'predicate': 'main subject',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q122079709',
#   'obj_id': 'Q19837'},
#  {'subject': 'Toy Story',
#   'predicate': 'executive producer',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q171048',
#   'obj_id': 'Q19837'},
#  {'subject': 'Justia Patents inventor ID',
#   'predicate': 'Wikidata property example',
#   'object': 'Steve Jobs',
#   'subj_id': 'P3874',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs',
#   'predicate': 'different from',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q18754959',
#   'obj_id': 'Q19837'},
#  {'subject': 'Steve Jobs Archive',
#   'predicate': 'interested in',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q124618897',
#   'obj_id': 'Q19837'},
#  {'subject': 'FaceTime',
#   'predicate': 'significant person',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q648357',
#   'obj_id': 'Q19837'},
#  {'subject': 'Mona Simpson',
#   'predicate': 'sibling',
#   'object': 'Steve Jobs',
#   'subj_id': 'Q238331',
#   'obj_id': 'Q19837'}]

# %%
jobs_triplets = get_head_triplets("Q19837") + get_tail_triplets("Q19837")
jobs_df = pd.DataFrame(jobs_triplets).drop_duplicates()
jobs_df
# Out:
#                         subject                  predicate  \
# 0                    Steve Jobs             place of birth
# 1                    Steve Jobs             place of death
# 2                    Steve Jobs              sex or gender
# 3                    Steve Jobs                     father
# 4                    Steve Jobs                     mother
# ..                          ...                        ...
# 146  Justia Patents inventor ID  Wikidata property example
# 147                  Steve Jobs             different from
# 148          Steve Jobs Archive              interested in
# 149                    FaceTime         significant person
# 150                Mona Simpson                    sibling
#
#                              object     subj_id     obj_id
# 0                     San Francisco      Q19837        Q62
# 1                         Palo Alto      Q19837     Q47265
# 2                              male      Q19837   Q6581097
# 3               Abdulfattah Jandali      Q19837  Q12605967
# 4    Joanne Carole Schieble Simpson      Q19837  Q28941744
# ..                              ...         ...        ...
# 146                      Steve Jobs       P3874     Q19837
# 147                      Steve Jobs   Q18754959     Q19837
# 148                      Steve Jobs  Q124618897     Q19837
# 149                      Steve Jobs     Q648357     Q19837
# 150                      Steve Jobs     Q238331     Q19837
#
# [151 rows x 5 columns]

# %%
# apple_triplets = get_head_triplets("Q312") + get_tail_triplets("Q312")
apple_triplets = get_head_triplets("Q312")
apple_df = pd.DataFrame(apple_triplets).drop_duplicates()
apple_df
# Out:
#     subject                       predicate                         object  \
# 0     Apple                        location       United States of America
# 1     Apple                  has subsidiary                    Apple Store
# 2     Apple                  has subsidiary                         Claris
# 3     Apple                  has subsidiary              Beats Electronics
# 4     Apple                  has subsidiary                FileMaker, Inc.
# ..      ...                             ...                            ...
# 100   Apple     has works in the collection             Design Museum Gent
# 101   Apple     has works in the collection             Museum of Industry
# 102   Apple   copyright status as a creator  works protected by copyrights
# 103   Apple                external auditor              Ernst & Young LLP
# 104   Apple  affiliated worker organisation     Apple worker organizations
#
#     subj_id      obj_id
# 0      Q312         Q30
# 1      Q312     Q421253
# 2      Q312    Q1095605
# 3      Q312    Q1961036
# 4      Q312    Q1982831
# ..      ...         ...
# 100    Q312    Q1809071
# 101    Q312    Q2245203
# 102    Q312   Q73555012
# 103    Q312   Q98525448
# 104    Q312  Q108523862
#
# [105 rows x 5 columns]

# %%
woznyak_triplets = get_head_triplets("Q483382") + get_tail_triplets("Q483382")
woznyak_df = pd.DataFrame(woznyak_triplets).drop_duplicates()
woznyak_df
# Out:
#                                        subject               predicate  \
# 0                                Steve Wozniak          place of birth
# 1                                Steve Wozniak           sex or gender
# 2                                Steve Wozniak                  spouse
# 3                                Steve Wozniak  country of citizenship
# 4                                Steve Wozniak  country of citizenship
# ..                                         ...                     ...
# 84                                        iWoz            main subject
# 85                                       HP-65                 used by
# 86  Pause Giant AI Experiments: An Open Letter               signatory
# 87                        The Art of Intrusion      author of foreword
# 88                              Control-Vision      significant person
#
#                       object     subj_id     obj_id
# 0                   San Jose     Q483382     Q16553
# 1                       male     Q483382   Q6581097
# 2                 Janet Hill     Q483382  Q22442739
# 3   United States of America     Q483382        Q30
# 4                     Serbia     Q483382       Q403
# ..                       ...         ...        ...
# 84             Steve Wozniak    Q5975708    Q483382
# 85             Steve Wozniak     Q220638    Q483382
# 86             Steve Wozniak  Q117349926    Q483382
# 87             Steve Wozniak    Q3818760    Q483382
# 88             Steve Wozniak    Q5165806    Q483382
#
# [89 rows x 5 columns]

# %%
pixar_triplets = get_head_triplets("Q127552") + get_tail_triplets("Q127552")
pixar_df = pd.DataFrame(pixar_triplets).drop_duplicates()
pixar_df
# Out:
#             subject                      predicate                    object  \
# 0             Pixar                        country  United States of America
# 1             Pixar                    instance of          animation studio
# 2             Pixar                    instance of   film production company
# 3             Pixar                    instance of                  business
# 4             Pixar                     founded by             Edwin Catmull
# ..              ...                            ...                       ...
# 228    Portal:Pixar  Wikimedia portal's main topic                     Pixar
# 229  Template:Pixar             template has topic                     Pixar
# 230       Q23662070                        used by                     Pixar
# 231             Bao               copyright holder                     Pixar
# 232         Kitbull               copyright holder                     Pixar
#
#        subj_id    obj_id
# 0      Q127552       Q30
# 1      Q127552  Q1107679
# 2      Q127552  Q1762059
# 3      Q127552  Q4830453
# 4      Q127552    Q93161
# ..         ...       ...
# 228  Q15613750   Q127552
# 229   Q4200363   Q127552
# 230  Q23662070   Q127552
# 231  Q55070849   Q127552
# 232  Q61740829   Q127552
#
# [233 rows x 5 columns]

# %%
next_triplets = get_head_triplets("Q308993") + get_tail_triplets("Q308993")
next_df = pd.DataFrame(next_triplets).drop_duplicates()
next_df
# Out:
#                   subject                                          predicate  \
# 0                    NeXT                                            country
# 1                    NeXT                                        instance of
# 2                    NeXT                                        instance of
# 3                    NeXT                                         founded by
# 4                    NeXT                                           owned by
# 5                    NeXT                              headquarters location
# 6                    NeXT                            chief executive officer
# 7                    NeXT                                           industry
# 8                    NeXT                                           industry
# 9                    NeXT                              location of formation
# 10                   NeXT                              location of formation
# 11                   NeXT                              location of formation
# 12                   NeXT                              topic's main category
# 13                   NeXT  product, material, or service produced or prov...
# 14                   NeXT  product, material, or service produced or prov...
# 15                   NeXT  product, material, or service produced or prov...
# 16                   NeXT  product, material, or service produced or prov...
# 17                   NeXT  product, material, or service produced or prov...
# 18                   NeXT                                         legal form
# 19                   NeXT                        has works in the collection
# 20                   NeXT                                        merged into
# 21  NeXT RISC Workstation                                        instance of
# 22             Steve Jobs                                           employer
# 23             Susan Kare                                           employer
# 24          Avie Tevanian                                           employer
# 25        Bertrand Serlet                                           employer
# 26      Jean-Marie Hullot                                           employer
# 27         Duco Sickinghe                                           employer
# 28              Rich Page                                           employer
# 29        Stuart M. Reges                                           employer
# 30             Ken Segall                                           employer
# 31               NeXTcube                                       manufacturer
# 32          NeXT Computer                                       manufacturer
# 33         NeXTcube Turbo                                       manufacturer
# 34               NeXTSTEP                                          developer
# 35               OpenStep                                          developer
# 36               NeXTcube                                          developer
# 37              Music Kit                                          developer
# 38               NeXTMail                                          developer
# 39         NeXTcube Turbo                                          developer
# 40          Category:NeXT                              category's main topic
# 41                Doom II                                           platform
# 42                  macOS                                      influenced by
# 43              NeXT logo                                         represents
# 44                 DB13W3                                            used by
# 45         Motorola 56001                                            used by
# 46             Steve Jobs                                           owner of
# 47              NeXT logo                                          symbol of
#
#                                 object     subj_id    obj_id
# 0             United States of America     Q308993       Q30
# 1                             business     Q308993  Q4830453
# 2                           enterprise     Q308993  Q6881511
# 3                           Steve Jobs     Q308993    Q19837
# 4                           Steve Jobs     Q308993    Q19837
# 5                         Redwood City     Q308993   Q505549
# 6                           Steve Jobs     Q308993    Q19837
# 7                    computer hardware     Q308993     Q3966
# 8                    software industry     Q308993   Q880371
# 9                            Palo Alto     Q308993    Q47265
# 10                           Cupertino     Q308993   Q189471
# 11                            Woodside     Q308993   Q984177
# 12                       Category:NeXT     Q308993  Q7214353
# 13                            NeXTSTEP     Q308993   Q831367
# 14                         NeXTstation     Q308993  Q1426558
# 15                            NeXTcube     Q308993  Q1972984
# 16                       NeXT Computer     Q308993  Q4045099
# 17                      NeXTcube Turbo     Q308993  Q6983889
# 18              privately held company     Q308993  Q1589009
# 19  San Francisco Museum of Modern Art     Q308993   Q913672
# 20                               Apple     Q308993      Q312
# 21                                NeXT    Q6983888   Q308993
# 22                                NeXT      Q19837   Q308993
# 23                                NeXT      Q48971   Q308993
# 24                                NeXT    Q2705121   Q308993
# 25                                NeXT    Q2730061   Q308993
# 26                                NeXT    Q3167700   Q308993
# 27                                NeXT    Q3385305   Q308993
# 28                                NeXT    Q7323403   Q308993
# 29                                NeXT    Q7627000   Q308993
# 30                                NeXT   Q98410583   Q308993
# 31                                NeXT    Q1972984   Q308993
# 32                                NeXT    Q4045099   Q308993
# 33                                NeXT    Q6983889   Q308993
# 34                                NeXT     Q831367   Q308993
# 35                                NeXT    Q1193981   Q308993
# 36                                NeXT    Q1972984   Q308993
# 37                                NeXT    Q6941581   Q308993
# 38                                NeXT    Q6983882   Q308993
# 39                                NeXT    Q6983889   Q308993
# 40                                NeXT    Q7214353   Q308993
# 41                                NeXT     Q755186   Q308993
# 42                                NeXT      Q14116   Q308993
# 43                                NeXT   Q99519556   Q308993
# 44                                NeXT     Q595385   Q308993
# 45                                NeXT  Q115781990   Q308993
# 46                                NeXT      Q19837   Q308993
# 47                                NeXT   Q99519556   Q308993

# %%
all_df = pd.concat([jobs_df, apple_df, woznyak_df, pixar_df, next_df])
all_df
# Out:
#            subject       predicate                          object  \
# 0       Steve Jobs  place of birth                   San Francisco
# 1       Steve Jobs  place of death                       Palo Alto
# 2       Steve Jobs   sex or gender                            male
# 3       Steve Jobs          father             Abdulfattah Jandali
# 4       Steve Jobs          mother  Joanne Carole Schieble Simpson
# ..             ...             ...                             ...
# 43       NeXT logo      represents                            NeXT
# 44          DB13W3         used by                            NeXT
# 45  Motorola 56001         used by                            NeXT
# 46      Steve Jobs        owner of                            NeXT
# 47       NeXT logo       symbol of                            NeXT
#
#        subj_id     obj_id
# 0       Q19837        Q62
# 1       Q19837     Q47265
# 2       Q19837   Q6581097
# 3       Q19837  Q12605967
# 4       Q19837  Q28941744
# ..         ...        ...
# 43   Q99519556    Q308993
# 44     Q595385    Q308993
# 45  Q115781990    Q308993
# 46      Q19837    Q308993
# 47   Q99519556    Q308993
#
# [626 rows x 5 columns]

# %%
all_df = all_df.drop_duplicates()
all_df
# Out:
#            subject       predicate                          object  \
# 0       Steve Jobs  place of birth                   San Francisco
# 1       Steve Jobs  place of death                       Palo Alto
# 2       Steve Jobs   sex or gender                            male
# 3       Steve Jobs          father             Abdulfattah Jandali
# 4       Steve Jobs          mother  Joanne Carole Schieble Simpson
# ..             ...             ...                             ...
# 42           macOS   influenced by                            NeXT
# 43       NeXT logo      represents                            NeXT
# 44          DB13W3         used by                            NeXT
# 45  Motorola 56001         used by                            NeXT
# 47       NeXT logo       symbol of                            NeXT
#
#        subj_id     obj_id
# 0       Q19837        Q62
# 1       Q19837     Q47265
# 2       Q19837   Q6581097
# 3       Q19837  Q12605967
# 4       Q19837  Q28941744
# ..         ...        ...
# 42      Q14116    Q308993
# 43   Q99519556    Q308993
# 44     Q595385    Q308993
# 45  Q115781990    Q308993
# 47   Q99519556    Q308993
#
# [617 rows x 5 columns]

# %%
import requests

def wikidata_id2wikipedia_name(ids):
    
    num_batches = len(ids) // 50 + int(len(ids) % 50 != 0)
    names = {}

    for batch in range(num_batches):
        id_batch = ids[batch*50:batch*50+50]
        id_batch = "|".join(id_batch)
        res = requests.get("https://www.wikidata.org/w/api.php?action=wbgetentities&format=json&props=sitelinks&ids={}&sitefilter=enwiki".format(id_batch)).json()
        for entity in res['entities']:
            if "sitelinks" in res['entities'][entity] and "enwiki" in res['entities'][entity]["sitelinks"]:
                names[entity] = res['entities'][entity]["sitelinks"]["enwiki"]["title"]
    return names

def get_alternative_labels(entity_id):
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    query = f"""
    SELECT ?item ?itemAltLabel WHERE {{

    VALUES (?subject) {{(wd:{entity_id})}}  
    # ?subject skos:altLabel ?itemAltLabel . FILTER (lang(?itemAltLabel) = "en")
 

    }}
    """
    
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    results = results["results"]["bindings"]

    output_labels = []
    for res in results:
        output_labels.append(res['itemAltLabel']['value'])
    
    return output_labels
get_alternative_labels("Q483382")
# Out:
# ['Mr. Steve Wozniak',
#  'Stephan Gary Wozniak',
#  'Stephen Gary Wozniak',
#  'Stephen Wozniak',
#  'The Woz',
#  'Woz']

# %%
ids = list(set(list(all_df['subj_id']) + list(all_df['obj_id'])))
wikidata_id2wiki_mapping = wikidata_id2wikipedia_name(ids)
wikidata_id2wiki_mapping
# Out:
# {'Q43845': 'Businessperson',
#  'Q5700571': 'Heinz Awards',
#  'Q14094': 'IPod Touch',
#  'Q1150306': 'Disney Legends',
#  'Q2252704': 'Partysaurus Rex',
#  'Q2730061': 'Bertrand Serlet',
#  'Q21974358': 'Zaltair',
#  'Q18002980': 'Lava (2014 film)',
#  'Q3818760': 'The Art of Intrusion',
#  'Q61740829': 'Kitbull',
#  'Q1426558': 'NeXTstation',
#  'Q30587923': 'Designed by Apple in California',
#  'Q269214': 'John Lasseter',
#  'Q47265': 'Palo Alto, California',
#  'Q6983889': 'NeXTcube Turbo',
#  'Q785706': 'One Man Band (film)',
#  'Q168756': 'University of California, Berkeley',
#  'Q8257564': 'Category:Apple Inc. people',
#  'Q6173448': 'Wikipedia:Vital articles/Level/4',
#  'Q80978': 'Hewlett-Packard',
#  'Q19673': 'Al Gore',
#  'Q7139120': 'Category:Pixar',
#  'Q17386294': 'Angus MacLane',
#  'Q18810921': 'Chrisann Brennan',
#  'Q189471': 'Cupertino, California',
#  'Q1193981': 'OpenStep',
#  'Q388105': 'Presto (animation software)',
#  'Q48971': 'Susan Kare',
#  'Q3966': 'Computer hardware',
#  'Q42417740': 'Woz U',
#  'Q6581097': 'Male gender',
#  'Q22645': 'Smartphone',
#  'Q187726': 'Monsters, Inc.',
#  'Q82594': 'Computer scientist',
#  'Q308993': 'NeXT',
#  'Q201652': 'Apple II',
#  'Q6144664': 'Inside Out (2015 film)',
#  'Q13512513': 'The Secret History of Hacking',
#  'Q269415': 'Digital distribution',
#  'Q21775892': 'The Son of a Migrant from Syria',
#  'Q17388808': 'Susan Wagner',
#  'Q113877606': 'Inside Out 2',
#  'Q1140775': 'Reed College',
#  'Q749153': "Geri's Game",
#  'Q155972': 'Tablet computer',
#  'Q7365310': 'Ronald Sugar',
#  'Q20243178': 'Steve Jobs (disambiguation)',
#  'Q403': 'Serbia',
#  'Q3283283': 'Pixar Short Films Collection, Volume 1',
#  'Q1589009': 'Privately held company',
#  'Q768941': 'The Adventures of André & Wally B.',
#  'Q205375': 'Inventor',
#  'Q30': 'United States',
#  'Q170035': 'Ratatouille (film)',
#  'Q113879962': 'Elio (film)',
#  'Q7215242': 'Category:Apple Inc.',
#  'Q15885268': 'Finding Nemo (franchise)',
#  'Q9589': 'ITunes',
#  'Q5012809': 'CL 9',
#  'Q1972984': 'NeXTcube',
#  'Q108570386': 'Twenty Something (2021 film)',
#  'Q57655560': 'Corp.',
#  'Q4038751': 'FingerWorks',
#  'Q368215': 'App Store (Apple)',
#  'Q914155': 'Luxo Jr.',
#  'Q187266': 'Toy Story 2',
#  'Q115615897': 'Win or Lose (TV series)',
#  'Q242446': 'Lucasfilm',
#  'Q3617636': 'Ann Mather',
#  'Q212961': 'Pancreatic cancer',
#  'Q3814511': 'Ken Schretzmann',
#  'Q24265062': 'Brian Fee',
#  'Q463303': 'American Academy of Arts and Sciences',
#  'Q2586695': 'National Design Awards',
#  'Q93092': 'William Reeves (animator)',
#  'Q19837': 'Steve Jobs',
#  'Q5165806': 'Control-Vision',
#  'Q8084438': 'Braeburn Capital',
#  'Q507306': 'Nasdaq-100',
#  'Q595385': 'DB13W3',
#  'Q79341113': 'Wind (2019 film)',
#  'Q28366283': 'Danielle Feinberg',
#  'Q5616016': 'Template:Apple Inc.',
#  'Q3017175': 'Apple II (original)',
#  'Q2219678': 'Mater and the Ghostlight',
#  'Q112801489': 'Elemental (2023 film)',
#  'Q80993': 'Software engineering',
#  'Q117349926': 'Pause Giant AI Experiments: An Open Letter',
#  'Q17019378': 'Luxo Jr. (character)',
#  'Q1657080': 'Planes (film)',
#  'Q16739993': 'The Cruciferous Vegetable Amplification',
#  'Q4781260': 'Thoughts on Flash',
#  'Q392825': 'Jobs (film)',
#  'Q219635': 'BlackRock',
#  'Q7214353': 'Category:NeXT',
#  'Q936260': 'For the Birds (film)',
#  'Q43035': 'Electrical engineering',
#  'Q213326': 'The Incredibles',
#  'Q92653': 'Bruce Perens',
#  'Q20666333': 'Kyle Balda',
#  'Q7953': 'Zen',
#  'Q486860': 'Mountain View, California',
#  'Q532423': 'Bob Iger',
#  'Q797106': 'BURN-E',
#  'Q104409060': 'Lightyear (film)',
#  'Q5031682': 'Candice Clark',
#  'Q495377': 'Richmond, California',
#  'Q108523862': 'Apple Inc. and unions',
#  'Q217583': 'Berkshire Hathaway',
#  'Q5322166': 'Designer',
#  'Q27964622': 'Borrowed Time (film)',
#  'Q1546066': 'Networking hardware',
#  'Q2681381': 'The Art of Deception',
#  'Q113641997': 'Toy Story 5',
#  'Q1961036': 'Beats Electronics',
#  'Q26936286': 'AirPods',
#  'Q1334829': 'Wearable computer',
#  'Q14330342': 'Kori Rae',
#  'Q1455793': 'Jan Pinkava',
#  'Q126796': 'Brave (2012 film)',
#  'Q6272244': 'Jonas Rivera',
#  'Q505549': 'Redwood City, California',
#  'Q3167700': 'Jean-Marie Hullot',
#  'Q104845027': 'Turning Red',
#  'Q7414': 'The Walt Disney Company',
#  'Q18336566': 'Steve',
#  'Q21463549': 'Siri Inc.',
#  'Q736938': 'Partly Cloudy',
#  'Q62': 'San Francisco',
#  'Q499178': 'Emeryville, California',
#  'Q1366018': 'National Inventors Hall of Fame',
#  'Q1048090': 'History of Apple Inc.',
#  'Q508712': 'Knick Knack',
#  'Q2840289': 'The Blue Umbrella (2013 film)',
#  'Q2796': 'IPad',
#  'Q1101201': 'Small Fry (film)',
#  'Q6881511': 'Business enterprise',
#  'Q5020532': 'California Hall of Fame',
#  'Q332591': 'Ronald Wayne',
#  'Q7395176': 'SWEET16',
#  'Q1145731': 'University of Technology Sydney',
#  'Q740682': 'Bob Peterson (filmmaker)',
#  'Q1809071': 'Design Museum Gent',
#  'Q509725': 'Teddy Newton',
#  'Q18388277': 'Technology company',
#  'Q7603552': 'State Street Global Advisors',
#  'Q2457085': 'Hawaiian Vacation',
#  'Q30137500': 'HomePod',
#  'Q16553': 'San Jose, California',
#  'Q2347411': 'Steven Woznick',
#  'Q543179': 'Hal Hickel',
#  'Q500279': 'Pirates of Silicon Valley',
#  'Q3133593': 'Laurene Powell Jobs',
#  'Q312': 'Apple Inc.',
#  'Q581105': 'Consumer electronics',
#  'Q29940924': 'Jerome Ranft',
#  'Q75507275': 'Float (2019 film)',
#  'Q357627': 'Pete Docter',
#  'Q188740': 'Museum of Modern Art',
#  'Q97355518': 'Bassma Al Jandaly',
#  'Q5421417': 'Exploring the Reef with Jean-Michel Cousteau',
#  'Q16835875': 'AuthenTec',
#  'Q2907405': "It's Tough to Be a Bug!",
#  'Q1415395': 'Film industry',
#  'Q928272': 'De Anza College',
#  'Q216153': "A Bug's Life",
#  'Q61895636': 'Austin Madison',
#  'Q891723': 'Public company',
#  'Q5815826': 'Coco (2017 film)',
#  'Q431289': 'Brand',
#  'Q89': 'Apple',
#  'Q111445092': 'Ciao Alberto',
#  'Q1191023': 'Think different',
#  'Q182153': 'Cars (film)',
#  'Q638608': 'Software development',
#  'Q549465': 'Tin Toy',
#  'Q18010946': 'Apple Watch',
#  'Q19867262': "Sanjay's Super Team",
#  'Q5637266': 'Hackers: Wizards of the Electronic Age',
#  'Q179310': 'Computing',
#  'Q12125162': 'ISteve',
#  'Q5449677': 'Financial Times Person of the Year',
#  'Q3530531': 'Tokyo Mater',
#  'Q6941581': 'Music Kit',
#  'Q831367': 'NeXTSTEP',
#  'Q63925380': 'Smash and Grab (2019 film)',
#  'Q82059': 'Nasdaq',
#  'Q22073999': 'Josh Cooley',
#  'Q19850847': 'Steve Jobs: The Lost Interview',
#  'Q736674': 'University of Colorado Boulder',
#  'Q1121749': 'Perfectionism (psychology)',
#  'Q7155402': 'Category:Steve Jobs',
#  'Q4925623': 'Paul (given name)',
#  'Q984177': 'Woodside, California',
#  'Q1119662': 'Imagination Technologies',
#  'Q180816': 'Dow Jones Industrial Average',
#  'Q2477691': 'Alta Mesa Memorial Park',
#  'Q177491': 'Breakout (video game)',
#  'Q5535894': 'George and A.J.',
#  'Q50363815': 'Tom Porter (computer scientist)',
#  'Q665908': 'Cars Toons',
#  'Q7397': 'Software',
#  'Q7323403': 'Rich Page',
#  'Q3037956': 'Doug Sweetland',
#  'Q1179049': 'Day & Night (2010 film)',
#  'Q755186': 'Doom II',
#  'Q1095605': 'Claris',
#  'Q5482740': 'Programmer',
#  'Q64744044': 'Soul (2020 film)',
#  'Q2216535': 'Walt Disney Studios (division)',
#  'Q2893391': 'Anobit',
#  'Q2705121': 'Avie Tevanian',
#  'Q1541081': 'Grace Murray Hopper Award',
#  'Q24495873': 'Piper (film)',
#  'Q104978342': 'Fincy Pierre',
#  'Q912481': 'Mac OS X 10.0',
#  'Q746323': 'Lifted (2006 film)',
#  'Q1107679': 'Animation studio',
#  'Q270285': 'Apple TV',
#  'Q6983888': 'NeXT RISC Workstation',
#  'Q7737199': 'The Good Dinosaur',
#  'Q3281834': 'Malek Jandali',
#  'Q5975708': 'IWoz',
#  'Q29552': 'Democratic Party (United States)',
#  'Q1992382': 'Darla K. Anderson',
#  'Q18981': 'Apple I',
#  'Q15271001': 'Toy Story Toons',
#  'Q187278': 'Toy Story 3',
#  'Q21079862': 'Cars 3',
#  'Q18517638': 'Toy Story 4',
#  'Q15733028': 'Party Central',
#  'Q2619317': 'Bud Luckey',
#  'Q1820274': 'Gary (given name)',
#  'Q625645': 'Steve Jobs (book)',
#  'Q95386759': 'Out (2020 film)',
#  'Q55070849': 'Bao (film)',
#  'Q57901798': 'Pixar Short Films Collection, Volume 3',
#  'Q1206788': 'Your Friend the Rat',
#  'Q483325': 'Ellen DeGeneres',
#  'Q7808649': 'Tiny Toy Stories',
#  'Q127552': 'Pixar',
#  'Q16842521': 'The Bite in the Apple',
#  'Q131524': 'Entrepreneur',
#  'Q55386504': 'The Incredibles (franchise)',
#  'Q178648': 'Peripheral',
#  'Q29573231': 'Lou (2017 film)',
#  'Q167037': 'Corporation',
#  'Q913672': 'San Francisco Museum of Modern Art',
#  'Q1493021': 'National Academy of Engineering',
#  'Q658255': 'Subsidiary',
#  'Q111366198': 'Nobody Like U',
#  'Q9192103': 'Radiator Springs',
#  'Q5215619': 'Dancing with the Stars (American TV series) season 8',
#  'Q3074457': 'Floyd Norman',
#  'Q3553520': 'US Festival',
#  'Q1703163': 'Buzz Lightyear of Star Command: The Adventure Begins',
#  'Q855971': 'Pixar RenderMan',
#  'Q104587599': 'Burrow (film)',
#  'Q108607639': 'Nona (2021 film)',
#  'Q2983236': 'Lisa Brennan-Jobs',
#  'Q679527': 'Museum Boijmans Van Beuningen',
#  'Q18010990': 'Apple Pay',
#  'Q484876': 'Chief executive officer',
#  'Q2761378': 'Alvy Ray Smith',
#  'Q1206658': 'University of Colorado',
#  'Q37226': 'Teacher',
#  'Q7920563': 'Venus (yacht)',
#  'Q111165179': 'Nimona (film)',
#  'Q6680359': 'Loren Carpenter',
#  'Q352842': 'Teaching',
#  'Q97925311': 'Luca (2021 film)',
#  'Q217475': 'Tokyo Stock Exchange',
#  'Q9321426': 'Finding Dory',
#  'Q13409231': 'Atari, Inc.',
#  'Q5': 'Human',
#  'Q17132005': 'Hoover Medal',
#  'Q6116760': 'Jackling House',
#  'Q63959177': 'SparkShorts',
#  'Q20895867': 'Eve Jobs',
#  'Q59690895': 'Onward (film)',
#  'Q849363': 'The Vanguard Group',
#  'Q130365301': 'Dream Productions',
#  'Q1072759': "Mike's New Car",
#  'Q1264168': "Dug's Special Mission",
#  'Q60997373': 'Universal Scene Description',
#  'Q6902872': 'Monsters, Inc. (franchise)',
#  'Q2766': 'IPhone',
#  'Q16338': 'Personal computer',
#  'Q83962045': 'Loop (2020 film)',
#  'Q5209661': 'Daisuke Tsutsumi',
#  'Q14091': 'IMac',
#  'Q2245203': 'Museum of Industry (Ghent)',
#  'Q18754959': 'Steve Jobs (film)',
#  'Q124426107': 'Self (film)',
#  'Q104905': 'WALL-E',
#  'Q24496982': 'The Love Witch',
#  'Q1860': 'English language',
#  'Q5593916': 'Grammy Trustees Award',
#  'Q8763889': 'Category:Pixar in amusement parks',
#  'Q507423': 'Ralph Eggleston',
#  'Q3282637': 'Film producer',
#  'Q220638': 'HP-65',
#  'Q1137478': 'Macintosh 128K',
#  'Q4830453': 'Business',
#  'Q55070915': 'Domee Shi',
#  'Q6545959': 'Light & Heavy (film)',
#  'Q4927100': 'Stephen',
#  'Q4045099': 'NeXT Computer',
#  'Q108730501': 'A Spark Story',
#  'Q61483839': 'Purl (film)',
#  'Q11650': 'Electronics',
#  'Q1979607': 'Financier',
#  'Q615466': "Boundin'",
#  'Q1432544': 'Hackers: Heroes of the Computer Revolution',
#  'Q709063': 'Arthur D. Levinson',
#  'Q1630228': 'Presto (film)',
#  'Q7237455': 'Category:Pixar animated films',
#  'Q421253': 'Apple Store',
#  'Q7112182': 'Outline of Apple Inc.',
#  'Q880371': 'Software industry',
#  'Q21428001': "Riley's First Date?",
#  'Q265852': 'Tim Cook',
#  'Q864124': 'Los Altos, California',
#  'Q11661': 'Information technology',
#  'Q121734157': 'Make Something Wonderful',
#  'Q648357': 'FaceTime',
#  'Q14116': 'MacOS',
#  'Q6983882': 'NeXTMail',
#  'Q328723': 'Andrew Stanton',
#  'Q1798917': 'La Luna (2011 film)',
#  'Q9479': 'IPod',
#  'Q98410583': 'Ken Segall',
#  'Q4200363': 'Template:Pixar',
#  'Q3072261': "The Legend of Mor'du",
#  'Q93161': 'Edwin Catmull',
#  'Q171048': 'Toy Story',
#  'Q483382': 'Steve Wozniak',
#  'Q453094': 'Joe Ranft',
#  'Q6128032': 'James A. Bell',
#  'Q641362': 'Monsters University',
#  'Q2244246': 'The Pixar Story',
#  'Q1053574': 'Executive producer',
#  'Q24832112': 'Incredibles 2',
#  'Q271117': 'Andrea Jung',
#  'Q371482': 'Apple Lisa',
#  'Q5890521': 'Homestead High School (California)',
#  'Q3866789': 'Mr. Incredible and Pals',
#  'Q162768': 'Personal digital assistant',
#  'Q192212': 'Cars 2',
#  'Q2620855': 'Satellite Award for Best Animated or Mixed Media Feature',
#  'Q242345': 'S&P 500',
#  'Q85761667': 'Forky Asks a Question',
#  'Q1112582': "Red's Dream",
#  'Q132863': 'Finding Nemo',
#  'Q310960': 'Brad Bird',
#  'Q588806': 'Integer BASIC',
#  'Q75687': 'Mac (computer)',
#  'Q33999': 'Actor',
#  'Q1343730': 'Enrico Casarosa',
#  'Q937629': 'National Medal of Technology and Innovation',
#  'Q174811': 'Up (2009 film)',
#  'Q238331': 'Mona Simpson',
#  'Q3685364': 'Computer & Communications Industry Association',
#  'Q1004385': 'Jack-Jack Attack',
#  'Q748': 'Buddhism'}

# %%
import time

wikidata_id2alternative_name = {}
for id_ in ids:
    wikidata_id2alternative_name[id_] = get_alternative_labels(id_)
    time.sleep(0.3)

# %%
len(wikidata_id2alternative_name)
# Out:
# 489

# %%
wikidata_id2alternative_name
# Out:
# {'Q67311526': ['obalkyknih.cz', 'Obálky knih CZ'],
#  'Q43845': ['dealer',
#   'businessman',
#   'business person',
#   'businesswoman',
#   'business man',
#   'business woman',
#   'business people',
#   'businessmen',
#   'businesspeople'],
#  'Q5700571': ['Heinz Awards'],
#  'Q114304773': [],
#  'Q14094': ['Apple iPod Touch'],
#  'Q1150306': [],
#  'Q2252704': [],
#  'Q116790970': ['WGS 2015'],
#  'Q2730061': [],
#  'Q21974358': ['Zaltair 8800'],
#  'Q18002980': [],
#  'Q3818760': [],
#  'Q61740829': [],
#  'Q52987978': [],
#  'Q1426558': [],
#  'Q27910148': [],
#  'Q30587923': [],
#  'Q54809843': ['.usdz',
#   'Universal Scene Description Zipped AR format (USDC)',
#   'usdz'],
#  'Q269214': ['John A. Lasseter', 'John Alan Lasseter'],
#  'Q47265': ['Palo Alto (duplicate)', 'Palo Alto, CA', 'Palo Alto, California'],
#  'Q6983889': [],
#  'Q785706': [],
#  'Q168756': ['U.C. Berkeley',
#   'University of California–Berkeley',
#   'UCB',
#   'Berkeley',
#   'Cal',
#   'Berkeley University',
#   'berkeley.edu',
#   'Cal-Berkeley',
#   'UC Berkeley',
#   'Univ. of California Berkeley',
#   'University of California at Berkeley',
#   'University of California Berkeley'],
#  'Q8257564': [],
#  'Q6173448': ['vital articles level 4', 'Vital Articles/Expanded', 'WP:VA/E'],
#  'Q80978': ['Hewlett-Packard Development Company, L.P. (Spring, TX)',
#   'HP',
#   'Hewlett Packard',
#   'Hewlett-Packard Company',
#   'Hewlett-Packard Development Co.',
#   'Hewlett-Packard Development Company, L.P.',
#   'HP Development Company'],
#  'Q19673': ['Gore',
#   'Albert Gore',
#   'Al Gore Jr.',
#   'Albert Arnold "Al" Gore Jr.',
#   'Albert Arnold Gore',
#   'Albert Arnold Gore Jr.',
#   'Albert Gore Jr.'],
#  'Q20895861': [],
#  'Q7139120': [],
#  'Q15846027': [],
#  'Q17386294': [],
#  'Q18810921': [],
#  'Q189471': ['Cupertino, California', 'City of Cupertino', 'Cupertino, CA'],
#  'Q1193981': [],
#  'Q29545180': [],
#  'Q7852935': [],
#  'Q388105': [],
#  'Q48971': [],
#  'Q3966': ['device',
#   'hw',
#   'hardware',
#   'computer accessory',
#   'computer component',
#   'computer part',
#   'PC accessory',
#   'PC component',
#   'PC hardware',
#   'PC part'],
#  'Q42417740': [],
#  'Q6581097': ['boy',
#   'guy',
#   'm',
#   'male gender',
#   'male human',
#   'male person',
#   'man',
#   'masc',
#   'sterner sex',
#   'male character'],
#  'Q22645': ['smartphones', 'smart phone'],
#  'Q187726': [],
#  'Q89375091': [],
#  'Q28039357': ['Becky Neiman-Cobb'],
#  'Q82594': ['computer specialist', 'computer professional'],
#  'Q308993': ['NeXT Computer',
#   'Next Computer, Inc.',
#   'NeXT Software',
#   'Next Software, Inc.',
#   'Next, Inc.'],
#  'Q201652': ['JApple ][ series'],
#  'Q52946669': [],
#  'Q6144664': [],
#  'Q13512513': ['Secret History of Hacking'],
#  'Q3339157': [],
#  'Q269415': ['content delivery',
#   'ESD',
#   'digital delivery',
#   'electronic software distribution',
#   'online distribution'],
#  'Q21775892': ['Son of a Migrant from Syria'],
#  'Q122033318': [],
#  'Q7431115': [],
#  'Q104529717': ['Frank Abney', 'Frank Abney III'],
#  'Q17388808': ['Susan Lynne Wagner'],
#  'Q113877606': [],
#  'Q1140775': ['Reed'],
#  'Q749153': [],
#  'Q155972': ['tablet', 'tablet PC'],
#  'Q7365310': ['Ronald D. Sugar'],
#  'Q20243178': [],
#  'Q403': ['RS', 'SRB', 'Republic of Serbia', 'Republika Srbija', 'Srbija'],
#  'Q3283283': [],
#  'Q1589009': ['private company',
#   'close corporation',
#   'closely held corporation',
#   'private corporation',
#   'unlisted company',
#   'unquoted company'],
#  'Q28919280': ['Steve Hunter', 'Steven C. Hunter', 'Steven Hunter'],
#  'Q102265222': ['Larry Aupperle'],
#  'Q29000247': [],
#  'Q768941': ['Adventures of Andre and Wally B.',
#   'Adventures of André and Wally B.',
#   'The Adventures of Andre and Wally B.',
#   'The Adventures of André and Wally B.'],
#  'Q205375': [],
#  'Q99519556': [],
#  'P4768': ['cinematografo company ID',
#   'cinematografo ID',
#   'cinematografo name ID',
#   'cinematografo name or company ID',
#   'cinematografo person ID',
#   'cinematografo.it company ID',
#   'cinematografo.it ID',
#   'cinematografo.it person ID'],
#  'Q30': ['the States',
#   'the U.S.',
#   'the United States',
#   'the United States of America',
#   'the US',
#   'the USA',
#   'U. S.',
#   'U. S. A.',
#   'U.S.',
#   'U.S.A.',
#   'US of A',
#   'USA',
#   'America',
#   'United States',
#   'US',
#   'Murica',
#   'Merica',
#   'the U.S. of A',
#   'the U.S. of America',
#   'the U.S.A.',
#   'the US of A',
#   'the US of America',
#   'U.S. of America',
#   'US of America'],
#  'Q170035': [],
#  'Q28941300': ['Paul Reinhold Jobs'],
#  'Q113879962': [],
#  'Q7215242': [],
#  'Q15885268': [],
#  'Q121964267': [],
#  'Q9589': ['Apple iTunes'],
#  'Q5012809': [],
#  'Q1972984': [],
#  'Q108570386': [],
#  'Q57655560': ['American corporation',
#   'Inc.',
#   'Incorporated',
#   'U.S. corporation',
#   'US corporation',
#   'Corp.',
#   'corporation in the United States',
#   'United States corporation'],
#  'Q4038751': [],
#  'Q368215': ['App Store (iOS)',
#   'App Store (iPadOS)',
#   'Apple App Store',
#   'com.apple.AppStore'],
#  'Q914155': [],
#  'Q187266': [],
#  'Q99356246': [],
#  'Q115615897': [],
#  'Q63107776': ['BSE',
#   'B.S.E.',
#   'Bachelor of Science and Engineering',
#   'BScEng'],
#  'Q242446': ['LFL',
#   'Lucasfilm Limited',
#   'Lucasfilm Limited, LLC',
#   'Lucasfilm Ltd.',
#   'Lucasfilm Ltd. LLC',
#   'Lucasfilm, Ltd.'],
#  'Q128798957': [],
#  'Q28941339': ['1924-1986', 'Clara Hagopian'],
#  'Q3617636': [],
#  'Q212961': ['Ca body of pancreas',
#   'Ca head of pancreas',
#   'Ca tail of pancreas',
#   'malignant neoplasm of body of pancreas',
#   'malignant neoplasm of head of pancreas',
#   'malignant neoplasm of tail of pancreas'],
#  'Q22083845': [],
#  'Q3814511': [],
#  'Q99999126': [],
#  'Q24265062': ['Brian Stacy Fee'],
#  'Q115781990': [],
#  'Q463303': ['AAAS',
#   'American Academy',
#   'American Academy of Arts & Sciences'],
#  'Q2586695': [],
#  'Q93092': ['Bill Reeves'],
#  'Q69358316': [],
#  'Q73768396': [],
#  'Q19837': ['T. Lateef',
#   'Abdul Lateef Jandali',
#   'Steven Jobs',
#   'Steven Paul Jobs'],
#  'Q1982831': ['FileMaker'],
#  'Q100827636': [],
#  'Q5165806': ['NEMO'],
#  'Q24259046': [],
#  'Q8084438': [],
#  'Q507306': ['NASDAQ 100 Index', 'NASDAQ-100', 'NASDAQ-100、NDX'],
#  'Q595385': ['13W3', 'DB-13W3'],
#  'Q25696256': [],
#  'Q17316283': [],
#  'Q104394953': [],
#  'Q28975655': ['.rib', 'Renderman interchange format', 'RIB'],
#  'Q79341113': [],
#  'Q28366283': [],
#  'Q5616016': [],
#  'Q3017175': ['Apple ]['],
#  'Q2219678': [],
#  'Q112801489': [],
#  'Q80993': ['software science', 'SE', 'software technology'],
#  'Q56598901': [],
#  'Q117349926': ['Open Letter to Pause AI'],
#  'Q17019378': [],
#  'Q1657080': [],
#  'Q105810600': ['ASI'],
#  'Q25696231': [],
#  'Q16739993': [],
#  'Q4781260': [],
#  'Q392825': [],
#  'Q219635': ['BLK', 'BlackRock, Inc.'],
#  'Q41572664': ['Samuel Alex Lasseter'],
#  'Q7214353': [],
#  'Q936260': [],
#  'Q99830980': ['Jamie Baker', 'James S. Baker'],
#  'Q43035': [],
#  'Q213326': ['Incredibles'],
#  'Q126724302': [],
#  'P3874': [],
#  'Q92653': [],
#  'Q20666333': [],
#  'Q7953': ['Zen Buddhism', 'Thiền', '선 [Seon]', '禅 [Chán]'],
#  'Q486860': ['Mountain View, CA', 'Mountain View, California'],
#  'Q109307645': [],
#  'Q532423': ['Robert A. Iger', 'Robert Allen "Bob" Iger', 'Robert Iger'],
#  'Q797106': [],
#  'Q104409060': [],
#  'Q5031682': [],
#  'Q495377': ['Richmond, CA', 'Richmond, California'],
#  'Q108523862': ['Apple unionization', 'Apple unions'],
#  'Q54321224': ['Internet Giants: Masters of the Universe'],
#  'Q217583': ['Valley Falls Company',
#   'Berkshire Hathaway Inc.',
#   'Berkshire Hathaway Incorperation'],
#  'Q23795630': ['Steel Wool Games'],
#  'Q2522490': [],
#  'Q7627000': ['Stuart Reges'],
#  'Q5322166': ['design expert', 'CAD designer'],
#  'Q27964622': [],
#  'Q1546066': ['computer networking device',
#   'network device',
#   'network equipment',
#   'network hardware',
#   'networking equipment'],
#  'Q2681381': ['Art of Deception',
#   'The Art of Deception. Controlling the Human Element of Security'],
#  'Q113641997': [],
#  'Q1961036': ['Beats', 'Beats by Dr. Dre', 'Beats Electronics LLC'],
#  'Q26936286': ['Apple AirPods'],
#  'Q1334829': ['body-borne computer', 'wearable', 'wearables'],
#  'Q14330342': [],
#  'Q1455793': ['Jan Jaroslav Pinkava'],
#  'Q126796': [],
#  'Q6272244': ['Jonas Hale Rivera'],
#  'Q505549': ['Redwood City, CA', 'Redwood City, California'],
#  'Q122079709': [],
#  'Q3167700': [],
#  'Q104845027': [],
#  'Q7414': ['Walt Disney',
#   'Disney',
#   'Disney Brothers Cartoon Studio',
#   'Walt Disney Productions',
#   'The Walt Disney Studio',
#   'Walt Disney Company'],
#  'Q50448844': [],
#  'Q18336566': ['Steve (first name)', 'Steve (given name)'],
#  'Q21463549': [],
#  'Q111464892': [],
#  'Q736938': [],
#  'Q62': ['San Francisco, Calif.',
#   'SF',
#   'Frisco',
#   'SFO',
#   'The City by the Bay',
#   'The Golden City',
#   'Paris of the West',
#   'San Francisco, California',
#   'Baghdad by the Bay',
#   'City and County of San Francisco',
#   'San Fran',
#   'San Francisco County',
#   'San Francisco County, California',
#   'San Francisco, CA'],
#  'Q499178': ['City of Emeryville', 'Emeryville, CA', 'Emeryville, California'],
#  'Q47510529': [],
#  'Q1366018': ['NIHF'],
#  'Q60429770': [],
#  'Q1048090': ['Apple Inc. history',
#   'history of Apple',
#   'history of Apple Computer',
#   'history of Apple Computer Inc.',
#   'history of Apple Computer, Inc.'],
#  'Q508712': [],
#  'Q109796898': [],
#  'Q2840289': ['Blue Umbrella'],
#  'Q2796': [],
#  'Q1101201': [],
#  'Q17501985': ['Steven (first name)', 'Steven (given name)'],
#  'Q6881511': ['company', 'business enterprise', 'firm'],
#  'Q5020532': [],
#  'Q332591': [],
#  'Q7395176': [],
#  'Q1145731': ['UTS', 'University of Technology, Sydney'],
#  'Q740682': [],
#  'Q1809071': ['Musée des Modèles', 'Museum voor Sierkunst en Vormgeving'],
#  'Q509725': [],
#  'Q110553619': [],
#  'Q1762059': ['film company', 'movie production company', 'movie company'],
#  'Q18388277': ['IT company', 'tech company', 'IT firm'],
#  'Q7603552': ['SSgA'],
#  'Q29000259': [],
#  'Q2457085': ['Toy Story Toons: Hawaiian Vacation'],
#  'Q30137500': ['Apple Home Pod',
#   'Apple HomePod',
#   'AudioAccessory1,1',
#   'Home Pod'],
#  'Q16553': ['San José',
#   'San Jose, California',
#   'City of San Jose',
#   'City of San José',
#   'Pueblo de San Jose de Guadalupe',
#   'Pueblo de San José de Guadalupe',
#   'San Jose, CA',
#   'San José, CA',
#   'San José, California'],
#  'Q2347411': [],
#  'Q543179': ['Hal T. Hickel'],
#  'Q500279': [],
#  'Q3133593': ['Laurene Jobs', 'Laurene Powell-Jobs'],
#  'Q312': ['Apple Computer Inc',
#   'Apple Computer Inc.',
#   'Apple Incorporated',
#   'Apple, Inc'],
#  'Q581105': ['home electronics', 'household electronics'],
#  'Q105085154': [],
#  'Q29940924': [],
#  'Q75507275': [],
#  'Q357627': ['Peter Docter', 'Peter Hans Docter'],
#  'Q188740': ['MoMA',
#   'The Museum of Modern Art, New York',
#   'Museum of Modern Art (New York, N.Y.)'],
#  'Q97355518': [],
#  'Q5421417': [],
#  'Q37461660': [],
#  'Q16835875': [],
#  'Q2907405': [],
#  'Q1415395': ['motion picture industry', 'movie industry'],
#  'Q928272': [],
#  'Q216153': ["Bug's Life"],
#  'Q61895636': [],
#  'Q55303337': [],
#  'Q891723': ['publicly traded company',
#   'listed company',
#   'public corporation',
#   'publicly held company',
#   'publicly listed company'],
#  'Q5815826': ["Pixar's Coco"],
#  'Q431289': ['brandmark'],
#  'Q89': ['apple fruit'],
#  'Q111445092': [],
#  'Q1191023': [],
#  'Q3385305': [],
#  'Q60339057': ['Stanford Libraries Special Collections & University Archives',
#   'Stanford Libraries Special Collections and University Archives',
#   'Stanford University Archives',
#   'Stanford University Department of Special Collections and University Archives',
#   'Stanford University. Libraries. Department of Special Collections and University Archives',
#   'Stanford University. University Archives'],
#  'Q182153': [],
#  'Q638608': [],
#  'Q549465': [],
#  'Q18010946': ['iWatch', 'AppleWatch', '\uf8ff Watch'],
#  'Q19867262': [],
#  'Q5637266': [],
#  'Q179310': ['computer technology'],
#  'Q12125162': [],
#  'Q5449677': [],
#  'Q51954858': ['Academy Awards predictive Screening',
#   'Oscars predictive Screening'],
#  'Q3530531': ['Cars Toons: Tokyo Mater'],
#  'Q6941581': [],
#  'Q831367': ['NeXTStep', 'NEXTSTEP', 'OPENSTEP'],
#  'Q63925380': [],
#  'Q82059': ['NASDAQ - All Markets',
#   'Nasdaq Stock Market',
#   'National Association of Securities Dealers Automated Quotations',
#   'NASDAQ'],
#  'Q22073999': ['Joshua Cooley', 'J.P. Cooley'],
#  'Q19850847': [],
#  'P12142': [],
#  'Q121968022': [],
#  'Q736674': ['Colo',
#   'Boulder',
#   'Buffaloes',
#   'Buffalos',
#   'Buffs',
#   'C.U. Boulder',
#   'Colorado',
#   'Colorado University',
#   'colorado.edu',
#   'CU',
#   'CU at Boulder',
#   'CU Boulder',
#   'CU-Boulder',
#   'CUB',
#   'Golden Buffs',
#   'U of CO',
#   'U of Colo',
#   'U of Colorado',
#   'UC Boulder',
#   'UCB',
#   'Univ of CO',
#   'Univ of Colo',
#   'Univ of Colorado',
#   'University of CO',
#   'University of Colo',
#   'University of Colorado',
#   'University of Colorado at Boulder',
#   'University of Colorado, Boulder',
#   'U.C.B.'],
#  'Q1121749': ['perfectionist', 'perfectionistic'],
#  'Q7155402': [],
#  'Q4925623': ['Paul (first name)', 'Paul (given name)'],
#  'Q984177': ['Woodside, CA', 'Woodside, California'],
#  'P6740': ['Justia Patents organization ID'],
#  'Q1119662': ['Imagination Technologies (United Kingdom)'],
#  'Q28934506': [],
#  'Q180816': ['DJI', 'DJIA Component', 'Dow', 'Dow Jones', 'The Dow'],
#  'Q2477691': [],
#  'Q177491': [],
#  'Q5535894': [],
#  'Q50363815': ['Thomas Porter'],
#  'Q23662070': [],
#  'Q665908': ["Cars Toon: Mater's Tall Tales", "Mater's Tall Tales"],
#  'Q7397': ['computer software', 'computational tool'],
#  'Q7323403': ['Richard Page'],
#  'Q3037956': [],
#  'Q1179049': [],
#  'Q755186': ['Doom 2', 'Doom II: Hell on Earth'],
#  'Q1095605': ['Claris Inc.',
#   'Claris International',
#   'Claris International Inc.'],
#  'Q5482740': ['software developer',
#   'developer',
#   'computer programmer',
#   'dev',
#   'coder',
#   'software programmer'],
#  'Q64744044': [],
#  'Q2216535': ['The Walt Disney Studios'],
#  'Q2893391': ['Anobit Technolgies'],
#  'Q2705121': ['Avie', 'Avadis Tevanian'],
#  'Q1541081': ['ACM Grace Murray Hopper Award', 'Grace Murray Hopper Awards'],
#  'Q24495873': [],
#  'Q104978342': ['Fancy Pierre',
#   '@pierrefincy',
#   'pierrefincy',
#   'Pierre Fancy',
#   'p fincy',
#   'P. Fincy',
#   '@fincypierre',
#   'Fency Pierre',
#   'fincypierre',
#   'Jean F. Pierre',
#   'Jean Fincy Pierre',
#   'pierre fincy',
#   'Pierre, Fincy'],
#  'Q912481': [],
#  'Q746323': [],
#  'Q1107679': ['animation production company'],
#  'Q123312390': [],
#  'Q270285': ['iTV', 'AppleTV'],
#  'Q6983888': [],
#  'Q7737199': ['Good Dinosaur',
#   'The Good Dinosaur 3D',
#   'The Untitled Pixar Movie About Dinosaurs',
#   'Untitled Pixar Movie About Dinosaurs'],
#  'Q3281834': [],
#  'Q5975708': ['iWoz: From Computer Geek to Cult Icon: How I Invented the Personal Computer, Co-Founded Apple, and Had Fun Doing It'],
#  'Q24515300': [],
#  'Q29552': ['Democrat',
#   'The Democrats',
#   'Dems',
#   'Democrats',
#   'Democratic Party (United States)',
#   'Democratic Party of the United States',
#   'U.S. Democratic Party',
#   'United States Democratic Party',
#   'US Democratic Party'],
#  'Q1992382': ['Darla Kay Anderson'],
#  'Q18981': ['Apple-1', 'Apple Computer 1'],
#  'Q121975583': [],
#  'Q15271001': [],
#  'Q17593997': [],
#  'Q187278': [],
#  'Q7298416': [],
#  'Q21079862': [],
#  'Q52951676': [],
#  'Q18517638': ['Toy Story Four'],
#  'Q15733028': [],
#  'Q2619317': ['Bud E. Luckey',
#   'Bud Everett Luckey',
#   'William E. Luckey',
#   'William Luckey'],
#  'Q1820274': ['Gary (first name)', 'Gary (given name)'],
#  'Q625645': ["'' Steve Jobs ''", 'Steve Jobs (book)'],
#  'Q95386759': [],
#  'Q55070849': [],
#  'Q57901798': [],
#  'Q1206788': [],
#  'Q483325': [],
#  'Q7808649': [],
#  'Q127552': ['Graphics Group', 'Pixar Studios'],
#  'Q16842521': [],
#  'Q131524': ['undertaking'],
#  'Q3993230': [],
#  'Q55386504': ['Incredibles (franchise)'],
#  'Q178648': ['computer peripheral',
#   'computer peripherals',
#   'peripheral device',
#   'peripherals'],
#  'Q29573231': [],
#  'Q167037': ['corporated entity'],
#  'Q913672': ['SFMOMA', 'San Francisco Museum of Art'],
#  'Q3739104': ['death by natural causes',
#   'natural causation',
#   'natural cause',
#   'natural death'],
#  'Q24515051': [],
#  'Q1493021': ['NAE',
#   'U.S. National Academy of Engineering',
#   'United States National Academy of Engineering',
#   'US National Academy of Engineering'],
#  'Q658255': ['daughter company',
#   'subsidiary company',
#   'subsidiary undertaking',
#   'child company'],
#  'Q111366198': [],
#  'Q9192103': [],
#  'Q27883602': [],
#  'Q5215619': ['DWTS 8'],
#  'Q3074457': ['Floyd Ernest Norman'],
#  'Q3553520': [],
#  'Q4343358': ['Thanks, Steve'],
#  'Q109045843': [],
#  'Q1703163': [],
#  'Q855971': ['PhotoRealistic RenderMan', 'Pixar RenderMan', 'PRMan'],
#  'Q104587599': [],
#  'Q108607639': [],
#  'Q2983236': ['Lisa Nicole Brennan', 'Lisa Nicole Brennan-Jobs'],
#  'Q679527': ['Boijmans',
#   'Boijmans Van Beuningen',
#   'Musée Boymans-van Beuningen',
#   'Museum Boijmans',
#   'Museum Boijmans Van Beuningen (hoofdlocatie plus Depot Boijmans van Beuningen)'],
#  'Q15453962': ['Roger L. Gould'],
#  'Q18010990': ['ApplePay', '\uf8ffPay'],
#  'Q484876': ['CEO', 'chief executive', 'CE', 'CEx'],
#  'Q26265164': ['Jordan James Ranft'],
#  'Q2761378': ['A. R. Smith', 'Alvy Ray Smith III'],
#  'Q1206658': ['CU', 'U of Colorado'],
#  'Q37226': ['professor', 'educator', 'schoolmaster', 'schoolmistress'],
#  'Q7920563': ['IMO 1011836'],
#  'Q124618897': [],
#  'Q111165179': [],
#  'Q6680359': ['Loren C. Carpenter'],
#  'Q1055701': [],
#  'Q352842': ['instruction',
#   'teaching and instruction',
#   'instruction and teaching'],
#  'Q97925311': [],
#  'Q217475': ['TSE',
#   'TOKYO STOCK EXCHANGE, INC.',
#   'Tokyo Stock Exchange, Inc.',
#   'Tosho',
#   'Tōshō',
#   'TYO',
#   'XTKS',
#   'TOKYO STOCK EXCHANGE'],
#  'Q9321426': ['Dory', 'Finding Nemo 2'],
#  'Q13409231': ['Atari', 'Atari Inc.', 'WCI Games Inc.'],
#  'Q5': ['human being',
#   'humans',
#   'people',
#   'person',
#   'man',
#   'men',
#   'individual human',
#   'individual Homo sapien',
#   'non-fictional human',
#   'nonfictional human'],
#  'Q17132005': [],
#  'Q6116760': [],
#  'Q63959177': ['Pixar SparkShorts'],
#  'Q20895867': [],
#  'Q22442735': [],
#  'Q59690895': [],
#  'Q849363': ['Vanguard', 'Vanguard Group'],
#  'Q130365301': [],
#  'Q1072759': [],
#  'Q1264168': [],
#  'Q60997373': ['USD', 'OpenUSD'],
#  'Q34633481': [],
#  'Q6902872': ['Monsters', 'Monsters, Incorporated'],
#  'Q2766': ['Apple iPhone',
#   'IPhone',
#   'iPhone family',
#   'iPhone line',
#   'iPhone series'],
#  'Q16338': ['PC'],
#  'Q83962045': [],
#  'Q5209661': ['Dice Tsutsumi'],
#  'Q14091': [],
#  'Q2245203': ['MIAT',
#   'Industriemuseum Gent',
#   'Museum about industry, labour and textile',
#   'Museum of Industry (Ghent)',
#   'Museum of Industry, Work and Textiles'],
#  'Q18754959': [],
#  'Q30748112': [],
#  'Q124426107': [],
#  'Q104905': ['WALL·E', 'Wall-E'],
#  'Q24496982': ['Love Witch'],
#  'Q1860': ['English language',
#   'English-language',
#   'English (language)',
#   'The English language',
#   'English the Global Language'],
#  'Q3369375': [],
#  'Q5593916': [],
#  'Q72303384': [],
#  'Q94947914': [],
#  'Q8763889': [],
#  'Q507423': [],
#  'Q116956752': [],
#  'Q3282637': ['producer', 'movie producer', 'motion picture producer'],
#  'Q61875074': [],
#  'Q220638': [],
#  'Q107397371': [],
#  'Q1137478': [],
#  'Q4830453': [],
#  'Q55070915': [],
#  'Q24515261': [],
#  'Q6545959': ['Light &amp; Heavy'],
#  'Q108689908': [],
#  'Q4927100': [],
#  'Q4045099': ['NeXT Computer System'],
#  'Q108730501': [],
#  'Q61483839': [],
#  'Q11650': [],
#  'Q1979607': [],
#  'Q615466': [],
#  'Q27567211': [],
#  'Q1432544': ['Hackers'],
#  'Q709063': ['Arthur Levinson'],
#  'Q1630228': [],
#  'Q7237455': ['Category:Pixar movies'],
#  'Q20895866': ['Erin Siena Jobs', 'Erin Jobs'],
#  'Q60167777': [],
#  'Q421253': ['Apple Retail Store'],
#  'Q7112182': [],
#  'Q880371': ['computer software industry'],
#  'Q28941744': ['Joanne Carole Schieble', 'Joanne Carole Simpson'],
#  'Q21428001': [],
#  'Q265852': ['Timothy Cook',
#   'Tim Apple',
#   'Timothy D. Cook',
#   'Timothy Donald Cook'],
#  'Q864124': ['Los Altos, CA', 'Los Altos, California'],
#  'Q26257952': ['Steve Jobs childhood house'],
#  'Q24515239': [],
#  'Q11661': ['IT', 'I.T.', 'info tech', 'Shelf:Information technology'],
#  'Q121734157': [],
#  'Q648357': [],
#  'Q14116': ['OSX',
#   'Mac OS',
#   'Mac OS 10',
#   'Mac OS X',
#   'Macintosh Operating System X',
#   'OS X'],
#  'Q6983882': [],
#  'Q328723': ['Andrew Ayers Stanton', 'Andrew Christopher Stanton Jr.'],
#  'Q1798917': ['Luna'],
#  'Q9479': ['Apple iPod'],
#  'Q98410583': [],
#  'Q22442738': [],
#  'Q55570924': [],
#  'Q4200363': [],
#  'Q3072261': ["Legend of Mor'du"],
#  'Q93161': ['Ed Catmull', 'Edwin E. Catmull', 'Edwin Earl Catmull'],
#  'Q73555012': ['copyrighted work',
#   'oeuvre copyrighted',
#   'work copyrighted',
#   'works are copyrighted',
#   'works in copyright'],
#  'Q98525448': [],
#  'Q1233073': ['Walt Disney Motion Pictures Group, Inc.'],
#  'Q171048': ['Toy Story 1'],
#  'Q483382': ['Mr. Steve Wozniak',
#   'Stephan Gary Wozniak',
#   'Stephen Gary Wozniak',
#   'Stephen Wozniak',
#   'The Woz',
#   'Woz'],
#  'Q22442739': [],
#  'Q453094': ['Joseph Henry Ranft'],
#  'Q6128032': ['James Aaron Bell'],
#  'Q27941349': [],
#  'Q121333773': [],
#  'Q641362': [],
#  'Q2244246': ['Pixar Story'],
#  'Q1053574': ['EP'],
#  'P11345': ['CineDataBase cast ID', 'Cinematografo.it cast ID (new)'],
#  'Q24832112': ['incredible 2',
#   'Incredibles 2 in Disney Digital 3D',
#   'Incredibles2',
#   'The Incredibles 2',
#   'The Incredibles 2 in Disney Digital 3D'],
#  'Q15613750': [],
#  'Q271117': [],
#  'Q371482': ['Lisa', 'The Lisa'],
#  'Q5890521': [],
#  'Q3866789': [],
#  'Q162768': ['pda', 'PDA'],
#  'Q192212': [],
#  'Q2620855': [],
#  'Q242345': ['S&P',
#   'S & P 500',
#   'S&P 500 Component',
#   'S&P 500 Index',
#   "Standard & Poor's 500"],
#  'Q28971229': ['Bobby Alcid Rubio'],
#  'Q17290934': [],
#  'Q28869465': ['Rob Gibbs', 'Robert James Gibbs'],
#  'Q85761667': [],
#  'Q1112582': [],
#  'Q132863': ['Nemo'],
#  'Q12605967': ['A. F. J. Jandali'],
#  'Q310960': ['Bradley Bird', 'Phillip Bradley Bird'],
#  'Q52986630': [],
#  'Q108256281': [],
#  'Q588806': [],
#  'Q7245704': [],
#  'Q75687': ['Macintosh',
#   'Apple Mac',
#   'Apple Macintosh',
#   'Mac Computers',
#   'MacInTosh',
#   'Macintosh Computer'],
#  'Q33999': ['movie actress',
#   'actors',
#   'actresses',
#   'movie actresses',
#   'actress'],
#  'Q1343730': [],
#  'Q100826648': [],
#  'Q937629': [],
#  'Q174811': [],
#  'Q238331': [],
#  'Q3685364': ['CCIA', 'Computer and Communications Industry Association'],
#  'Q1004385': [],
#  'Q748': ['Dharma',
#   'Bauddha Dhamma',
#   'Bauddha Dharma',
#   'Buddha Dhamma',
#   'Buddha Dharma',
#   'Buddhist religion',
#   'Dhamma',
#   'Dharmavinaya',
#   'Fo-chiao',
#   'Fo-Kiao',
#   'Fojiao']}

# %%
all_df['wiki_subj'] = all_df['subj_id'].apply(lambda x: wikidata_id2wiki_mapping[x] if x in wikidata_id2wiki_mapping else None)
all_df['wiki_obj'] = all_df['obj_id'].apply(lambda x: wikidata_id2wiki_mapping[x] if x in wikidata_id2wiki_mapping else None)

all_df
# Out:
#            subject       predicate                          object  \
# 0       Steve Jobs  place of birth                   San Francisco
# 1       Steve Jobs  place of death                       Palo Alto
# 2       Steve Jobs   sex or gender                            male
# 3       Steve Jobs          father             Abdulfattah Jandali
# 4       Steve Jobs          mother  Joanne Carole Schieble Simpson
# ..             ...             ...                             ...
# 42           macOS   influenced by                            NeXT
# 43       NeXT logo      represents                            NeXT
# 44          DB13W3         used by                            NeXT
# 45  Motorola 56001         used by                            NeXT
# 47       NeXT logo       symbol of                            NeXT
#
#        subj_id     obj_id   wiki_subj               wiki_obj
# 0       Q19837        Q62  Steve Jobs          San Francisco
# 1       Q19837     Q47265  Steve Jobs  Palo Alto, California
# 2       Q19837   Q6581097  Steve Jobs            Male gender
# 3       Q19837  Q12605967  Steve Jobs                   None
# 4       Q19837  Q28941744  Steve Jobs                   None
# ..         ...        ...         ...                    ...
# 42      Q14116    Q308993       MacOS                   NeXT
# 43   Q99519556    Q308993        None                   NeXT
# 44     Q595385    Q308993      DB13W3                   NeXT
# 45  Q115781990    Q308993        None                   NeXT
# 47   Q99519556    Q308993        None                   NeXT
#
# [617 rows x 7 columns]

# %%
all_df = all_df.dropna()
all_df
# Out:
#            subject               predicate                    object  \
# 0       Steve Jobs          place of birth             San Francisco
# 1       Steve Jobs          place of death                 Palo Alto
# 2       Steve Jobs           sex or gender                      male
# 5       Steve Jobs                  spouse       Laurene Powell Jobs
# 6       Steve Jobs  country of citizenship  United States of America
# ..             ...                     ...                       ...
# 39  NeXTcube Turbo               developer                      NeXT
# 40   Category:NeXT   category's main topic                      NeXT
# 41         Doom II                platform                      NeXT
# 42           macOS           influenced by                      NeXT
# 44          DB13W3                 used by                      NeXT
#
#      subj_id    obj_id       wiki_subj               wiki_obj
# 0     Q19837       Q62      Steve Jobs          San Francisco
# 1     Q19837    Q47265      Steve Jobs  Palo Alto, California
# 2     Q19837  Q6581097      Steve Jobs            Male gender
# 5     Q19837  Q3133593      Steve Jobs    Laurene Powell Jobs
# 6     Q19837       Q30      Steve Jobs          United States
# ..       ...       ...             ...                    ...
# 39  Q6983889   Q308993  NeXTcube Turbo                   NeXT
# 40  Q7214353   Q308993   Category:NeXT                   NeXT
# 41   Q755186   Q308993         Doom II                   NeXT
# 42    Q14116   Q308993           MacOS                   NeXT
# 44   Q595385   Q308993          DB13W3                   NeXT
#
# [475 rows x 7 columns]

# %%
all_df.to_csv("wikidata_df.csv")

# %%
df = pd.read_csv('full_triplets.csv', index_col=0)
df = df.reset_index(drop=True)
# df = df.drop_duplicates()
df
# Out:
#                                                subject  \
# 0                                     Steven Paul Jobs
# 1                                     Steven Paul Jobs
# 2                                     Steven Paul Jobs
# 3                                     Steven Paul Jobs
# 4                                     Steven Paul Jobs
# ..                                                 ...
# 286  several other businesses and philanthropic ven...
# 287  several other businesses and philanthropic ven...
# 288  several other businesses and philanthropic ven...
# 289  several other businesses and philanthropic ven...
# 290  several other businesses and philanthropic ven...
#
#                    relation                                  object
# 0             date of birth                       February 24, 1955
# 1             date of death                         October 5, 2011
# 2    country of citizenship                United States of America
# 3                occupation                             Businessman
# 4                occupation                                Inventor
# ..                      ...                                     ...
# 286          specialized in                          Microprocessor
# 287          specialized in  technology and pop culture conventions
# 288          specialized in              technology in K–12 schools
# 289          specialized in                 environmental practices
# 290          specialized in                              satellites
#
# [291 rows x 3 columns]

# %%
wikipedia_subjects = list(df.subject.unique())
wikipedia_objects = list(df.object.unique())
wikipedia_entities = list(set(wikipedia_subjects + wikipedia_objects))

wikipedia_relations = list(df.relation.unique())
len(wikipedia_entities), len(wikipedia_relations)
# Out:
# (195, 54)

# %%
aligned_triplets = []
for _, row in all_df.iterrows():

    triplet_alternative = {"subject": row["subject"], "relation": row["predicate"], "object": row["object"]}
    
    subject_alternatives = wikidata_id2alternative_name[row['subj_id']] + [row['wiki_subj'], row['subject']]
    
    for name in subject_alternatives:
        if name in wikipedia_entities:
            triplet_alternative['subject'] = name
            break

    object_alternatives = wikidata_id2alternative_name[row['obj_id']] + [row['wiki_obj'], row['object']]

    for name in object_alternatives:
        if name in wikipedia_entities:
            triplet_alternative['object'] = name
            break
    aligned_triplets.append(triplet_alternative)

aligned_df = pd.DataFrame(aligned_triplets)
aligned_df
# Out:
#               subject                relation                    object
# 0    Steven Paul Jobs          place of birth             San Francisco
# 1    Steven Paul Jobs          place of death                 Palo Alto
# 2    Steven Paul Jobs           sex or gender                      male
# 3    Steven Paul Jobs                  spouse       Laurene Powell Jobs
# 4    Steven Paul Jobs  country of citizenship  United States of America
# ..                ...                     ...                       ...
# 470    NeXTcube Turbo               developer                      NeXT
# 471     Category:NeXT   category's main topic                      NeXT
# 472           Doom II                platform                      NeXT
# 473          Mac OS X           influenced by                      NeXT
# 474            DB13W3                 used by                      NeXT
#
# [475 rows x 3 columns]

# %%
wikidata_subjects = list(aligned_df.subject.unique())
wikidata_objects = list(aligned_df.object.unique())
wikidata_entities = list(set(wikidata_subjects + wikidata_objects))

wikidata_relations = list(aligned_df.relation.unique())
len(wikidata_entities), len(wikidata_relations)
# Out:
# (357, 92)

# %% [markdown]
# ## Comparing with the composed KG

# %%
import torch
import numpy as np
from transformers import AutoTokenizer, AutoModel

# %%
device = "cuda:5"
tokenizer = AutoTokenizer.from_pretrained('facebook/contriever')
model = AutoModel.from_pretrained('facebook/contriever').to(device)

# %%
def mean_pooling(token_embeddings, mask):
    token_embeddings = token_embeddings.masked_fill(~mask[..., None].bool(), 0.)
    sentence_embeddings = token_embeddings.sum(dim=1) / mask.sum(dim=1)[..., None]
    return sentence_embeddings


def embed_batch(names):
    inputs = tokenizer(names, padding=True, truncation=True, return_tensors='pt')
    outputs = model(**inputs.to(device))
    embeddings = mean_pooling(outputs[0], inputs['attention_mask'])
    return np.array(embeddings.detach().cpu())

# %%
embed_batch(["Steve Jobs", "Stephen Woznyak"]).shape
# Out:
# (2, 768)

# %%
all_df.to_csv("wikidata_df.csv")

# %%
len(set(wikidata_entities) & set(wikipedia_entities))
# Out:
# 62

# %%
wikipedia_entities_embedded = embed_batch(wikipedia_entities)
wikipedia_entities_embedded.shape
# Out:
# (195, 768)

# %%
wikipedia_relations_embedded = embed_batch(wikipedia_relations)
wikipedia_relations_embedded.shape
# Out:
# (54, 768)

# %%
wikidata_entities_embedded = embed_batch(wikidata_entities)
wikidata_entities_embedded.shape
# Out:
# (357, 768)

# %%
wikidata_relations_embedded = embed_batch(wikidata_relations)
wikidata_relations_embedded.shape
# Out:
# (92, 768)

# %%
from sklearn import metrics

relation_similarity_matrix = metrics.pairwise.cosine_similarity(wikidata_relations_embedded, wikipedia_relations_embedded)
relation_similarity_matrix.shape
# Out:
# (92, 54)

# %%
entity_similarity_matrix = metrics.pairwise.cosine_similarity(wikidata_entities_embedded, wikipedia_entities_embedded)
entity_similarity_matrix.shape
# Out:
# (357, 195)

# %%
best_entity_pairs = np.argmax(entity_similarity_matrix, axis=0)
len(best_entity_pairs)
# Out:
# 195

# %%
pedia2data_entity = {}
best_entity_pairs = np.argmax(entity_similarity_matrix, axis=0)

for i, _ in enumerate(wikipedia_entities):
    if entity_similarity_matrix[best_entity_pairs[i]][i] > 0.5:
        pedia2data_entity[wikipedia_entities[i]] = wikidata_entities[best_entity_pairs[i]]
pedia2data_entity
# Out:
# {'iPad': 'iPad',
#  '1.5 million shares': 'Nasdaq',
#  'Steven Paul Jobs': 'Steven Paul Jobs',
#  'Technology company': 'Technology company',
#  'Computer graphics division of Lucasfilm': 'Lucasfilm',
#  'Toy Story 4': 'Toy Story 4',
#  'Apple Watch': 'Apple Watch',
#  'NeXTcube': 'NeXTcube',
#  'Computers for higher-education and business markets': 'computing',
#  "NeXTSTEP operating system's application layer": 'NeXTSTEP',
#  'Electronic kit form': 'Music Kit',
#  'Finding Dory': 'Finding Dory',
#  'iPhone': 'iPhone',
#  '50 highest-grossing films of all time': 'film industry',
#  'NeXT': 'NeXT',
#  'iCloud': 'iPhone',
#  'NeXTstation': 'NeXTstation',
#  'WALL-E': 'WALL-E',
#  'John Lasseter': 'John Lasseter',
#  'revenue': 'chief executive officer',
#  'iPod': 'iPod',
#  'Disney Entertainment': 'Disney',
#  'Apple I personal computer': 'Personal computer',
#  'Mac OS X': 'Mac OS X',
#  'market capitalization': 'Dow Jones Industrial Average',
#  'Graphical user interface': 'Mac OS X',
#  '$3.2 trillion': 'S&P 500',
#  'advertising campaign': 'brand',
#  'satellites': 'Planes',
#  'Mouse': 'Macintosh',
#  'RenderMan': 'RenderMan',
#  'Software': 'Software',
#  'dynamic web pages': 'Rich Page',
#  'Vector graphics': 'programmer',
#  '1984': 'actor',
#  'Grammy Award': 'Grammy Trustees Award',
#  'Walt Disney Studios': 'Walt Disney Studios',
#  '1979': 'actor',
#  'Emeryville, California': 'Emeryville, California',
#  'third-party operating systems': 'Mac OS X',
#  'October 5, 2011': 'iTunes',
#  'Macintosh': 'Macintosh',
#  'Incredibles 2': 'Incredibles 2',
#  'Apple LaserWriter': 'apple',
#  'United Kingdom': 'United States of America',
#  'United States of America': 'United States of America',
#  'pancreatic neuroendocrine tumor': 'pancreatic cancer',
#  'Apple Computer, Inc.': 'Apple Inc.',
#  '2019': 'actor',
#  'Inside Out 2': 'Inside Out 2',
#  'Multinational corporation': 'corporation',
#  'Golden Lion for Lifetime Achievement': 'Heinz Award',
#  'hardware industry': 'computer hardware',
#  'Reed College': 'Reed College',
#  'CL 9': 'CL 9',
#  '3D computer-animated feature film': 'Satellite Award for Best Animated or Mixed Media Feature',
#  'Laser printer': 'tablet computer',
#  'Desktop publishing industry': 'software industry',
#  'iTunes': 'iTunes',
#  '1977': 'actor',
#  'Toy Story 3': 'Toy Story 3',
#  'Soul': 'Soul',
#  'Presidential Medal of Freedom': 'Hoover Medal',
#  'several other businesses and philanthropic ventures': 'entrepreneur',
#  'Luxo Jr.': 'Luxo Jr.',
#  'Coco': 'Coco',
#  'Zen Buddhism': 'Zen Buddhism',
#  'Inventor': 'Inventor',
#  'Redwood City': 'Redwood City',
#  'Pixar': 'Pixar',
#  'App Store': 'App Store',
#  'Cupertino': 'Cupertino',
#  'microcomputer': 'computing',
#  '28 films': 'actor',
#  'Doom': 'Doom II',
#  'Inside Out': 'Inside Out',
#  'Apple Music': 'apple',
#  'Venice Film Festival': 'film producer',
#  'Consumer electronics': 'Consumer electronics',
#  'George Lucas': 'Lucasfilm',
#  'Andrew Stanton': 'Andrew Stanton',
#  'iMac': 'iMac',
#  '1981': 'actor',
#  'video game': 'Atari, Inc.',
#  '15 of the 50 highest-grossing animated films of all time': 'Satellite Award for Best Animated or Mixed Media Feature',
#  'iTunes Store': 'iTunes',
#  'The Incredibles': 'The Incredibles',
#  'Hobbyists and technicians': 'electronics',
#  'Apple II': 'Apple II',
#  '1987': 'actor',
#  '1988': 'actor',
#  'Finding Nemo': 'Finding Nemo',
#  'Personal computer revolution': 'Personal computer',
#  'Pete Docter': 'Pete Docter',
#  '1983': 'actor',
#  'Lisa': 'Lisa',
#  'Academy Award': 'film producer',
#  'Businessman': 'film producer',
#  'Sun Microsystems': 'computing',
#  'Woz': 'Woz',
#  '1986 short film': 'Pixar Short Films Collection, Volume 3',
#  'Tim Cook': 'Tim Cook',
#  'Think different': 'Think different',
#  'San Francisco': 'San Francisco',
#  'Apple Lisa': 'Lisa',
#  '1995': 'Macintosh',
#  'Human–computer interface expert': 'computer scientist',
#  'many short films': 'film industry',
#  'Gap Inc.': 'Apple Inc.',
#  'technology in K–12 schools': 'information technology',
#  'Disney': 'Disney',
#  'Mainframe computer': 'computing',
#  'Personal computer': 'Personal computer',
#  'Apple Store retail chain': 'Apple Store',
#  'telecommunications': 'information technology',
#  'Microprocessor': 'computing',
#  'Academy Award for Best Picture': 'film producer',
#  'GPS': 'smartphone',
#  'OPENSTEP for Mach': 'OpenStep',
#  'Steve Wozniak': 'Steven Woznick',
#  'Apple TV': 'Apple TV',
#  'Apple Inc.': 'Apple Inc.',
#  'India': 'actor',
#  'Apple Pay': 'Apple Pay',
#  'Toy Story': 'Toy Story',
#  'iOS': 'iPad',
#  'OpenStep': 'OpenStep',
#  'Object-oriented programming': 'programmer',
#  'Brave': 'Brave',
#  'Apple I': 'Apple I',
#  'Xerox Alto': 'Palo Alto',
#  'Ratatouille': 'Ratatouille',
#  'Up': 'Up',
#  'Brad Bird': 'Brad Bird',
#  '1976': 'actor',
#  'Animation studio': 'Animation studio',
#  'business ethics': 'business',
#  "One of the world's most valuable brands": 'brand',
#  'Walt Disney Company': 'Walt Disney Studios',
#  'Golden Globe Award': 'film producer',
#  'Lucasfilm': 'Lucasfilm',
#  '2018': 'smartphone',
#  'switching power supply': 'networking hardware',
#  '1986': 'actor',
#  'CEO of Apple': 'apple'}

# %%
len(pedia2data_entity)
# Out:
# 145

# %%
pedia2data_relation = {}
best_relation_pairs = np.argmax(relation_similarity_matrix, axis=0)

for i, _ in enumerate(wikipedia_relations):
    if relation_similarity_matrix[best_relation_pairs[i]][i] > 0.5:
        pedia2data_relation[wikipedia_relations[i]] = wikidata_relations[best_relation_pairs[i]]
pedia2data_relation
# Out:
# {'date of birth': 'place of birth',
#  'date of death': 'place of birth',
#  'country of citizenship': 'country of citizenship',
#  'occupation': 'occupation',
#  'notable work': 'notable work',
#  'founder of': 'founded by',
#  'business partner': 'board member',
#  'place of birth': 'place of birth',
#  'educated at': 'educated at',
#  'instance of': 'instance of',
#  'developer': 'developer',
#  'influenced': 'influenced by',
#  'has part': 'part of',
#  'specialized in': 'founded by',
#  'funded': 'commissioned by',
#  'acquired': 'owned by',
#  'died of': 'cause of death',
#  'award received': 'award received',
#  'headquarters location': 'headquarters location',
#  'inception': 'founded by',
#  'revenue': 'chief executive officer',
#  'returned to': 'educated at',
#  'succeeded': 'educated at',
#  'largest manufacturing company by': 'manufacturer',
#  'largest vendor of': 'manufacturer',
#  'market capitalization': 'stock exchange',
#  'has': 'industry',
#  'developed': 'developer',
#  'hosted on': 'distributed by',
#  'contrast with': 'different from',
#  'shares issued': 'stock exchange',
#  'division of': 'part of',
#  'majority shareholder of': 'chief executive officer',
#  'mascot of': 'mascot',
#  'part of': 'part of',
#  'award nomination': 'award received',
#  'employment status': 'employer'}

# %%
len(pedia2data_relation)
# Out:
# 37

# %%
triplet_pairs = []

for i, row in df.iterrows():
    data_subj = pedia2data_entity[row['subject']] if row['subject'] in pedia2data_entity else None 
    data_obj = pedia2data_entity[row['object']] if row['object'] in pedia2data_entity else None
    data_rel = pedia2data_relation[row['relation']] if row['relation'] in pedia2data_relation else None

    if data_subj and data_obj and data_rel:
        triplet = aligned_df[(aligned_df['subject'] == data_subj) & (aligned_df['object'] == data_obj) & (aligned_df['relation'] == data_rel)]
        if len(triplet) > 0:
            triplet_pairs.append(((row['subject'], row['relation'], row['object']), (triplet.iloc[0,0], triplet.iloc[0,1], triplet.iloc[0,2])))

# %%
len(triplet_pairs), triplet_pairs
# Out:
# (19,
#  [(('Steven Paul Jobs', 'country of citizenship', 'United States of America'),
#    ('Steven Paul Jobs', 'country of citizenship', 'United States of America')),
#   (('Steven Paul Jobs', 'occupation', 'Businessman'),
#    ('Steven Paul Jobs', 'occupation', 'film producer')),
#   (('Steven Paul Jobs', 'occupation', 'Inventor'),
#    ('Steven Paul Jobs', 'occupation', 'Inventor')),
#   (('Apple Inc.', 'founder of', 'Steven Paul Jobs'),
#    ('Apple Inc.', 'founded by', 'Steven Paul Jobs')),
#   (('Steven Paul Jobs', 'place of birth', 'San Francisco'),
#    ('Steven Paul Jobs', 'place of birth', 'San Francisco')),
#   (('Steven Paul Jobs', 'educated at', 'Reed College'),
#    ('Steven Paul Jobs', 'educated at', 'Reed College')),
#   (('Pixar', 'instance of', 'Animation studio'),
#    ('Pixar', 'instance of', 'Animation studio')),
#   (('Steven Paul Jobs', 'notable work', 'iMac'),
#    ('Steven Paul Jobs', 'notable work', 'iMac')),
#   (('Steven Paul Jobs', 'notable work', 'iTunes'),
#    ('Steven Paul Jobs', 'notable work', 'iTunes')),
#   (('Apple Inc.', 'instance of', 'Multinational corporation'),
#    ('Apple Inc.', 'instance of', 'corporation')),
#   (('Apple Inc.', 'headquarters location', 'Cupertino'),
#    ('Apple Inc.', 'headquarters location', 'Cupertino')),
#   (('Apple Inc.', 'instance of', "One of the world's most valuable brands"),
#    ('Apple Inc.', 'instance of', 'brand')),
#   (('NeXT', 'headquarters location', 'Redwood City'),
#    ('NeXT', 'headquarters location', 'Redwood City')),
#   (('NeXT', 'inception', 'Steven Paul Jobs'),
#    ('NeXT', 'founded by', 'Steven Paul Jobs')),
#   (('Graphical user interface', 'influenced', 'NeXT'),
#    ('Mac OS X', 'influenced by', 'NeXT')),
#   (('Apple Inc.', 'shares issued', '1.5 million shares'),
#    ('Apple Inc.', 'stock exchange', 'Nasdaq')),
#   (('Pixar', 'headquarters location', 'Emeryville, California'),
#    ('Pixar', 'headquarters location', 'Emeryville, California')),
#   (('RenderMan', 'developed', 'Pixar'), ('RenderMan', 'developer', 'Pixar')),
#   (('Apple Inc.', 'inception', 'Steven Paul Jobs'),
#    ('Apple Inc.', 'founded by', 'Steven Paul Jobs'))])

# %%
wikidata_triplets = list(aligned_df['subject'] +  " " + aligned_df['relation'] + " " + aligned_df['object'])
wikipedia_triplets =  list(df['subject'] +  " " + df['relation'] + " " + df['object'])

# %%
wikidata_triplets[:10]
# Out:
# ['Steven Paul Jobs place of birth San Francisco',
#  'Steven Paul Jobs place of death Palo Alto',
#  'Steven Paul Jobs sex or gender male',
#  'Steven Paul Jobs spouse Laurene Powell Jobs',
#  'Steven Paul Jobs country of citizenship United States of America',
#  'Steven Paul Jobs instance of human',
#  'Steven Paul Jobs position held chief executive officer',
#  'Steven Paul Jobs child Lisa Brennan-Jobs',
#  'Steven Paul Jobs child Eve Jobs',
#  'Steven Paul Jobs educated at De Anza College']

# %%
wikipedia_triplets[:10]
# Out:
# ['Steven Paul Jobs date of birth February 24, 1955',
#  'Steven Paul Jobs date of death October 5, 2011',
#  'Steven Paul Jobs country of citizenship United States of America',
#  'Steven Paul Jobs occupation Businessman',
#  'Steven Paul Jobs occupation Inventor',
#  'Steven Paul Jobs notable work Apple Inc.',
#  'Steven Paul Jobs founder of NeXT',
#  'Steven Paul Jobs founder of Pixar',
#  'Steven Paul Jobs notable work Personal computer revolution',
#  'Steven Paul Jobs business partner Steve Wozniak']

# %%
set(wikipedia_triplets) & set(wikidata_triplets), len(set(wikipedia_triplets) & set(wikidata_triplets))
# Out:
# ({'Apple Inc. headquarters location Cupertino',
#   'NeXT headquarters location Redwood City',
#   'Pixar headquarters location Emeryville, California',
#   'Pixar instance of Animation studio',
#   'Steven Paul Jobs country of citizenship United States of America',
#   'Steven Paul Jobs educated at Reed College',
#   'Steven Paul Jobs notable work iMac',
#   'Steven Paul Jobs notable work iTunes',
#   'Steven Paul Jobs occupation Inventor',
#   'Steven Paul Jobs place of birth San Francisco'},
#  10)

# %%
wikidata_triplets_embedded = embed_batch(wikidata_triplets)
wikidata_triplets_embedded.shape
# Out:
# (475, 768)

# %%
wikipedia_triplets_embedded = embed_batch(wikipedia_triplets)
wikipedia_triplets_embedded.shape
# Out:
# (291, 768)

# %%
triplet_similarity_matrix = metrics.pairwise.cosine_similarity(wikidata_triplets_embedded, wikipedia_triplets_embedded)
triplet_similarity_matrix.shape
# Out:
# (475, 291)

# %%
best_triplet_pairs = np.argmax(triplet_similarity_matrix, axis=0)
best_triplet_pairs.shape
# Out:
# (291,)

# %%
triplet_pairs = []

for i, _ in enumerate(wikipedia_triplets):
    if triplet_similarity_matrix[best_triplet_pairs[i]][i] > 0.5:
        triplet_pairs.append((wikipedia_triplets[i], wikidata_triplets[best_triplet_pairs[i]]))

# %%
len(triplet_pairs)
# Out:
# 260

# %%
aligned_df
# Out:
#               subject                relation                    object
# 0    Steven Paul Jobs          place of birth             San Francisco
# 1    Steven Paul Jobs          place of death                 Palo Alto
# 2    Steven Paul Jobs           sex or gender                      male
# 3    Steven Paul Jobs                  spouse       Laurene Powell Jobs
# 4    Steven Paul Jobs  country of citizenship  United States of America
# ..                ...                     ...                       ...
# 470    NeXTcube Turbo               developer                      NeXT
# 471     Category:NeXT   category's main topic                      NeXT
# 472           Doom II                platform                      NeXT
# 473          Mac OS X           influenced by                      NeXT
# 474            DB13W3                 used by                      NeXT
#
# [475 rows x 3 columns]

# %%
aligned_df
# Out:
#               subject                relation                    object
# 0    Steven Paul Jobs          place of birth             San Francisco
# 1    Steven Paul Jobs          place of death                 Palo Alto
# 2    Steven Paul Jobs           sex or gender                      male
# 3    Steven Paul Jobs                  spouse       Laurene Powell Jobs
# 4    Steven Paul Jobs  country of citizenship  United States of America
# ..                ...                     ...                       ...
# 470    NeXTcube Turbo               developer                      NeXT
# 471     Category:NeXT   category's main topic                      NeXT
# 472           Doom II                platform                      NeXT
# 473          Mac OS X           influenced by                      NeXT
# 474            DB13W3                 used by                      NeXT
#
# [475 rows x 3 columns]

# %% [markdown]
# ## Comparing with linked names from wikipedia

# %%
pairs = []
pair_count = 0
edge_present = 0

counted_pairs = set()

wikipedia_common_triplets = []
wikidata_common_triplets = []


for _, row in aligned_df.iterrows():

    subj_name = row['subject']
    obj_name = row['object']


    if subj_name in wikipedia_entities and obj_name in wikipedia_entities:
        wikidata_common_triplets.append((row['subject'], row['relation'], row['object']))
        # edge_present += len(df[((df['subject'] == row['wiki_subj']) & (df['object'] == row['wiki_obj'])) | ((df['subject'] == row['wiki_obj']) & (df['object'] == row['wiki_subj']))])
        if (subj_name, obj_name) in counted_pairs or (obj_name, subj_name) in counted_pairs:
            continue
        else:
            edge_present += 1
            counted_pairs.add((subj_name, obj_name))

            intersected_triplets = df[((df['subject'] == subj_name) & (df['object'] == obj_name)) | ((df['subject'] == obj_name) & (df['object'] == subj_name))]

            if len(intersected_triplets) > 0:
                pair_count += 1
                for _, row_ in intersected_triplets.iterrows():
                    # wikidata_common_triplets.append((row['wiki_subj'], row['predicate'], row['wiki_obj']))
                    wikipedia_common_triplets.append((row_['subject'], row_['relation'], row_['object']))
                    # print(row['wiki_subj'], row['predicate'], row['wiki_obj'])
                    # print(row_['subject'], row_['relation'], row_['object'])
                    # print()
                # pair_count += len(intersected_triplets)
            
pair_count, pair_count/edge_present, edge_present
# Out:
# (44, 0.5714285714285714, 77)

# %%
"Up" in wikipedia_entities
# Out:
# True

# %%
df[df['subject'] == 'Up']
# Out:
#     subject          relation                          object
# 228      Up    award received                   Academy Award
# 236      Up  award nomination  Academy Award for Best Picture

# %%
for pedia_triplet, data_triplet in zip(wikipedia_common_triplets, wikidata_common_triplets):
    print(pedia_triplet, " | ", data_triplet)
# Out:
# ('Steven Paul Jobs', 'place of birth', 'San Francisco')  |  ('Steve Jobs', 'place of birth', 'San Francisco')
# ('Steven Paul Jobs', 'country of citizenship', 'United States of America')  |  ('Steve Jobs', 'country of citizenship', 'United States')
# ('Steven Paul Jobs', 'educated at', 'Reed College')  |  ('Steve Jobs', 'educated at', 'Reed College')
# ('Steven Paul Jobs', 'occupation', 'Inventor')  |  ('Steve Jobs', 'occupation', 'Inventor')
# ('Steven Paul Jobs', 'notable work', 'Apple Inc.')  |  ('Steve Jobs', 'employer', 'Apple Inc.')
# ('Apple Inc.', 'founder of', 'Steven Paul Jobs')  |  ('Steve Jobs', 'employer', 'Apple Inc.')
# ('Steven Paul Jobs', 'founder of', 'Apple Inc.')  |  ('Steve Jobs', 'employer', 'Apple Inc.')
# ('Steven Paul Jobs', 'departed from', 'Apple Inc.')  |  ('Steve Jobs', 'employer', 'Apple Inc.')
# ('Steven Paul Jobs', 'occupation', 'Apple Inc.')  |  ('Steve Jobs', 'employer', 'Apple Inc.')
# ('Steven Paul Jobs', 'influenced', 'Apple Inc.')  |  ('Steve Jobs', 'employer', 'Apple Inc.')
# ('Steven Paul Jobs', 'returned to', 'Apple Inc.')  |  ('Steve Jobs', 'employer', 'Apple Inc.')
# ('Steven Paul Jobs', 'participant', 'Apple Inc.')  |  ('Steve Jobs', 'employer', 'Apple Inc.')
# ('Apple Inc.', 'inception', 'Steven Paul Jobs')  |  ('Steve Jobs', 'employer', 'Apple Inc.')
# ('Steven Paul Jobs', 'founder of', 'Pixar')  |  ('Steve Jobs', 'employer', 'Pixar')
# ('Pixar', 'founder of', 'Steven Paul Jobs')  |  ('Steve Jobs', 'employer', 'Pixar')
# ('Steven Paul Jobs', 'funded', 'Pixar')  |  ('Steve Jobs', 'employer', 'Pixar')
# ('Steven Paul Jobs', 'majority shareholder of', 'Pixar')  |  ('Steve Jobs', 'employer', 'Pixar')
# ('Steven Paul Jobs', 'founder of', 'NeXT')  |  ('Steve Jobs', 'employer', 'NeXT')
# ('NeXT', 'inception', 'Steven Paul Jobs')  |  ('Steve Jobs', 'employer', 'NeXT')
# ('Steven Paul Jobs', 'occupation', 'NeXT')  |  ('Steve Jobs', 'employer', 'NeXT')
# ('Steven Paul Jobs', 'educated at', 'Zen Buddhism')  |  ('Steve Jobs', 'religion or worldview', 'Zen')
# ('Steven Paul Jobs', 'influenced', 'iPhone')  |  ('Steve Jobs', 'notable work', 'IPhone')
# ('Steven Paul Jobs', 'influenced', 'iPad')  |  ('Steve Jobs', 'notable work', 'IPad')
# ('Steven Paul Jobs', 'influenced', 'iPod')  |  ('Steve Jobs', 'notable work', 'IPod')
# ('Steven Paul Jobs', 'notable work', 'iTunes')  |  ('Steve Jobs', 'notable work', 'ITunes')
# ('Steven Paul Jobs', 'notable work', 'iMac')  |  ('Steve Jobs', 'notable work', 'IMac')
# ('Steven Paul Jobs', 'influenced', 'App Store')  |  ('Steve Jobs', 'notable work', 'App Store (Apple)')
# ('Steven Paul Jobs', 'notable work', 'Mac OS X')  |  ('MacOS', 'founded by', 'Steve Jobs')
# ('Apple Inc.', 'country of citizenship', 'United States of America')  |  ('Apple Inc.', 'location', 'United States')
# ('Apple Inc.', 'headquarters location', 'United States of America')  |  ('Apple Inc.', 'location', 'United States')
# ('Apple Inc.', 'inception', 'iPhone')  |  ('Apple Inc.', 'product, material, or service produced or provided', 'IPhone')
# ('Apple Inc.', 'has part', 'iPhone')  |  ('Apple Inc.', 'product, material, or service produced or provided', 'IPhone')
# ('Apple Inc.', 'largest vendor of', 'iPhone')  |  ('Apple Inc.', 'product, material, or service produced or provided', 'IPhone')
# ('Apple Inc.', 'inception', 'iPad')  |  ('Apple Inc.', 'product, material, or service produced or provided', 'IPad')
# ('Apple Inc.', 'specialized in', 'Software')  |  ('Apple Inc.', 'product, material, or service produced or provided', 'Software')
# ('Apple Inc.', 'inception', 'iPod')  |  ('Apple Inc.', 'product, material, or service produced or provided', 'IPod')
# ('Apple Inc.', 'inception', 'iMac')  |  ('Apple Inc.', 'product, material, or service produced or provided', 'IMac')
# ('Macintosh', 'developer', 'Apple Inc.')  |  ('Apple Inc.', 'product, material, or service produced or provided', 'Mac (computer)')
# ('Apple Inc.', 'inception', 'Macintosh')  |  ('Apple Inc.', 'product, material, or service produced or provided', 'Mac (computer)')
# ('Apple Inc.', 'has part', 'Macintosh')  |  ('Apple Inc.', 'product, material, or service produced or provided', 'Mac (computer)')
# ('Apple Inc.', 'has part', 'Apple TV')  |  ('Apple Inc.', 'product, material, or service produced or provided', 'Apple TV')
# ('Apple Inc.', 'specialized in', 'Apple TV')  |  ('Apple Inc.', 'product, material, or service produced or provided', 'Apple TV')
# ('Apple Inc.', 'specialized in', 'Consumer electronics')  |  ('Apple Inc.', 'product, material, or service produced or provided', 'Consumer electronics')
# ('Apple Inc.', 'has part', 'Apple Watch')  |  ('Apple Inc.', 'product, material, or service produced or provided', 'Apple Watch')
# ('Apple Inc.', 'specialized in', 'Apple Pay')  |  ('Apple Inc.', 'product, material, or service produced or provided', 'Apple Pay')
# ('Apple Inc.', 'founder of', 'Steve Wozniak')  |  ('Apple Inc.', 'founded by', 'Steve Wozniak')
# ('Steve Wozniak', 'founder of', 'Apple Inc.')  |  ('Apple Inc.', 'founded by', 'Steve Wozniak')
# ('Apple Inc.', 'inception', 'Steve Wozniak')  |  ('Apple Inc.', 'founded by', 'Steve Wozniak')
# ('Steve Wozniak', 'departed from', 'Apple Inc.')  |  ('Apple Inc.', 'founded by', 'Steve Wozniak')
# ('Apple Inc.', 'headquarters location', 'Cupertino')  |  ('Apple Inc.', 'headquarters location', 'Cupertino, California')
# ('Tim Cook', 'occupation', 'Apple Inc.')  |  ('Apple Inc.', 'chief executive officer', 'Tim Cook')
# ('Apple Inc.', 'inception', 'Think different')  |  ('Apple Inc.', 'motto', 'Think different')
# ('Steve Wozniak', 'country of citizenship', 'United States of America')  |  ('Steve Wozniak', 'country of citizenship', 'United States')
# ('Steve Wozniak', 'occupation', 'Inventor')  |  ('Steve Wozniak', 'occupation', 'Inventor')
# ('Steve Wozniak', 'developed', 'Apple I')  |  ('Steve Wozniak', 'notable work', 'Apple I')
# ('Steve Wozniak', 'developed', 'Apple II')  |  ('Steve Wozniak', 'notable work', 'Apple II (original)')
# ('Steve Wozniak', 'founder of', 'CL 9')  |  ('Steve Wozniak', 'owner of', 'CL 9')
# ('Pixar', 'country of citizenship', 'United States of America')  |  ('Pixar', 'country', 'United States')
# ('Pixar', 'instance of', 'Animation studio')  |  ('Pixar', 'instance of', 'Animation studio')
# ('Pixar', 'headquarters location', 'Emeryville, California')  |  ('Pixar', 'headquarters location', 'Emeryville, California')
# ('Pixar', 'acquired', 'Walt Disney Studios')  |  ('Pixar', 'parent organization', 'Walt Disney Studios (division)')
# ('Luxo Jr.', 'mascot of', 'Pixar')  |  ('Pixar', 'mascot', 'Luxo Jr. (character)')
# ('Pixar', 'developed', 'RenderMan')  |  ('Pixar RenderMan', 'developer', 'Pixar')
# ('RenderMan', 'developed', 'Pixar')  |  ('Pixar RenderMan', 'developer', 'Pixar')
# ('Pixar', 'notable work', 'Toy Story')  |  ('Toy Story', 'production company', 'Pixar')
# ('Pixar', 'developed', 'Inside Out 2')  |  ('Inside Out 2', 'production company', 'Pixar')
# ('NeXT', 'country of citizenship', 'United States of America')  |  ('NeXT', 'country', 'United States')
# ('NeXT', 'headquarters location', 'Redwood City')  |  ('NeXT', 'headquarters location', 'Redwood City, California')
# ('NeXTstation', 'specialized in', 'NeXT')  |  ('NeXT', 'product, material, or service produced or provided', 'NeXTstation')
# ('NeXTcube', 'specialized in', 'NeXT')  |  ('NeXT', 'product, material, or service produced or provided', 'NeXTcube')
# ('Apple Inc.', 'acquired', 'NeXT')  |  ('NeXT', 'merged into', 'Apple Inc.')
# ('NeXT', 'developed', 'OpenStep')  |  ('OpenStep', 'developer', 'NeXT')
# ('NeXT', 'specialized in', 'OpenStep')  |  ('OpenStep', 'developer', 'NeXT')

# %% [markdown]
# ## Neo4j

# %%
from neo4j import GraphDatabase

uri = "neo4j://localhost:7687"
username = "neo4j"
password = "12345678"
driver = GraphDatabase.driver(uri, auth=(username, password))

# %%
# def add_node(tx, node_name):
#     tx.run("CREATE (n:WikidataNode {name: $node_name})", node_name=node_name)

# def add_relation(tx, head, tail, relation):
#     query = f"""
#         MATCH (a {{name: $head}}), (b {{name: $tail}})
#         CREATE (a)-[r:{relation}]->(b)
#         RETURN type(r)
#         """
#     result = tx.run(query, head=head, tail=tail, database_='abc')

# def get_node(tx, name):
#     result = tx.run("MATCH (n:WikidataNode {name: $name}) RETURN n.name AS name", name=name)
#     return [record["name"] for record in result]


# for i, row in all_df.iterrows():
#     head = row['subject']
#     tail = row['object']
#     relation = "_".join(row['predicate'].replace("-", "").replace("/", "").replace("'", "").replace(",", "").replace(".", "").split())
#     # print(head, tail, relation)
#     with driver.session() as session:
#         if not session.read_transaction(get_node, head):
#             session.write_transaction(add_node, head)

#         if not session.read_transaction(get_node, tail):
#             session.write_transaction(add_node, tail)
            
#         session.write_transaction(add_relation, head, tail, relation)
# Out:
# /tmp/ipykernel_2976451/2957672088.py:23: DeprecationWarning: read_transaction has been renamed to execute_read
#   if not session.read_transaction(get_node, head):
# /tmp/ipykernel_2976451/2957672088.py:26: DeprecationWarning: read_transaction has been renamed to execute_read
#   if not session.read_transaction(get_node, tail):
# /tmp/ipykernel_2976451/2957672088.py:29: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(add_relation, head, tail, relation)
# /tmp/ipykernel_2976451/2957672088.py:27: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(add_node, tail)
# /tmp/ipykernel_2976451/2957672088.py:24: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(add_node, head)

# %%
def add_node(tx, node_name):
    tx.run("CREATE (n:WikidataNode {name: $node_name})", node_name=node_name)

def add_relation(tx, head, tail, relation):
    query = f"""
        MATCH (a {{name: $head}}), (b {{name: $tail}})
        CREATE (a)-[r:{relation}]->(b)
        RETURN type(r)
        """
    result = tx.run(query, head=head, tail=tail, database_='abc')

def get_node(tx, name):
    result = tx.run("MATCH (n:WikidataNode {name: $name}) RETURN n.name AS name", name=name)
    return [record["name"] for record in result]


for triplet in wikidata_common_triplets:
    head = triplet[0]
    tail = triplet[2]
    relation = "_".join(triplet[1].replace("-", "").replace("/", "").replace("'", "").replace(",", "").replace(".", "").split())
    # print(head, tail, relation)
    with driver.session() as session:
        if not session.read_transaction(get_node, head):
            session.write_transaction(add_node, head)

        if not session.read_transaction(get_node, tail):
            session.write_transaction(add_node, tail)
            
        session.write_transaction(add_relation, head, tail, relation)
# Out:
# /tmp/ipykernel_262807/1317099799.py:23: DeprecationWarning: read_transaction has been renamed to execute_read
#   if not session.read_transaction(get_node, head):
# /tmp/ipykernel_262807/1317099799.py:24: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(add_node, head)
# /tmp/ipykernel_262807/1317099799.py:26: DeprecationWarning: read_transaction has been renamed to execute_read
#   if not session.read_transaction(get_node, tail):
# /tmp/ipykernel_262807/1317099799.py:27: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(add_node, tail)
# /tmp/ipykernel_262807/1317099799.py:29: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(add_relation, head, tail, relation)

# %%
def add_node(tx, node_name):
    tx.run("CREATE (n:WikipediaNode {name: $node_name})", node_name=node_name)

def add_relation(tx, head, tail, relation):
    query = f"""
        MATCH (a:WikipediaNode {{name: $head}}), (b:WikipediaNode {{name: $tail}})
        CREATE (a)-[r:{relation}]->(b)
        RETURN type(r)
        """
    result = tx.run(query, head=head, tail=tail, database_='abc')

def get_node(tx, name):
    result = tx.run("MATCH (n:WikipediaNode {name: $name}) RETURN n.name AS name", name=name)
    return [record["name"] for record in result]


for triplet in wikipedia_common_triplets:
    head = triplet[0]
    tail = triplet[2]
    relation = "_".join(triplet[1].replace("-", "").replace("/", "").replace("'", "").replace(",", "").replace(".", "").split())
    # print(head, tail, relation)
    with driver.session() as session:
        if not session.read_transaction(get_node, head):
            session.write_transaction(add_node, head)

        if not session.read_transaction(get_node, tail):
            session.write_transaction(add_node, tail)
            
        session.write_transaction(add_relation, head, tail, relation)
# Out:
# /tmp/ipykernel_262807/335693486.py:23: DeprecationWarning: read_transaction has been renamed to execute_read
#   if not session.read_transaction(get_node, head):
# /tmp/ipykernel_262807/335693486.py:24: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(add_node, head)
# /tmp/ipykernel_262807/335693486.py:26: DeprecationWarning: read_transaction has been renamed to execute_read
#   if not session.read_transaction(get_node, tail):
# /tmp/ipykernel_262807/335693486.py:27: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(add_node, tail)
# /tmp/ipykernel_262807/335693486.py:29: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(add_relation, head, tail, relation)

# %%
def delete_all(tx):
    tx.run("MATCH (n) DETACH DELETE n")

with driver.session() as session:
    session.execute_write(delete_all)
