# %%
from pymongo.mongo_client import MongoClient
import json

# %% [markdown]
# ## Utils

# %%
mappings_dir = "utils/ontology_mappings/"

with open(mappings_dir+'prop2label.json', 'r') as f:
    PROP_2_LABEL = json.load(f)

with open(mappings_dir+'entity_type2label.json', 'r') as f:
    ENTITY_2_LABEL = json.load(f)

# %%
def get_mongo_client(mongo_uri):
    client = MongoClient(mongo_uri)
    return client

mongo_client = get_mongo_client("mongodb://localhost:27018/?directConnection=true")
db = mongo_client.get_database("wikidata_ontology")
db.list_collection_names()
# Out:
# ['properties',
#  'property_aliases',
#  'entity_aliases',
#  'triplets',
#  'filtered_triplets',
#  'entity_type_aliases',
#  'entity_types']

# %%
print(db.get_collection('entity_type_aliases').find_one().keys())
print(db.get_collection('entity_types').find_one().keys())
print(db.get_collection('properties').find_one().keys())
print(db.get_collection('property_aliases').find_one().keys())
# Out:
# dict_keys(['_id', 'entity_type_id', 'alias_label', 'alias_text_embedding'])
# dict_keys(['_id', 'entity_type_id', 'label', 'parent_type_ids', 'valid_subject_property_ids', 'valid_object_property_ids'])
# dict_keys(['_id', 'property_id', 'label', 'valid_subject_type_ids', 'valid_object_type_ids'])
# dict_keys(['_id', 'relation_id', 'alias_label', 'alias_text_embedding'])

# %%
print(list(db.get_collection('entity_type_aliases').list_search_indexes()))
print(list(db.get_collection('property_aliases').list_search_indexes()))
# Out:
# [{'id': '684c685a5ed97f053516d78c', 'name': 'entity_type_aliases', 'type': 'search', 'status': 'READY', 'queryable': True, 'latestVersion': 0, 'latestDefinition': {'mappings': {'dynamic': True, 'fields': {'alias_text_embedding': {'type': 'knnVector', 'dimensions': 768, 'similarity': 'cosine'}}}}}]
# [{'id': '684c686e5ed97f053516d78d', 'name': 'property_aliases_ids', 'type': 'search', 'status': 'READY', 'queryable': True, 'latestVersion': 0, 'latestDefinition': {'mappings': {'dynamic': True, 'fields': {'alias_text_embedding': {'type': 'knnVector', 'dimensions': 768, 'similarity': 'cosine'}, 'relation_id': {'type': 'token'}}}}}]

# %% [markdown]
# ## Functions for structural search

# %%
from utils.structured_dynamic_index_utils import Aligner as Aligner

# %% [markdown]
# ## Triple extraction tests

# %%
from utils.openai_utils import LLMTripletExtractor
from utils.structured_dynamic_index_utils_with_db import Aligner as DBAligner

aligner = DBAligner(db)
model_name = 'gpt-4.1-mini'
extractor = LLMTripletExtractor(model=model_name)

# %%
aligner.retrieve_properties_labels_and_constraints(['P291', 'P189'])
# Out:
# {'P189': {'label': 'location of discovery',
#   'valid_subject_type_ids': [],
#   'valid_object_type_ids': ['Q3895768', 'Q17334923', 'Q27096213']},
#  'P291': {'label': 'place of publication',
#   'valid_subject_type_ids': ['Q11424',
#    'Q386724',
#    'Q2031291',
#    'Q3331189',
#    'Q3523102',
#    'Q17489659'],
#   'valid_object_type_ids': ['Q220505', 'Q15796005', 'Q27096213', 'Q27787439']}}

# %%
from unidecode import unidecode
import re

def extract_triplets(text, sample_id):
    """Extract and refine knowledge graph triplets from text using LLM.
    
    Args:
        text (str): Input text to extract triplets from
        
    Returns:
        tuple: (final_triplets, filtered_triplets) where:
            - final_triplets: List of validated and refined triplets
            - filtered_triplets: List of triplets that couldn't be validated
    """
    # Extract initial triplets using LLM
    extracted_triplets = extractor.extract_triplets_from_text(text)
    
    final_triplets = []
    filtered_triplets = []

    for triplet in extracted_triplets['triplets']:        
        try:
            # Get candidate entity types
            subj_type_ids, obj_type_ids = aligner.retrieve_similar_entity_types(triplet=triplet)
            
            # Get candidate properties/relations
            properties = aligner.retrieve_properties_for_entity_type(
                target_relation=triplet['relation'],
                object_types=obj_type_ids, 
                subject_types=subj_type_ids,
                k=5
            )
            prop_2_label_and_constraint = aligner.retrieve_properties_labels_and_constraints(property_id_list=[p[0] for p in properties])
            entity_type_id_2_label = aligner.retrieve_entity_type_labels(subj_type_ids + obj_type_ids)

            # Build candidate triplet backbones
            candidates = []

            for prop_id, prop_direction in properties:
                valid_subject_type_ids = prop_2_label_and_constraint[prop_id]['valid_subject_type_ids']
                valid_object_type_ids = prop_2_label_and_constraint[prop_id]['valid_object_type_ids']
                property_label = prop_2_label_and_constraint[prop_id]['label']

                if prop_direction == 'direct':
                    # Include hierarchy here too??
                    subject_types = set(subj_type_ids) & set(valid_subject_type_ids)
                    object_types = set(obj_type_ids) & set(valid_object_type_ids)

                    # Use original type sets if no constraints matched
                    # meaning that property can be connected with <ANY> entity type
                    subject_types = subj_type_ids if len(subject_types) == 0 else subject_types
                    object_types = obj_type_ids if len(object_types) == 0 else object_types
                else:
                    subject_types = set(obj_type_ids) & set(valid_subject_type_ids)
                    object_types = set(subj_type_ids) & set(valid_object_type_ids) 
                    
                    # Use original type sets if no constraints matched
                    # meaning that property can be connected with <ANY> entity type
                    subject_types = obj_type_ids if len(subject_types) == 0 else subject_types
                    object_types = subj_type_ids if len(object_types) == 0 else object_types
                    
                subject_types = subj_type_ids if len(subject_types) == 0 else subject_types
                object_types = obj_type_ids if len(object_types) == 0 else object_types

                candidates.append({
                    "subject": triplet['subject'] if prop_direction == 'direct' else triplet['object'],
                    "relation": property_label,
                    'object': triplet['object'] if prop_direction == 'direct' else triplet['subject'],
                    "subject_types": [entity_type_id_2_label[t]['label'] for t in subject_types],
                    "object_types": [entity_type_id_2_label[t]['label'] for t in object_types]
                })


            # Refine relation and entity types using LLM - choose among valid backbones for triplet
            backbone_triplet = extractor.refine_relation_and_entity_types(
                text=text, 
                triplet=triplet,
                candidate_triplets=candidates,
            )
            print(backbone_triplet)
            backbone_triplet['qualifiers'] = triplet['qualifiers']

            # Refine entity names
            final_triplet = refine_entities(text, backbone_triplet, aligner, sample_id)
            
            final_triplets.append(final_triplet)
            # !! Add validation that triplet was formed from bd types
        except Exception as e:
            print(e)
            filtered_triplets.append(triplet)
        # print("2nd resulted triplet: ", final_triplet)
    # print("-"*100)
    if len(final_triplets) > 0:
        aligner.add_triplets(final_triplets, sample_id=sample_id)
    if len(filtered_triplets) > 0:
        aligner.add_filtered_triplets(filtered_triplets, sample_id=sample_id)
    return final_triplets, filtered_triplets


def refine_entities(text, triplet, aligner, sample_id):
    """Refine entity names using type constraints."""

    print(triplet)

    triplet['subject'] = unidecode(triplet['subject'])
    triplet['object'] = unidecode(triplet['object'])

    print(triplet['object_type'], triplet['subject_type'])
    ################################ Handle object refinement ################################
    obj_hierarchy = aligner.retrieve_entity_type_hirerarchy(triplet['object_type'])
    updated_obj = 'None'
    
    # do not change time or quantity entities
    if not any(t in ['Q186408', 'Q309314'] for t in obj_hierarchy):
        similar_objects = aligner.retrieve_entity_by_type(
            entity_name=triplet['object'],
            entity_type=triplet['object_type'],
            sample_id=sample_id
        )
        if len(similar_objects) > 0:
            if triplet['object'] in similar_objects:
                updated_obj = similar_objects[triplet['object']]
            else:
                updated_obj = extractor.refine_entity(
                    text=text,
                    triplet=triplet,
                    candidates=list(similar_objects.values()),
                    is_object=True
                )
                updated_obj = unidecode(updated_obj)
    
    if re.sub(r'[^\w\s]', '', updated_obj) != 'None':
        if triplet['object'] != updated_obj:
            aligner.add_entity(entity_name=updated_obj, alias=triplet['object'], entity_type=triplet['object_type'], sample_id=sample_id)
        triplet['object'] = updated_obj
    else:
        aligner.add_entity(entity_name=triplet['object'], alias=triplet['object'], entity_type=triplet['object_type'], sample_id=sample_id)

    ################################# Handle subject refinement ################################
    updated_subj = 'None'
    similar_subjects = aligner.retrieve_entity_by_type(
        entity_name=triplet['subject'],
        entity_type=triplet['subject_type'],
        sample_id=sample_id
    )
    if len(similar_subjects) > 0:
        if triplet['subject'] in similar_subjects:
            updated_subj = similar_subjects[triplet['subject']]
        else:
            updated_subj = extractor.refine_entity(
                text=text,
                triplet=triplet,
                candidates=list(similar_subjects.values()),
                is_object=False
            )
            updated_subj = unidecode(updated_subj)
    
    if re.sub(r'[^\w\s]', '', updated_subj) != 'None':
        if triplet['subject'] != updated_subj:
            aligner.add_entity(entity_name=updated_subj, alias=triplet['subject'], entity_type=triplet['subject_type'], sample_id=sample_id)
        triplet['subject'] = updated_subj
    else:
        aligner.add_entity(entity_name=triplet['subject'], alias=triplet['subject'], entity_type=triplet['subject_type'], sample_id=sample_id)
        
    return triplet

# %%
text = "Yura Borisov is up for Best Supporting Actor for his role in Sean Baker's “Anora” at the Academy Awards on March 2, making him the first Russian to be nominated in an acting category since the fall of the Soviet Union."

# %%
import time

start_time = time.time()
result = extract_triplets(text, "0")
end_time = time.time()
print(f"\nExecution time: {end_time - start_time:.2f} seconds")
# Out:
# {'subject': 'Yura Borisov', 'relation': 'nominated for', 'object': 'Best Supporting Actor', 'subject_type': 'human', 'object_type': 'class of award'}
# {'subject': 'Yura Borisov', 'relation': 'nominated for', 'object': 'Best Supporting Actor', 'subject_type': 'human', 'object_type': 'class of award', 'qualifiers': [{'relation': 'for work', 'object': 'Anora'}, {'relation': 'award event', 'object': 'Academy Awards'}, {'relation': 'point in time', 'object': 'March 2'}]}
# class of award human
# class of award
# ['artificial object', 'class (collection of items defined by common characteristics)', 'cultural artifact', 'metaclass', 'entity', 'class of award', 'object', 'award', 'abstract entity', 'collective entity']
# 0
# {'Best Supporting Actor': 'Best Supporting Actor'}
# ['continuant', 'person or organization', 'individual organism', 'natural person', 'class (collection of items defined by common characteristics)', 'person', 'group or class of organisms', 'physical object', 'agent (distinct and identifiable entity capable of performing actions)', 'individual animal', 'anatomical entity', 'entity', 'legal person', 'concrete object', 'object', 'human', 'organisms known by a particular common name', 'physical anatomical entity', 'abstract entity', 'organism', 'animal', 'individual', 'group or class of physical objects', 'collective entity']
# 0
# {'Borisov': 'Borisov'}
# {'subject': 'Anora', 'relation': 'director', 'object': 'Sean Baker', 'subject_type': 'film', 'object_type': 'human'}
# {'subject': 'Anora', 'relation': 'director', 'object': 'Sean Baker', 'subject_type': 'film', 'object_type': 'human', 'qualifiers': []}
# human film
# human
# ['continuant', 'person or organization', 'individual organism', 'natural person', 'class (collection of items defined by common characteristics)', 'person', 'group or class of organisms', 'physical object', 'agent (distinct and identifiable entity capable of performing actions)', 'individual animal', 'anatomical entity', 'entity', 'legal person', 'concrete object', 'object', 'human', 'organisms known by a particular common name', 'physical anatomical entity', 'abstract entity', 'organism', 'animal', 'individual', 'group or class of physical objects', 'collective entity']
# 0
# {'Borisov': 'Borisov', 'Yura Borisov': 'Borisov'}
# ['video work', 'video and/or audio work', 'function', 'film', 'binary relation', 'sequence', 'intellectual work', 'artificial object', 'creative work', 'class (mathematical collection of sets that can be defined based on a property of its members (set theory))', 'product', 'audiovisual work', 'mathematical object', 'goods', 'goods and services', 'entity', 'set', 'work (intellectual or artistic creation)', 'visual artwork', 'object', 'spatio-temporal entity', 'abstract entity', 'mathematical structure', 'work of art', 'relation', 'property']
# 0
# {'Anora': 'Anora', 'Inception': 'Inception'}
# {'subject': 'Yura Borisov', 'relation': 'nominee', 'object': 'fall of the Soviet Union', 'subject_type': 'human', 'object_type': 'political event'}
# {'subject': 'Yura Borisov', 'relation': 'nominee', 'object': 'fall of the Soviet Union', 'subject_type': 'human', 'object_type': 'political event', 'qualifiers': []}
# political event human
# political event
# ['occurrence', 'event', 'political event', 'entity', 'object', 'spatio-temporal entity', 'occurrent']
# 0
# {'fall of the Soviet Union': 'fall of the Soviet Union'}
# ['continuant', 'person or organization', 'individual organism', 'natural person', 'class (collection of items defined by common characteristics)', 'person', 'group or class of organisms', 'physical object', 'agent (distinct and identifiable entity capable of performing actions)', 'individual animal', 'anatomical entity', 'entity', 'legal person', 'concrete object', 'object', 'human', 'organisms known by a particular common name', 'physical anatomical entity', 'abstract entity', 'organism', 'animal', 'individual', 'group or class of physical objects', 'collective entity']
# 0
# {'Yura Borisov': 'Borisov', 'Borisov': 'Borisov', 'Sean Baker': 'Sean Baker'}
#
# Execution time: 16.24 seconds

# %%
list(db.get_collection("entity_aliases").find({}, {'_id': 0, "label": 1, "alias": 1, "entity_type": 1, "sample_id": 1}))
# Out:
# [{'label': 'Best Supporting Actor',
#   'entity_type': 'award',
#   'alias': 'Best Supporting Actor',
#   'sample_id': '0'},
#  {'label': 'Borisov',
#   'entity_type': 'human',
#   'alias': 'Borisov',
#   'sample_id': '0'},
#  {'label': 'fall of the Soviet Union',
#   'entity_type': 'event',
#   'alias': 'fall of the Soviet Union',
#   'sample_id': '0'},
#  {'label': 'Anora', 'entity_type': 'film', 'alias': 'Anora', 'sample_id': '0'},
#  {'label': 'science fiction',
#   'entity_type': 'genre',
#   'alias': 'science fiction',
#   'sample_id': '0'},
#  {'label': 'Inception',
#   'entity_type': 'film',
#   'alias': 'Inception',
#   'sample_id': '0'},
#  {'label': 'Borisov',
#   'entity_type': 'human',
#   'alias': 'Yura Borisov',
#   'sample_id': '0'},
#  {'label': 'Sean Baker',
#   'entity_type': 'human',
#   'alias': 'Sean Baker',
#   'sample_id': '0'}]

# %%
db.get_collection("triplets").delete_many({})
# Out:
# DeleteResult({'n': 18, 'electionId': ObjectId('7fffffff0000000000000008'), 'opTime': {'ts': Timestamp(1751714329, 2), 't': 8}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1751714329, 2), 'signature': {'hash': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', 'keyId': 0}}, 'operationTime': Timestamp(1751714329, 2)}, acknowledged=True)

# %%
db.get_collection("entity_aliases").delete_many({})
# Out:
# DeleteResult({'n': 19, 'electionId': ObjectId('7fffffff0000000000000008'), 'opTime': {'ts': Timestamp(1751714329, 4), 't': 8}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1751714329, 4), 'signature': {'hash': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', 'keyId': 0}}, 'operationTime': Timestamp(1751714329, 4)}, acknowledged=True)

# %%
extractor.calculate_cost()
# Out:
# 0.0091016

# %%
list(db.get_collection('entity_aliases').list_search_indexes())
# Out:
# [{'id': '68460260d541617ce2e16b42',
#   'name': 'entities',
#   'type': 'search',
#   'status': 'READY',
#   'queryable': True,
#   'latestVersion': 0,
#   'latestDefinition': {'mappings': {'dynamic': True,
#     'fields': {'entity_type': {'type': 'token'},
#      'sample_id': {'type': 'token'},
#      'alias_text_embedding': {'type': 'knnVector',
#       'dimensions': 768,
#       'similarity': 'cosine'}}}}}]

# %%
db.get_collection('entity_aliases').delete_many({})
# Out:
# DeleteResult({'n': 17726, 'electionId': ObjectId('7fffffff0000000000000008'), 'opTime': {'ts': Timestamp(1751709397, 1773), 't': 8}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1751709397, 1773), 'signature': {'hash': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', 'keyId': 0}}, 'operationTime': Timestamp(1751709397, 1773)}, acknowledged=True)

# %%
list(db.get_collection('triplets').find({}))
# Out:
# [{'_id': ObjectId('686446949362efa843c65a26'),
#   'subject': 'Michael Joseph Jackson',
#   'object': 'August 29, 1958',
#   'relation': 'date of birth',
#   'object_type': 'point in time',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'a4ddb2ba-eb7e-4268-92ca-fec0036c35cc',
#   'source_text_id': 0},
#  {'_id': ObjectId('686446969362efa843c65a27'),
#   'subject': 'Michael Joseph Jackson',
#   'subject_type': 'human',
#   'object_type': 'point in time',
#   'relation': 'date of death',
#   'object': 'June 25, 2009',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'a4ddb2ba-eb7e-4268-92ca-fec0036c35cc',
#   'source_text_id': 0},
#  {'_id': ObjectId('686446979362efa843c65a28'),
#   'subject': 'Michael Joseph Jackson',
#   'object': 'singer',
#   'relation': 'occupation',
#   'object_type': 'profession',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'a4ddb2ba-eb7e-4268-92ca-fec0036c35cc',
#   'source_text_id': 0},
#  {'_id': ObjectId('686446989362efa843c65a29'),
#   'object': 'songwriter',
#   'object_type': 'profession',
#   'relation': 'occupation',
#   'subject_type': 'human',
#   'subject': 'Michael Joseph Jackson',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'a4ddb2ba-eb7e-4268-92ca-fec0036c35cc',
#   'source_text_id': 0},
#  {'_id': ObjectId('6864469b9362efa843c65a2a'),
#   'subject': 'Michael Joseph Jackson',
#   'object': 'dancer',
#   'relation': 'occupation',
#   'object_type': 'profession',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'a4ddb2ba-eb7e-4268-92ca-fec0036c35cc',
#   'source_text_id': 0},
#  {'_id': ObjectId('6864469d9362efa843c65a2b'),
#   'object': 'philanthropist',
#   'object_type': 'profession',
#   'relation': 'occupation',
#   'subject_type': 'human',
#   'subject': 'Michael Joseph Jackson',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'a4ddb2ba-eb7e-4268-92ca-fec0036c35cc',
#   'source_text_id': 0},
#  {'_id': ObjectId('686521c89362efa843c65a57'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'February 24, 1955',
#   'relation': 'date of birth',
#   'object_type': 'point in time',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686521c99362efa843c65a58'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'October 5, 2011',
#   'relation': 'date of death',
#   'object_type': 'point in time',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686521cb9362efa843c65a59'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'businessman',
#   'relation': 'occupation',
#   'object_type': 'profession',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686521cc9362efa843c65a5a'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'inventor',
#   'relation': 'occupation',
#   'object_type': 'profession',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686521ce9362efa843c65a5b'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'investor',
#   'relation': 'occupation',
#   'object_type': 'profession',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686521d09362efa843c65a5c'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'Apple Inc.',
#   'relation': 'founded by',
#   'object_type': 'company',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686521d19362efa843c65a5d'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'NeXT',
#   'relation': 'founded by',
#   'object_type': 'company',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686521d39362efa843c65a5e'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'Pixar',
#   'relation': 'owner of',
#   'object_type': 'enterprise',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686521d49362efa843c65a5f'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'Pixar',
#   'relation': 'owner of',
#   'object_type': 'company',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [{'relation': 'type', 'object': 'majority'}],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686521d69362efa843c65a60'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'personal computer revolution',
#   'relation': 'part of',
#   'object_type': 'event',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [{'relation': 'time period', 'object': '1970s and 1980s'}],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686521d89362efa843c65a61'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'Steve Wozniak',
#   'relation': 'partner in business or sport',
#   'object_type': 'human',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686522509362efa843c65a62'),
#   'subject': 'Steven Paul Jobs',
#   'object': '1955',
#   'relation': 'date of birth',
#   'object_type': 'point in time',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [{'relation': 'place of birth', 'object': 'San Francisco'}],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686522539362efa843c65a63'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'shortly afterwards',
#   'relation': 'adopted',
#   'object_type': 'event',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686522569362efa843c65a64'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'Reed College',
#   'relation': 'educated at',
#   'object_type': 'educational organization',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [{'relation': 'point in time', 'object': '1972'}],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686522579362efa843c65a65'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'Reed College',
#   'relation': 'withdrew from',
#   'object_type': 'educational institution',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [{'relation': 'point in time', 'object': '1972'}],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('6865225a9362efa843c65a66'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'India',
#   'relation': 'traveled to',
#   'object_type': 'country',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [{'relation': 'point in time', 'object': '1974'},
#    {'relation': 'purpose', 'object': 'seeking enlightenment'}],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('6865225b9362efa843c65a67'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'Zen Buddhism',
#   'relation': 'studied in',
#   'object_type': 'philosophy',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('6865225e9362efa843c65a68'),
#   'subject': 'Steve Jobs',
#   'object': 'Apple Inc.',
#   'relation': 'founded by',
#   'object_type': 'enterprise',
#   'subject_type': 'group of humans',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [{'relation': 'point in time', 'object': '1976'}],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686522609362efa843c65a69'),
#   'subject': 'Apple Inc.',
#   'object': 'Apple I personal computer',
#   'relation': 'developer',
#   'object_type': 'product',
#   'subject_type': 'company',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [{'relation': 'type', 'object': 'personal computer'}],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686522629362efa843c65a6a'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'Apple II',
#   'relation': 'notable work',
#   'object_type': 'product',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [{'relation': 'point in time', 'object': '1977'},
#    {'relation': 'type', 'object': 'mass-produced microcomputer'}],
#   'sample_id': 'b4a86b83-7ec9-4819-bdf3-d2e002dda8c8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686523e29362efa843c65a6f'),
#   'object': 'United States of America',
#   'object_type': 'country',
#   'relation': 'country of citizenship',
#   'subject_type': 'human',
#   'subject': 'Steven Paul Jobs',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b0da1e16-d936-47f3-a112-3b7ac0f42fb8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686523e79362efa843c65a70'),
#   'subject': 'Apple Inc.',
#   'object': 'Steven Paul Jobs',
#   'relation': 'founded by',
#   'object_type': 'human',
#   'subject_type': 'company',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b0da1e16-d936-47f3-a112-3b7ac0f42fb8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686523e89362efa843c65a71'),
#   'subject': 'NeXT',
#   'object': 'Steven Paul Jobs',
#   'relation': 'founded by',
#   'object_type': 'human',
#   'subject_type': 'company',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b0da1e16-d936-47f3-a112-3b7ac0f42fb8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686523e99362efa843c65a72'),
#   'object': 'Pixar',
#   'object_type': 'company',
#   'relation': 'member of',
#   'subject_type': 'human',
#   'subject': 'Steven Paul Jobs',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b0da1e16-d936-47f3-a112-3b7ac0f42fb8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686523eb9362efa843c65a73'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'personal computer revolution',
#   'relation': 'notable work',
#   'object_type': 'technology',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [{'relation': 'point in time', 'object': '1970s'},
#    {'relation': 'point in time', 'object': '1980s'}],
#   'sample_id': 'b0da1e16-d936-47f3-a112-3b7ac0f42fb8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686524619362efa843c65a74'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'San Francisco',
#   'relation': 'place of birth',
#   'object_type': 'city',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b0da1e16-d936-47f3-a112-3b7ac0f42fb8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686524649362efa843c65a75'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'shortly after birth',
#   'relation': 'practiced by',
#   'object_type': 'event',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b0da1e16-d936-47f3-a112-3b7ac0f42fb8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686524659362efa843c65a76'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'Reed College',
#   'relation': 'educated at',
#   'object_type': 'university',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [{'relation': 'point in time', 'object': '1972'}],
#   'sample_id': 'b0da1e16-d936-47f3-a112-3b7ac0f42fb8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686524669362efa843c65a77'),
#   'subject': 'Steven Paul Jobs',
#   'object': '1972',
#   'relation': 'date of application',
#   'object_type': 'point in time',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b0da1e16-d936-47f3-a112-3b7ac0f42fb8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686524689362efa843c65a78'),
#   'relation': 'participant in',
#   'subject_type': 'human',
#   'subject': 'Steven Paul Jobs',
#   'object': 'India',
#   'object_type': 'country',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [{'relation': 'point in time', 'object': '1974'},
#    {'relation': 'purpose', 'object': 'seeking enlightenment'}],
#   'sample_id': 'b0da1e16-d936-47f3-a112-3b7ac0f42fb8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686524699362efa843c65a79'),
#   'subject': 'Steven Paul Jobs',
#   'object': 'Zen Buddhism',
#   'relation': 'participant in',
#   'object_type': 'religion',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': 'b0da1e16-d936-47f3-a112-3b7ac0f42fb8',
#   'source_text_id': 0},
#  {'_id': ObjectId('6865246c9362efa843c65a7a'),
#   'subject': 'Apple Inc.',
#   'object': 'Apple I',
#   'relation': 'product, material, or service produced or provided',
#   'object_type': 'computer',
#   'subject_type': 'corporation',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [{'relation': 'developer', 'object': 'Steve Wozniak'}],
#   'sample_id': 'b0da1e16-d936-47f3-a112-3b7ac0f42fb8',
#   'source_text_id': 0},
#  {'_id': ObjectId('6865246e9362efa843c65a7b'),
#   'relation': 'product, material, or service produced or provided',
#   'subject_type': 'corporation',
#   'subject': 'Apple Inc.',
#   'object': 'Apple II',
#   'object_type': 'computer',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [{'relation': 'point in time', 'object': '1977'},
#    {'relation': 'notable for',
#     'object': 'first highly successful mass-produced microcomputer'}],
#   'sample_id': 'b0da1e16-d936-47f3-a112-3b7ac0f42fb8',
#   'source_text_id': 0},
#  {'_id': ObjectId('686541e29362efa843c65a7c'),
#   'object': 'personal computer revolution',
#   'object_type': 'event',
#   'relation': 'notable work',
#   'subject_type': 'human',
#   'subject': 'Steven Paul Jobs',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [{'relation': 'time period', 'object': '1970s and 1980s'}],
#   'sample_id': '9d057292-7769-4da9-b987-7ff6fdfb81a4',
#   'source_text_id': 0},
#  {'_id': ObjectId('686542199362efa843c65a7d'),
#   'subject': 'Michael Joseph Jackson',
#   'object': 'King of Pop',
#   'relation': 'nickname',
#   'object_type': 'nickname',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': '9d057292-7769-4da9-b987-7ff6fdfb81a4',
#   'source_text_id': 0},
#  {'_id': ObjectId('6865421b9362efa843c65a7e'),
#   'subject': 'Michael Joseph Jackson',
#   'object': '20th century',
#   'relation': 'intangible cultural heritage status',
#   'object_type': 'historical period',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': '9d057292-7769-4da9-b987-7ff6fdfb81a4',
#   'source_text_id': 0},
#  {'_id': ObjectId('6868dd599362efa843c65a7f'),
#   'subject': 'Michael Joseph Jackson',
#   'object': '20th century',
#   'relation': 'notable work',
#   'object_type': 'historical period',
#   'subject_type': 'human',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'sample_id': '55ae886a-9275-41f3-ad92-14ea1d21c014',
#   'source_text_id': 0},
#  {'_id': ObjectId('6868f6459362efa843c65aea'),
#   'subject': 'Elvis Presley',
#   'object': 'January 8, 1935',
#   'relation': 'date of birth',
#   'object_type': 'point in time',
#   'subject_type': 'human',
#   'sample_id': '581e6c95-177f-400b-8d26-248c522b8aad',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'source_text_id': 0},
#  {'_id': ObjectId('6868f6459362efa843c65aeb'),
#   'subject': 'Elvis Presley',
#   'object': 'August 16, 1977',
#   'relation': 'date of death',
#   'object_type': 'point in time',
#   'subject_type': 'human',
#   'sample_id': '581e6c95-177f-400b-8d26-248c522b8aad',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'source_text_id': 0},
#  {'_id': ObjectId('6868f6459362efa843c65aec'),
#   'subject': 'Elvis Presley',
#   'object': 'American',
#   'relation': 'country of citizenship',
#   'object_type': 'nationality',
#   'subject_type': 'human',
#   'sample_id': '581e6c95-177f-400b-8d26-248c522b8aad',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'source_text_id': 0},
#  {'_id': ObjectId('6868f6459362efa843c65aed'),
#   'subject': 'Elvis Presley',
#   'object': 'singer',
#   'relation': 'occupation',
#   'object_type': 'profession',
#   'subject_type': 'human',
#   'sample_id': '581e6c95-177f-400b-8d26-248c522b8aad',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'source_text_id': 0},
#  {'_id': ObjectId('6868f6459362efa843c65aee'),
#   'object': 'actor',
#   'object_type': 'profession',
#   'relation': 'occupation',
#   'sample_id': '581e6c95-177f-400b-8d26-248c522b8aad',
#   'subject_type': 'human',
#   'subject': 'Elvis Presley',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'source_text_id': 0},
#  {'_id': ObjectId('6868f6459362efa843c65aef'),
#   'object': 'King of Rock and Roll',
#   'object_type': 'nickname',
#   'relation': 'named after',
#   'sample_id': '581e6c95-177f-400b-8d26-248c522b8aad',
#   'subject_type': 'human',
#   'subject': 'Elvis Presley',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'source_text_id': 0},
#  {'_id': ObjectId('6868f6459362efa843c65af0'),
#   'object': 'one of the most significant cultural figures of the 20th century',
#   'object_type': 'cultural icon',
#   'relation': 'intangible cultural heritage status',
#   'sample_id': '581e6c95-177f-400b-8d26-248c522b8aad',
#   'subject_type': 'human',
#   'subject': 'Elvis Presley',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'source_text_id': 0},
#  {'_id': ObjectId('6868f64d9362efa843c65af1'),
#   'object': 'one of the most significant cultural figures of the 20th century',
#   'object_type': 'cultural icon',
#   'relation': 'dedicated heritage entity',
#   'sample_id': '581e6c95-177f-400b-8d26-248c522b8aad',
#   'subject_type': 'human',
#   'subject': 'Elvis Presley',
#   'completion_token_num': 0,
#   'prompt_token_nums': 0,
#   'qualifiers': [],
#   'source_text_id': 0}]

# %%
db.list_collection_names()
# Out:
# ['entity_types',
#  'properties',
#  'entity_aliases',
#  'triplets',
#  'entity_type_aliases',
#  'property_aliases']

# %%
import time
text = "In 2010, Christopher Nolan directed the science fiction movie Inception"
# text = 'Sam Altman’s net worth is a major topic for people following the tech industry, as the CEO of OpenAI is one of the most prominent figures out there, especially with the rise of artificial intelligence (AI) and chatbots like ChatGPT.'
# text = "Musk’s xAI releases artificial intelligence model Grok 3, claims better performance than rivals in early testing."
start_time = time.time()
result = extract_triplets(text, "0")
end_time = time.time()
print(f"\nExecution time: {end_time - start_time:.2f} seconds")
# Out:
# {'subject': 'Christopher Nolan', 'relation': 'director', 'object': 'Inception', 'subject_type': 'human', 'object_type': 'movie'}
# {'subject': 'Christopher Nolan', 'relation': 'director', 'object': 'Inception', 'subject_type': 'human', 'object_type': 'movie', 'qualifiers': [{'relation': 'point in time', 'object': '2010'}]}
# movie human
# movie
# 'NoneType' object is not subscriptable
# {'subject': 'Inception', 'relation': 'genre', 'object': 'science fiction', 'subject_type': 'film', 'object_type': 'genre'}
# {'subject': 'Inception', 'relation': 'genre', 'object': 'science fiction', 'subject_type': 'film', 'object_type': 'genre', 'qualifiers': []}
# genre film
# genre
# ['class (collection of items defined by common characteristics)', 'metaclass', 'entity', 'genre', 'abstract entity', 'collective entity']
# 0
# {}
# ['video work', 'video and/or audio work', 'function', 'film', 'binary relation', 'sequence', 'intellectual work', 'artificial object', 'creative work', 'class (mathematical collection of sets that can be defined based on a property of its members (set theory))', 'product', 'audiovisual work', 'mathematical object', 'goods', 'goods and services', 'entity', 'set', 'work (intellectual or artistic creation)', 'visual artwork', 'object', 'spatio-temporal entity', 'abstract entity', 'mathematical structure', 'work of art', 'relation', 'property']
# 0
# {'Anora': 'Anora'}
#
# Execution time: 7.82 seconds

# %%
extractor.calculate_cost()
# Out:
# 0.013104400000000002

# %%
result
# Out:
# ([{'subject': 'Inception',
#    'relation': 'genre',
#    'object': 'science fiction',
#    'subject_type': 'film',
#    'object_type': 'genre',
#    'qualifiers': [],
#    'sample_id': '0',
#    '_id': ObjectId('684604708cb451afb7c0ed2d')}],
#  [{'subject': 'Christopher Nolan',
#    'relation': 'director',
#    'object': 'Inception',
#    'qualifiers': [{'relation': 'point in time', 'object': '2010'}],
#    'subject_type': 'human',
#    'object_type': 'movie',
#    'sample_id': '0',
#    '_id': ObjectId('684604708cb451afb7c0ed2e')}])

# %%
from utils.structured_dynamic_index_utils import Aligner as Aligner
aligner = Aligner()
extractor = LLMTripletExtractor(model=model_name)

# %%
import time
# aligner = Aligner()
start_time = time.time()
result = extract_triplets(text)
end_time = time.time()
print(f"\nExecution time: {end_time - start_time:.2f} seconds")

# %%
extractor.calculate_cost()
